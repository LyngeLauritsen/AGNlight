# %%
import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LogNorm
import scipy.stats as stats
from matplotlib import gridspec
import aplpy as apl #The Astronomy Plotting Library for python
import astropy
from astropy.stats import sigma_clip
from astropy.modeling import functional_models, models, fitting
import astropy.units as U
from astropy.coordinates import ICRS, Galactic, FK4, FK5, Angle, Latitude, Longitude
import astropy.constants as C
from astropy import wcs
import astropy.io.fits as fits
from astropy.io import ascii
import astropy.coordinates as coord
from astropy.coordinates import SkyCoord
from astropy.stats import signal_to_noise_oir_ccd as SNRas
#import spectral_cube as SC
#from spectral_cube import SpectralCube as sc
from astropy.wcs import WCS
matplotlib.use('Agg')
import matplotlib.cm as cm
#import astrometry as ast
import pyfits
import requests
import json
import os
from sklearn import datasets, linear_model
from scipy.optimize import curve_fit
import numpy.ma as ma
from astropy.table import Table, Column
import pyextract
import sewpy
import pandas as pd
from astropy import units as u
# Out:
# /home/lynge/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
sta1_RA_WORLD = SkyCoord('13:06:23.368 -40:24:47.36', unit=(u.hourangle, u.deg)).ra.degree #TYC 7777-7-1
sta1_DEC_WORLD = SkyCoord('13:06:23.368 -40:24:47.36', unit=(u.hourangle, u.deg)).dec.degree

sta2_RA_WORLD = SkyCoord('13:06:20.816 -40:24:00.86', unit=(u.hourangle, u.deg)).ra.degree #2MASS J13062081-4024008
sta2_DEC_WORLD = SkyCoord('13:06:20.816 -40:24:00.86', unit=(u.hourangle, u.deg)).dec.degree

sta3_RA_WORLD = SkyCoord('13:06:31.543 -40:29:53.57', unit=(u.hourangle, u.deg)).ra.degree #UCAC2 14614825
sta3_DEC_WORLD = SkyCoord('13:06:31.543 -40:29:53.57', unit=(u.hourangle, u.deg)).dec.degree

sky_RA_WORLD = SkyCoord('13:06:26 -40:25:33', unit=(u.hourangle, u.deg)).ra.degree #Random patch of sky
sky_DEC_WORLD = SkyCoord('13:06:26 -40:25:33', unit=(u.hourangle, u.deg)).dec.degree


k_g = 0.16
k_r = 0.08
k_i = 0.02
k_z = 0.01

mag_refsta1_g = 11.861
mag_refsta1_r = 11.562
mag_refsta1_i = 11.460
mag_refsta1_z = 11.430

mag_refsta2_g = 10.166
mag_refsta2_r = 10.229
mag_refsta2_i = 10.347
mag_refsta2_z = 10.456

refsta1_RA = SkyCoord('01:54:38 00:43:01', unit=(u.hourangle, u.deg)).ra.degree #P525_E_21_10_17
refsta1_DEC = SkyCoord('01:54:38 00:43:01', unit=(u.hourangle, u.deg)).dec.degree 

refsta2_RA = SkyCoord('08:52:34 -00:39:49', unit=(u.hourangle, u.deg)).ra.degree #PG1323_086_10_07_17
refsta2_DEC = SkyCoord('08:52:34 -00:39:49', unit=(u.hourangle, u.deg)).dec.degree

# %%
QUASAR1_g = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g')]

QUASAR2_g = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g')]

refsta1_g = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g')]

refsta2_g = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g')]

# %%
QUASAR1_r = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r')]

QUASAR2_r = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r')]

refsta1_r = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r')]

refsta2_r = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r')]

# %%
QUASAR1_i = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i')]

QUASAR2_i = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i')]

refsta1_i = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i')]

refsta2_i = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i')]

# %%
QUASAR1_z = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z')]

QUASAR2_z = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z')]

refsta1_z = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z')]

refsta2_z = [os.path.join('/media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z')]

# %%
def dist(mid,end):
    return np.sqrt((mid[0] - end[0])**2 + (mid[1] - end[1])**2)

# %%
def flux_cal(A_mag,B_mag,B_flux):
    '''Flux of A found through magnitude and flux of B'''
    return B_flux*10**((B_mag-A_mag)/2.5)

# %%
def Basic(quasar,header):
    '''Provides a basic list of neccesities from the fits header file for use in the later \
    flux determination, it does not serve an individual purpose beyound that'''
    AGNdata = quasar #np.rot90(np.rot90(np.fliplr(quasar)))
    #header = data[0].header
    #print header
    RAstd = header['CRVAL1']
    DECstd = header['CRVAL2']
    #print RAstd, DECstd
    pixspa = header['PIXSCALE']/(3600.)
    #print pixspa
    RAstdpix = header['CRPIX1']
    DECstdpix = header['CRPIX2']
    exptime = 10 # header['EXPTIME']
    return header,AGNdata,RAstd,DECstd,pixspa,RAstdpix,DECstdpix,exptime

# %%
def curve(quasar,header,w,center,apparature):
    '''Determines the FLUX of the stellar object given the the numpy array of the image, \
    the header of the fits file, the astropy coordinate representation, \
    the object position and the apparature of interest'''
    header,AGNdata,RAstd,DECstd,pixspa,RAstdpix,DECstdpix,exptime = Basic(quasar,header)
    #AGNdata = np.swapaxes(AGNdata,0,1)
    y, x = np.ogrid[0:header['NAXIS1'],0:header['NAXIS1']]
    #w = np.swapaxes(w,0,1)
    #F_AGN = np.zeros((512,512,3)) #((int(2*apparature/pixspa)+1,int(2*apparature/pixspa)+1,3))
    #print center
    x1 = w.all_world2pix(center[0],center[1],0)
    x1,y1 = (x1[0]),(x1[1])
    try:
        mask = ((y-y1)**2 + (x-x1)**2) > (apparature/float(pixspa))**2
        AGNdata[mask] = float(0)
        mask = AGNdata == 0.
        rows = np.flatnonzero((~mask).sum(axis=1))
        cols = np.flatnonzero((~mask).sum(axis=0))
        AGNdata = AGNdata[rows.min():rows.max()+1, cols.min():cols.max()+1]
        #print apparature/float(pixspa)
    except:
        AGNdata = np.array([[float('nan'),float('nan')],[float('nan'),float('nan')]])
    #if np.sum(AGNdata) < 500:
    #    AGNdata = np.array([[float('nan'),float('nan')],[float('nan'),float('nan')]])
    return AGNdata/float(exptime), x1, y1

# %%
def comp1(qua,sta):
    '''Code to determine the relation between the AGN and the Stellar flux as determined by either me \
    or by the SExtractor program respectively'''
    comp = qua/sta
    return comp

# %%
def SNR(data1,data2,header,ap1,ap2):
    npix1 = np.pi*ap1**2/((header['PIXSCALE']/3600.)**2)
    npix2 = np.pi*ap2**2/((header['PIXSCALE']/3600.)**2)
    #data2_1 = ((data2-data1)/npix2)*npix1
    data1_2 = data1/10.
    data2_2 = data2/10.
    return SNRas(10.,data1_2,abs(data2_2),0,header['RON'],npix1,gain=header['GAIN'])

# %%
def SXtable(quas,aperture):
    header = pyfits.getheader(quas)
    phot_app = aperture*3600/header['PIXSCALE']
    np.set_printoptions(threshold=np.inf)
    sew = sewpy.SEW(params=['XMODEL_WORLD', 'YMODEL_WORLD', 'X2MODEL_WORLD', 'Y2MODEL_WORLD', 
                            'XMODEL_IMAGE', 'YMODEL_IMAGE', 'FLUX_RADIUS(1)', 'FLUX_APER','ELLIPTICITY'],
                    config={"DETECT_THRESH":5, 'DETECT_MINAREA':20, 'DETECT_MAXAREA':30000, 
                            "PHOT_FLUXFRAC":"0.5", 'PHOT_APERTURES':2*phot_app, 
                            'PIXEL_SCALE':header['PIXSCALE']}
                    , sexpath='/usr/bin/sextractor')
    out = sew(quas)
    return out

# %%
def flux(quas,aperture,main_RA_WORLD,main_DEC_WORLD):
    header = pyfits.getheader(quas)
    RAmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,1)[0]
    DECmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,1)[1]
    output = float('nan')
    if 15 < RAmain < header['NAXIS1'] - 15 and 15 < DECmain < header['NAXIS2'] - 15: 
        out = SXtable(quas,aperture)
        #print out['table']['XMODEL_IMAGE']
        #print RAmain
        RAmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,0)[0]
        DECmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,0)[1]
        #print out['table']['XMODEL_IMAGE'], out['table']['YMODEL_IMAGE']
        #print RAmain, DECmain

        for j in range(len(out['table']['XMODEL_IMAGE'])):
            #output['time'][i] = header['MJD-OBS']
            if RAmain - 20. < out['table']['XMODEL_IMAGE'][j] <  RAmain + 20. and \
            DECmain - 20. < out['table']['YMODEL_IMAGE'][j] < DECmain + 20.:
                #print 'YES'
                output = out['table']['FLUX_APER'][j]
                break
    else:
        output = float('nan')
        #print 'Done'
    return output

# %%
def findmag(start,compare1,RA_star,DEC_star,RA_com,DEC_com,mag_com,AIR_EXTINCTION):
    print mag_com
    aperture1 = 0.001
    #201.5441,-8.8601
    com_flu = []
    com_AIRMASS = []
    com_EXPTIME = []
    star_flu = []
    star_AIRMASS = []
    star_EXPTIME = []
    for i in range(len(compare1)):
        print 'Frame nr. ', i, compare1[i]
        header = pyfits.getheader(compare1[i])
        a1 = flux(compare1[i],2*aperture1,RA_com,DEC_com)/float(header['EXPTIME'])
        print header['EXPTIME']
        if a1 > 0:
            #print a1
            com_flu.append(a1), com_AIRMASS.append(header['AIRMASS']*AIR_EXTINCTION), com_EXPTIME.append(header['EXPTIME'])
        else:
            print a1
            com_flu.append(float('nan')), com_AIRMASS.append(float('nan')), com_EXPTIME.append(header['EXPTIME'])
        #plt.figure(figsize=(3,3))
        #plt.imshow(a1,cmap='hot')
        #plt.colorbar()
    for i in range(len(start)):
        print 'Frame nr. ', i, start[i]
        header = pyfits.getheader(start[i])
        a1 = flux(start[i],2*aperture1,RA_star,DEC_star)/float(header['EXPTIME'])
        print header['EXPTIME']
        if a1 > 0:
            #print a1
            star_flu.append(a1), star_AIRMASS.append(header['AIRMASS']*AIR_EXTINCTION), star_EXPTIME.append(header['EXPTIME'])
        else:
            star_flu.append(float('nan')), star_AIRMASS.append(float('nan')), star_EXPTIME.append(header['EXPTIME'])
        #plt.figure(figsize=(3,3))
        #plt.imshow(a1,cmap='hot')
        #plt.colorbar()
    com_flu = np.array(com_flu)
    print com_flu
    com_AIRMASS = np.array(com_AIRMASS)
    com_EXPTIME = np.array(com_EXPTIME)
    star_flu = np.array(star_flu)
    print star_flu
    star_AIRMASS = np.array(star_AIRMASS)
    star_EXPTIME = np.array(star_EXPTIME)
    com_flu = com_flu#/com_EXPTIME
    star_flu = star_flu#/star_EXPTIME
    com_flux = np.nanmean(com_flu)
    com_AIRMASS_num = np.nanmean(com_AIRMASS)
    star_AIRMASS_num = np.nanmean(star_AIRMASS)
    print star_AIRMASS_num
    mag1 = (star_AIRMASS_num-com_AIRMASS_num) + mag_com - 2.5*np.log10(star_flu/com_flux)
    mag = mag1
    print (star_AIRMASS_num-com_AIRMASS_num)
    print mag_com, com_flux, np.average(com_flu)
    print mag
    return mag

# %%
com1_1 = findmag(QUASAR1_g,refsta1_g,sta1_RA_WORLD,sta1_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_g,k_g)
com2_1 = findmag(QUASAR1_g,refsta1_g,sta2_RA_WORLD,sta2_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_g,k_g)
com3_1 = findmag(QUASAR1_g,refsta1_g,sta3_RA_WORLD,sta3_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_g,k_g)

com1_2 = findmag(QUASAR2_g,refsta2_g,sta1_RA_WORLD,sta1_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_g,k_g)
com2_2 = findmag(QUASAR2_g,refsta2_g,sta2_RA_WORLD,sta2_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_g,k_g)
com3_2 = findmag(QUASAR2_g,refsta2_g,sta3_RA_WORLD,sta3_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_g,k_g)
# Out:
# 11.861
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh009.fits
# /home/lynge/anaconda2/lib/python2.7/site-packages/pyfits/hdu/image.py:515: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU.
#   warnings.warn(msg, VerifyWarning)
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / Reference system for celestial coordinates
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# No handlers could be found for logger "sewpy.sewpy"
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs038.fits
# 45.0
# [ 12069.8825  12064.99    12153.775   12060.9725  12063.475   12179.36
#   12196.285   12163.125 ]
# [ 8620.14888889  8759.22        9009.16444444]
# 0.61016
# 0.361088
# 11.861 12118.983125 12118.983125
# [ 12.59196653  12.57458987  12.54404217]
# 11.861
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs038.fits
# 45.0
# [ 12069.8825  12064.99    12153.775   12060.9725  12063.475   12179.36
#   12196.285   12163.125 ]
# [ 2734.09555556  2777.27333333  2850.66444444]
# 0.61016
# 0.361088
# 11.861 12118.983125 12118.983125
# [ 13.83871923  13.82170689  13.7933882 ]
# 11.861
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/g/IMG2017002URs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/g/IMG2017002URs038.fits
# 45.0
# [ 12069.8825  12064.99    12153.775   12060.9725  12063.475   12179.36
#   12196.285   12163.125 ]
# [ 2151.88644444  2145.19933333  2197.98133333]
# 0.61016
# 0.361088
# 11.861 12118.983125 12118.983125
# [ 14.09870508  14.10208432  14.07569345]
# 10.166
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs041.fits
# 45.0
# [ 60010.25   60478.225  60409.9    60549.05   60771.4    60890.5    60743.
#   60694.4  ]
# [ 13377.99555556  13597.88444444  13703.40888889]
# 0.163093333333
# -0.0355786666667
# 10.166 60568.340625 60568.340625
# [ 11.7700579   11.75235716  11.74396398]
# 10.166
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs041.fits
# 45.0
# [ 60010.25   60478.225  60409.9    60549.05   60771.4    60890.5    60743.
#   60694.4  ]
# [ 4712.65777778  4766.78444444  4802.14222222]
# 0.163093333333
# -0.0355786666667
# 10.166 60568.340625 60568.340625
# [ 12.90287076  12.89047174  12.88244798]
# 10.166
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/g/IMG2017146URs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/g/IMG2017146URs041.fits
# 45.0
# [ 60010.25   60478.225  60409.9    60549.05   60771.4    60890.5    60743.
#   60694.4  ]
# [ nan  nan  nan]
# nan
# nan
# 10.166 60568.340625 60568.340625
# [ nan  nan  nan]
# /home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:50: RuntimeWarning: Mean of empty slice

# %%
print 'g-filter'
print 'Star 1'
print com1_1,com1_2
print np.nanmean((com1_1,com1_2)), np.nanstd((com1_1,com1_2))

print 'Star 2'
print com2_1,com2_2
print np.nanmean((com2_1,com2_2)), np.nanstd((com2_1,com2_2))

print 'Star 3'
print com3_1,com3_2
print np.nanmean((com3_1,com3_2)), np.nanstd((com3_1,com3_2))
# Out:
# g-filter
# Star 1
# [ 12.59196653  12.57458987  12.54404217] [ 11.7700579   11.75235716  11.74396398]
# 12.1628296013 0.407683227605
# Star 2
# [ 13.83871923  13.82170689  13.7933882 ] [ 12.90287076  12.89047174  12.88244798]
# 13.3549341341 0.463230787306
# Star 3
# [ 14.09870508  14.10208432  14.07569345] [ nan  nan  nan]
# 14.0921609494 0.0117257171095

# %%
com1_1 = findmag(QUASAR1_r,refsta1_r,sta1_RA_WORLD,sta1_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_r,k_r)
com2_1 = findmag(QUASAR1_r,refsta1_r,sta2_RA_WORLD,sta2_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_r,k_r)
com3_1 = findmag(QUASAR1_r,refsta1_r,sta3_RA_WORLD,sta3_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_r,k_r)

com1_2 = findmag(QUASAR2_r,refsta2_r,sta1_RA_WORLD,sta1_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_r,k_r)
com2_2 = findmag(QUASAR2_r,refsta2_r,sta2_RA_WORLD,sta2_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_r,k_r)
com3_2 = findmag(QUASAR2_r,refsta2_r,sta3_RA_WORLD,sta3_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_r,k_r)
# Out:
# 11.562
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs038.fits
# 45.0
# [ 16609.2725  16608.215   16641.605   16582.98    16595.385   16684.83
#   16767.18    16696.21  ]
# [ 13437.54666667  13636.88444444  13844.97777778]
# 0.30508
# 0.180544
# 11.562 16648.2096875 16648.2096875
# [ 11.97516288  11.95917494  11.94273219]
# 11.562
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs038.fits
# 45.0
# [ 16609.2725  16608.215   16641.605   16582.98    16595.385   16684.83
#   16767.18    16696.21  ]
# [  9724.51777778   9800.48888889  10036.99555556]
# 0.30508
# 0.180544
# 11.562 16648.2096875 16648.2096875
# [ 12.32629266  12.31784349  12.29195351]
# 11.562
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/r/IMG2017002BRs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/r/IMG2017002BRs038.fits
# 45.0
# [ 16609.2725  16608.215   16641.605   16582.98    16595.385   16684.83
#   16767.18    16696.21  ]
# [ 5458.10222222  5459.00888889  5430.78888889]
# 0.30508
# 0.180544
# 11.562 16648.2096875 16648.2096875
# [ 12.95335868  12.95317834  12.95880554]
# 10.229
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs041.fits
# 45.0
# [ 61977.2    62260.25   62183.225  62449.6    62630.95   62713.7    62526.15
#   62658.   ]
# [ 18967.77777778  19203.78        19302.01777778]
# 0.0815466666667
# -0.0177893333333
# 10.229 62424.884375 62424.884375
# [ 11.5045639   11.49113823  11.48559825]
# 10.229
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs041.fits
# 45.0
# [ 61977.2    62260.25   62183.225  62449.6    62630.95   62713.7    62526.15
#   62658.   ]
# [ 15802.13555556  16020.85333333  16072.24888889]
# 0.0815466666667
# -0.0177893333333
# 10.229 62424.884375 62424.884375
# [ 11.70281558  11.68789092  11.68441341]
# 10.229
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/r/IMG2017146BRs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/r/IMG2017146BRs041.fits
# 45.0
# [ 61977.2    62260.25   62183.225  62449.6    62630.95   62713.7    62526.15
#   62658.   ]
# [ nan  nan  nan]
# nan
# nan
# 10.229 62424.884375 62424.884375
# [ nan  nan  nan]
# /home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:50: RuntimeWarning: Mean of empty slice

# %%
print 'r-filter'
print 'Star 1'
print com1_1,com1_2
print np.nanmean((com1_1,com1_2)), np.nanstd((com1_1,com1_2))

print 'Star 2'
print com2_1,com2_2
print np.nanmean((com2_1,com2_2)), np.nanstd((com2_1,com2_2))

print 'Star 3'
print com3_1,com3_2
print np.nanmean((com3_1,com3_2)), np.nanstd((com3_1,com3_2))
# Out:
# r-filter
# Star 1
# [ 11.97516288  11.95917494  11.94273219] [ 11.5045639   11.49113823  11.48559825]
# 11.7263950652 0.232884662004
# Star 2
# [ 12.32629266  12.31784349  12.29195351] [ 11.70281558  11.68789092  11.68441341]
# 12.0018682616 0.310384935435
# Star 3
# [ 12.95335868  12.95317834  12.95880554] [ nan  nan  nan]
# 12.955114187 0.00261121968898

# %%
com1_1 = findmag(QUASAR1_i,refsta1_i,sta1_RA_WORLD,sta1_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_i,k_i)
com2_1 = findmag(QUASAR1_i,refsta1_i,sta2_RA_WORLD,sta2_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_i,k_i)
com3_1 = findmag(QUASAR1_i,refsta1_i,sta3_RA_WORLD,sta3_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_i,k_i)

com1_2 = findmag(QUASAR2_i,refsta2_i,sta1_RA_WORLD,sta1_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_i,k_i)
com2_2 = findmag(QUASAR2_i,refsta2_i,sta2_RA_WORLD,sta2_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_i,k_i)
com3_2 = findmag(QUASAR2_i,refsta2_i,sta3_RA_WORLD,sta3_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_i,k_i)
# Out:
# 11.46
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs038.fits
# 45.0
# [ 10524.625   10535.645   10624.535   10566.7525  10587.315   10663.96
#   10688.335   10662.69  ]
# [ 9633.53777778  9814.50888889  9855.98666667]
# 0.07627
# 0.045136
# 11.46 10606.7321875 10606.7321875
# [ 11.6096255   11.58941858  11.58483974]
# 11.46
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs038.fits
# 45.0
# [ 10524.625   10535.645   10624.535   10566.7525  10587.315   10663.96
#   10688.335   10662.69  ]
# [ 19225.76888889  19286.99777778  19614.10666667]
# 0.07627
# 0.045136
# 11.46 10606.7321875 10606.7321875
# [ 10.85938071  10.85592843  10.83766868]
# 11.46
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/i/IMG2017002ULs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/i/IMG2017002ULs038.fits
# 45.0
# [ 10524.625   10535.645   10624.535   10566.7525  10587.315   10663.96
#   10688.335   10662.69  ]
# [ 4824.65333333  4814.04        4770.45333333]
# 0.07627
# 0.045136
# 11.46 10606.7321875 10606.7321875
# [ 12.36042472  12.36281577  12.37269088]
# 10.347
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs041.fits
# 45.0
# [ 32028.5    32066.325  32144.05   32258.925  32392.945  32426.64
#   32350.685  32393.6  ]
# [ 11778.28666667  11948.89555556  12004.79111111]
# 0.0203866666667
# -0.00444733333333
# 10.347 32257.70875 32257.70875
# [ 11.43643116  11.42081705  11.41574994]
# 10.347
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs041.fits
# 45.0
# [ 32028.5    32066.325  32144.05   32258.925  32392.945  32426.64
#   32350.685  32393.6  ]
# [ 26008.97777778  26446.51111111  26627.55555556]
# 0.0203866666667
# -0.00444733333333
# 10.347 32257.70875 32257.70875
# [ 10.57632825  10.55821549  10.55080821]
# 10.347
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/i/IMG2017146ULs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/i/IMG2017146ULs041.fits
# 45.0
# [ 32028.5    32066.325  32144.05   32258.925  32392.945  32426.64
#   32350.685  32393.6  ]
# [ nan  nan  nan]
# nan
# nan
# 10.347 32257.70875 32257.70875
# [ nan  nan  nan]
# /home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:50: RuntimeWarning: Mean of empty slice

# %%
print 'i-filter'
print 'Star 1'
print com1_1,com1_2
print np.nanmean((com1_1,com1_2)), np.nanstd((com1_1,com1_2))

print 'Star 2'
print com2_1,com2_2
print np.nanmean((com2_1,com2_2)), np.nanstd((com2_1,com2_2))

print 'Star 3'
print com3_1,com3_2
print np.nanmean((com3_1,com3_2)), np.nanstd((com3_1,com3_2))
# Out:
# i-filter
# Star 1
# [ 11.6096255   11.58941858  11.58483974] [ 11.43643116  11.42081705  11.41574994]
# 11.5094803257 0.0857136359097
# Star 2
# [ 10.85938071  10.85592843  10.83766868] [ 10.57632825  10.55821549  10.55080821]
# 10.7063882953 0.144959437204
# Star 3
# [ 12.36042472  12.36281577  12.37269088] [ nan  nan  nan]
# 12.3653104587 0.0053092516542

# %%
com1_1 = findmag(QUASAR1_z,refsta1_z,sta1_RA_WORLD,sta1_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_z,k_z)
com2_1 = findmag(QUASAR1_z,refsta1_z,sta2_RA_WORLD,sta2_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_z,k_z)
com3_1 = findmag(QUASAR1_z,refsta1_z,sta3_RA_WORLD,sta3_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_z,k_z)

com1_2 = findmag(QUASAR2_z,refsta2_z,sta1_RA_WORLD,sta1_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_z,k_z)
com2_2 = findmag(QUASAR2_z,refsta2_z,sta2_RA_WORLD,sta2_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_z,k_z)
com3_2 = findmag(QUASAR2_z,refsta2_z,sta3_RA_WORLD,sta3_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_z,k_z)
# Out:
# 11.43
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs038.fits
# 45.0
# [ 2136.35525  2109.8865   2115.71375  2110.02075  2086.294    2102.1185
#   2149.6695   2108.575  ]
# [ 1967.43844444  2020.65911111  1994.56377778]
# 0.038135
# 0.022568
# 11.43 2114.82915625 2114.82915625
# [ 11.53100334  11.50202359  11.5161364 ]
# 11.43
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs038.fits
# 45.0
# [ 2136.35525  2109.8865   2115.71375  2110.02075  2086.294    2102.1185
#   2149.6695   2108.575  ]
# [ 6675.30666667  6643.97333333  6699.59333333]
# 0.038135
# 0.022568
# 11.43 2114.82915625 2114.82915625
# [ 10.20457817  10.20968652  10.20063512]
# 11.43
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh009.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh010.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh013.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLh014.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs011.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs012.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs015.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/04-01-17-SA093_317/z/IMG2017002BLs016.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs036.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs037.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/04-01-17-ESO323/z/IMG2017002BLs038.fits
# 45.0
# [ 2136.35525  2109.8865   2115.71375  2110.02075  2086.294    2102.1185
#   2149.6695   2108.575  ]
# [ 1322.62355556  1322.88377778  1311.81044444]
# 0.038135
# 0.022568
# 11.43 2114.82915625 2114.82915625
# [ 11.96216559  11.961952    11.97107851]
# 10.456
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs041.fits
# 45.0
# [ 5873.8425  5906.485   5861.6025  5897.6575  5899.17    5916.97    5904.01
#   5928.705 ]
# [ 2484.70666667  2509.05333333  2514.14      ]
# 0.0101933333333
# -0.00222366666667
# 10.456 5898.5553125 5898.5553125
# [ 11.39245266  11.38186574  11.37966683]
# 10.456
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs041.fits
# 45.0
# [ 5873.8425  5906.485   5861.6025  5897.6575  5899.17    5916.97    5904.01
#   5928.705 ]
# [ 9492.49555556  9594.90222222  9624.76222222]
# 0.0101933333333
# -0.00222366666667
# 10.456 5898.5553125 5898.5553125
# [ 9.93718947  9.92553909  9.92216545]
# 10.456
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh001.fits
# 40.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh002.fits
# 40.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh005.fits
# 40.0
# Frame nr.  3 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLh006.fits
# 40.0
# Frame nr.  4 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs003.fits
# 20.0
# Frame nr.  5 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs004.fits
# 20.0
# Frame nr.  6 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs007.fits
# 20.0
# Frame nr.  7 /media/lynge/Lynge-Back-up/Calibration/28-05-17-SA100_241/z/IMG2017146BLs008.fits
# 20.0
# Frame nr.  0 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs039.fits
# 45.0
# Frame nr.  1 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs040.fits
# 45.0
# Frame nr.  2 /media/lynge/Lynge-Back-up/Calibration/28-05-17-ESO323/z/IMG2017146BLs041.fits
# 45.0
# [ 5873.8425  5906.485   5861.6025  5897.6575  5899.17    5916.97    5904.01
#   5928.705 ]
# [ nan  nan  nan]
# nan
# nan
# 10.456 5898.5553125 5898.5553125
# [ nan  nan  nan]
# /home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:50: RuntimeWarning: Mean of empty slice

# %%
print 'z-filter'
print 'Star 1'
print com1_1,com1_2
print np.nanmean((com1_1,com1_2)), np.nanstd((com1_1,com1_2))

print 'Star 2'
print com2_1,com2_2
print np.nanmean((com2_1,com2_2)), np.nanstd((com2_1,com2_2))

print 'Star 3'
print com3_1,com3_2
print np.nanmean((com3_1,com3_2)), np.nanstd((com3_1,com3_2))
# Out:
# z-filter
# Star 1
# [ 11.53100334  11.50202359  11.5161364 ] [ 11.39245266  11.38186574  11.37966683]
# 11.4505247608 0.0665095165307
# Star 2
# [ 10.20457817  10.20968652  10.20063512] [ 9.93718947  9.92553909  9.92216545]
# 10.0666323029 0.138433942722
# Star 3
# [ 11.96216559  11.961952    11.97107851] [ nan  nan  nan]
# 11.9650653661 0.00425283036814

# %%
HD101274_1 = findmag(NGC3783_r,P_r,sta1_RA_WORLD,sta1_DEC_WORLD,r_P_RA,r_P_DEC,P_mag_r,k_r)
Tyc_22_1 = findmag(NGC3783_r,P_r,sta2_RA_WORLD,sta2_DEC_WORLD,r_P_RA,r_P_DEC,P_mag_r,k_r)
Tyc_529_1 = findmag(NGC3783_r,P_r,sta3_RA_WORLD,sta3_DEC_WORLD,r_P_RA,r_P_DEC,P_mag_r,k_r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-07dbc6342341> in <module>()
# ----> 1 HD101274_1 = findmag(NGC3783_r,P_r,sta1_RA_WORLD,sta1_DEC_WORLD,r_P_RA,r_P_DEC,P_mag_r,k_r)
#       2 Tyc_22_1 = findmag(NGC3783_r,P_r,sta2_RA_WORLD,sta2_DEC_WORLD,r_P_RA,r_P_DEC,P_mag_r,k_r)
#       3 Tyc_529_1 = findmag(NGC3783_r,P_r,sta3_RA_WORLD,sta3_DEC_WORLD,r_P_RA,r_P_DEC,P_mag_r,k_r)
#       4
#       5
#
# NameError: name 'NGC3783_r' is not defined

# %%
print 'r-filter'
print HD101274_1
print np.mean(HD101274_1,), np.std(HD101274_1)

print Tyc_22_1
print np.mean(Tyc_22_1), np.std(Tyc_22_1)

print Tyc_529_1
print np.mean(Tyc_529_1), np.std(Tyc_529_1)

# %%
HD101274_1 = findmag(NGC3783_i,P_i,sta1_RA_WORLD,sta1_DEC_WORLD,i_P_RA,i_P_DEC,P_mag_i,k_i)
Tyc_22_1 = findmag(NGC3783_i,P_i,sta2_RA_WORLD,sta2_DEC_WORLD,i_P_RA,i_P_DEC,P_mag_i,k_i)
Tyc_529_1 = findmag(NGC3783_i,P_i,sta3_RA_WORLD,sta3_DEC_WORLD,i_P_RA,i_P_DEC,P_mag_i,k_i)

# %%
print 'i-filter'
print HD101274_1
print np.mean(HD101274_1,), np.std(HD101274_1)

print Tyc_22_1
print np.mean(Tyc_22_1), np.std(Tyc_22_1)

print Tyc_529_1
print np.mean(Tyc_529_1), np.std(Tyc_529_1)

# %%
sta2_RA_WORLD = 174.82083333
sta2_DEC_WORLD = -37.76194444

HD101274_1 = findmag(NGC3783_z,P_z,sta1_RA_WORLD,sta1_DEC_WORLD,z_P_RA,z_P_DEC,P_mag_z,k_z)
Tyc_22_1 = findmag(NGC3783_z,P_z,sta2_RA_WORLD,sta2_DEC_WORLD,z_P_RA,z_P_DEC,P_mag_z,k_z)
Tyc_529_1 = findmag(NGC3783_z,P_z,sta3_RA_WORLD,sta3_DEC_WORLD,z_P_RA,z_P_DEC,P_mag_z,k_z)

# %%
print 'z-filter'
print HD101274_1
print np.nanmean(HD101274_1,), np.nanstd(HD101274_1)

print Tyc_22_1
print np.nanmean(Tyc_22_1), np.nanstd(Tyc_22_1)

print Tyc_529_1
print np.nanmean(Tyc_529_1), np.nanstd(Tyc_529_1)
