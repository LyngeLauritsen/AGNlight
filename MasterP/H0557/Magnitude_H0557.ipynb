# %%
import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LogNorm
import scipy.stats as stats
from matplotlib import gridspec
import aplpy as apl #The Astronomy Plotting Library for python
import astropy
from astropy.stats import sigma_clip
from astropy.modeling import functional_models, models, fitting
import astropy.units as U
from astropy.coordinates import ICRS, Galactic, FK4, FK5, Angle, Latitude, Longitude
import astropy.constants as C
from astropy import wcs
import astropy.io.fits as fits
from astropy.io import ascii
import astropy.coordinates as coord
from astropy.coordinates import SkyCoord
from astropy.stats import signal_to_noise_oir_ccd as SNRas
#import spectral_cube as SC
#from spectral_cube import SpectralCube as sc
from astropy.wcs import WCS
matplotlib.use('Agg')
import matplotlib.cm as cm
#import astrometry as ast
import pyfits
import requests
import json
import os
from sklearn import datasets, linear_model
from scipy.optimize import curve_fit
import numpy.ma as ma
from astropy.table import Table, Column
import pyextract
import sewpy
import pandas as pd
from astropy import units as u
# Out:
# /home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:25: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/lynge/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/lynge/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-31-a1e4ca7cbff6>", line 5, in <module>
#     get_ipython().magic(u'matplotlib inline')
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2158, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2079, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-104>", line 2, in matplotlib
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2949, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/pylabtools.py", line 308, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()

# %%
sta1_RA_WORLD = SkyCoord('05:58:03.962 -38:19:15.51', unit=(u.hourangle, u.deg)).ra.degree #UCAC3 86-422902
sta1_DEC_WORLD = SkyCoord('05:58:03.962 -38:19:15.51', unit=(u.hourangle, u.deg)).dec.degree

sta2_RA_WORLD = SkyCoord('05:58:12.487 -38:19:31.86', unit=(u.hourangle, u.deg)).ra.degree #TYC 8438-1960-1
sta2_DEC_WORLD = SkyCoord('05:58:12.487 -38:19:31.86', unit=(u.hourangle, u.deg)).dec.degree

sta3_RA_WORLD = SkyCoord('05:58:11.342 -38:18:29.98', unit=(u.hourangle, u.deg)).ra.degree #TYC 8438-1960-1
sta3_DEC_WORLD = SkyCoord('05:58:11.342 -38:18:29.98', unit=(u.hourangle, u.deg)).dec.degree

sky_RA_WORLD = SkyCoord('05:58:05.5 -38:20:43.5', unit=(u.hourangle, u.deg)).ra.degree #Random patch of sky
sky_DEC_WORLD = SkyCoord('05:58:05.5 -38:20:43.5', unit=(u.hourangle, u.deg)).dec.degree


k_g = 0.16
k_r = 0.08
k_i = 0.02
k_z = 0.01

mag_refsta1_g = 13.291
mag_refsta1_r = 12.843
mag_refsta1_i = 12.668
mag_refsta1_z = float('nan') #12.593

mag_refsta2_g = 11.689
mag_refsta2_r = 11.491
mag_refsta2_i = 11.465
mag_refsta2_z = 11.500

mag_refsta3_g = 13.291
mag_refsta3_r = 12.843
mag_refsta3_i = 12.668
mag_refsta3_z = 12.593

refsta1_RA = SkyCoord('00:24:28 07:49:00', unit=(u.hourangle, u.deg)).ra.degree #P525_E_21_10_17
refsta1_DEC = SkyCoord('00:24:28 07:49:00', unit=(u.hourangle, u.deg)).dec.degree 

refsta2_RA = SkyCoord('00:55:09.9097 +00:43:12.906', unit=(u.hourangle, u.deg)).ra.degree #SA092_342_27_11_17
refsta2_DEC = SkyCoord('00:55:09.9097 +00:43:12.906', unit=(u.hourangle, u.deg)).dec.degree 

refsta3_RA = SkyCoord('00:24:28 07:49:00', unit=(u.hourangle, u.deg)).ra.degree #P525-E
refsta3_DEC = SkyCoord('00:24:28 07:49:00', unit=(u.hourangle, u.deg)).dec.degree

# %%
QUASAR1_g = [os.path.join('/media/lynge/LACIE/Calibration/10-11-17-H0557/g/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/10-11-17-H0557/g/')]

QUASAR2_g = [os.path.join('/media/lynge/LACIE/Calibration/21-11-17-H0557/g/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-11-17-H0557/g/')]

refsta1_g = [os.path.join('/media/lynge/LACIE/Calibration/10-11-17-P525-E/g/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/10-11-17-P525-E/g/')]

refsta2_g = [os.path.join('/media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/')]

QUASAR3_g = [os.path.join('/media/lynge/LACIE/Calibration/21-10-17-H0557/g/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-10-17-H0557/g/')]

refsta3_g = [os.path.join('/media/lynge/LACIE/Calibration/21-10-17-P525-E/g/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-10-17-P525-E/g/')]

# %%
QUASAR1_r = [os.path.join('/media/lynge/LACIE/Calibration/10-11-17-H0557/r/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/10-11-17-H0557/r/')]

QUASAR2_r = [os.path.join('/media/lynge/LACIE/Calibration/21-11-17-H0557/r/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-11-17-H0557/r/')]

refsta1_r = [os.path.join('/media/lynge/LACIE/Calibration/10-11-17-P525-E/r/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/10-11-17-P525-E/r/')]

refsta2_r = [os.path.join('/media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/')]

QUASAR3_r = [os.path.join('/media/lynge/LACIE/Calibration/21-10-17-H0557/r/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-10-17-H0557/r/')]

refsta3_r = [os.path.join('/media/lynge/LACIE/Calibration/21-10-17-P525-E/r/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-10-17-P525-E/r/')]

# %%
QUASAR1_i = [os.path.join('/media/lynge/LACIE/Calibration/10-11-17-H0557/i/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/10-11-17-H0557/i/')]

QUASAR2_i = [os.path.join('/media/lynge/LACIE/Calibration/21-11-17-H0557/i/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-11-17-H0557/i/')]

refsta1_i = [os.path.join('/media/lynge/LACIE/Calibration/10-11-17-P525-E/i/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/10-11-17-P525-E/i/')]

refsta2_i = [os.path.join('/media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/')]

QUASAR3_i = [os.path.join('/media/lynge/LACIE/Calibration/21-10-17-H0557/i/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-10-17-H0557/i/')]

refsta3_i = [os.path.join('/media/lynge/LACIE/Calibration/21-10-17-P525-E/i/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-10-17-P525-E/i/')]

# %%
QUASAR1_z = [os.path.join('/media/lynge/LACIE/Calibration/10-11-17-H0557/z/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/10-11-17-H0557/z/')]

QUASAR2_z = [os.path.join('/media/lynge/LACIE/Calibration/21-11-17-H0557/z/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-11-17-H0557/z/')]

refsta1_z = [os.path.join('/media/lynge/LACIE/Calibration/10-11-17-P525-E/z/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/10-11-17-P525-E/z/')]

refsta2_z = [os.path.join('/media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/')]

QUASAR3_z = [os.path.join('/media/lynge/LACIE/Calibration/21-10-17-H0557/z/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-10-17-H0557/z/')]

refsta3_z = [os.path.join('/media/lynge/LACIE/Calibration/21-10-17-P525-E/z/',f) \
        for f in os.listdir('/media/lynge/LACIE/Calibration/21-10-17-P525-E/z/')]

print QUASAR2_z
# Out:
# ['/media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs103.fits', '/media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs104.fits', '/media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs105.fits']

# %%
def dist(mid,end):
    return np.sqrt((mid[0] - end[0])**2 + (mid[1] - end[1])**2)

# %%
def flux_cal(A_mag,B_mag,B_flux):
    '''Flux of A found through magnitude and flux of B'''
    return B_flux*10**((B_mag-A_mag)/2.5)

# %%
def Basic(quasar,header):
    '''Provides a basic list of neccesities from the fits header file for use in the later \
    flux determination, it does not serve an individual purpose beyound that'''
    AGNdata = quasar #np.rot90(np.rot90(np.fliplr(quasar)))
    #header = data[0].header
    #print header
    RAstd = header['CRVAL1']
    DECstd = header['CRVAL2']
    #print RAstd, DECstd
    pixspa = header['PIXSCALE']/(3600.)
    #print pixspa
    RAstdpix = header['CRPIX1']
    DECstdpix = header['CRPIX2']
    exptime = 10 # header['EXPTIME']
    return header,AGNdata,RAstd,DECstd,pixspa,RAstdpix,DECstdpix,exptime

# %%
def curve(quasar,header,w,center,apparature):
    '''Determines the FLUX of the stellar object given the the numpy array of the image, \
    the header of the fits file, the astropy coordinate representation, \
    the object position and the apparature of interest'''
    header,AGNdata,RAstd,DECstd,pixspa,RAstdpix,DECstdpix,exptime = Basic(quasar,header)
    #AGNdata = np.swapaxes(AGNdata,0,1)
    y, x = np.ogrid[0:header['NAXIS1'],0:header['NAXIS1']]
    #w = np.swapaxes(w,0,1)
    #F_AGN = np.zeros((512,512,3)) #((int(2*apparature/pixspa)+1,int(2*apparature/pixspa)+1,3))
    #print center
    x1 = w.all_world2pix(center[0],center[1],0)
    x1,y1 = (x1[0]),(x1[1])
    try:
        mask = ((y-y1)**2 + (x-x1)**2) > (apparature/float(pixspa))**2
        AGNdata[mask] = float(0)
        mask = AGNdata == 0.
        rows = np.flatnonzero((~mask).sum(axis=1))
        cols = np.flatnonzero((~mask).sum(axis=0))
        AGNdata = AGNdata[rows.min():rows.max()+1, cols.min():cols.max()+1]
        #print apparature/float(pixspa)
    except:
        AGNdata = np.array([[float('nan'),float('nan')],[float('nan'),float('nan')]])
    #if np.sum(AGNdata) < 500:
    #    AGNdata = np.array([[float('nan'),float('nan')],[float('nan'),float('nan')]])
    return AGNdata/float(exptime), x1, y1

# %%
def comp1(qua,sta):
    '''Code to determine the relation between the AGN and the Stellar flux as determined by either me \
    or by the SExtractor program respectively'''
    comp = qua/sta
    return comp

# %%
def SNR(data1,data2,header,ap1,ap2):
    npix1 = np.pi*ap1**2/((header['PIXSCALE']/3600.)**2)
    npix2 = np.pi*ap2**2/((header['PIXSCALE']/3600.)**2)
    #data2_1 = ((data2-data1)/npix2)*npix1
    data1_2 = data1/10.
    data2_2 = data2/10.
    return SNRas(10.,data1_2,abs(data2_2),0,header['RON'],npix1,gain=header['GAIN'])

# %%
def SXtable(quas,aperture):
    header = pyfits.getheader(quas)
    phot_app = aperture*3600/header['PIXSCALE']
    np.set_printoptions(threshold=np.inf)
    sew = sewpy.SEW(params=['XMODEL_WORLD', 'YMODEL_WORLD', 'X2MODEL_WORLD', 'Y2MODEL_WORLD', 
                            'XMODEL_IMAGE', 'YMODEL_IMAGE', 'FLUX_RADIUS(1)', 'FLUX_APER','ELLIPTICITY'],
                    config={"DETECT_THRESH":5, 'DETECT_MINAREA':20, 'DETECT_MAXAREA':30000, 
                            "PHOT_FLUXFRAC":"0.5", 'PHOT_APERTURES':2*phot_app, 
                            'PIXEL_SCALE':header['PIXSCALE']}
                    , sexpath='/usr/bin/sextractor')
    out = sew(quas)
    return out

# %%
def flux(quas,aperture,main_RA_WORLD,main_DEC_WORLD):
    header = pyfits.getheader(quas)
    RAmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,1)[0]
    DECmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,1)[1]
    output = float('nan')
    if 15 < RAmain < header['NAXIS1'] - 15 and 15 < DECmain < header['NAXIS2'] - 15: 
        out = SXtable(quas,aperture)
        #print out['table']['XMODEL_IMAGE']
        #print RAmain
        RAmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,0)[0]
        DECmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,0)[1]
        #print out['table']['XMODEL_IMAGE'], out['table']['YMODEL_IMAGE']
        #print RAmain, DECmain

        for j in range(len(out['table']['XMODEL_IMAGE'])):
            #output['time'][i] = header['MJD-OBS']
            if RAmain - 20. < out['table']['XMODEL_IMAGE'][j] <  RAmain + 20. and \
            DECmain - 20. < out['table']['YMODEL_IMAGE'][j] < DECmain + 20.:
                #print 'YES'
                output = out['table']['FLUX_APER'][j]
                break
    else:
        output = float('nan')
        #print 'Done'
    return output

# %%
def findmag(start,compare1,RA_star,DEC_star,RA_com,DEC_com,mag_com,AIR_EXTINCTION):
    print mag_com
    aperture1 = 0.0012
    #201.5441,-8.8601
    com_flu = []
    com_AIRMASS = []
    com_EXPTIME = []
    star_flu = []
    star_AIRMASS = []
    star_EXPTIME = []
    for i in range(len(compare1)):
        print 'Frame nr. ', i, compare1[i]
        header = pyfits.getheader(compare1[i])
        a1 = flux(compare1[i],2*aperture1,RA_com,DEC_com)/float(header['EXPTIME'])
        print header['EXPTIME']
        if a1 > 0:
            #print a1
            com_flu.append(a1), com_AIRMASS.append(header['AIRMASS']*AIR_EXTINCTION), com_EXPTIME.append(header['EXPTIME'])
        else:
            print a1
            com_flu.append(float('nan')), com_AIRMASS.append(float('nan')), com_EXPTIME.append(header['EXPTIME'])
        #plt.figure(figsize=(3,3))
        #plt.imshow(a1,cmap='hot')
        #plt.colorbar()
    for i in range(len(start)):
        print 'Frame nr. ', i, start[i]
        header = pyfits.getheader(start[i])
        a1 = flux(start[i],2*aperture1,RA_star,DEC_star)/float(header['EXPTIME'])
        print header['EXPTIME']
        if a1 > 0:
            #print a1
            star_flu.append(a1), star_AIRMASS.append(header['AIRMASS']*AIR_EXTINCTION), star_EXPTIME.append(header['EXPTIME'])
        else:
            star_flu.append(float('nan')), star_AIRMASS.append(float('nan')), star_EXPTIME.append(header['EXPTIME'])
        #plt.figure(figsize=(3,3))
        #plt.imshow(a1,cmap='hot')
        #plt.colorbar()
    com_flu = np.array(com_flu)
    print com_flu
    com_AIRMASS = np.array(com_AIRMASS)
    com_EXPTIME = np.array(com_EXPTIME)
    star_flu = np.array(star_flu)
    print star_flu
    star_AIRMASS = np.array(star_AIRMASS)
    star_EXPTIME = np.array(star_EXPTIME)
    com_flu = com_flu#/com_EXPTIME
    star_flu = star_flu#/star_EXPTIME
    com_flux = np.nanmean(com_flu)
    com_AIRMASS_num = np.nanmean(com_AIRMASS)
    star_AIRMASS_num = np.nanmean(star_AIRMASS)
    print star_AIRMASS_num
    mag1 = (star_AIRMASS_num-com_AIRMASS_num) + mag_com - 2.5*np.log10(star_flu/com_flux)
    mag = mag1
    print (star_AIRMASS_num-com_AIRMASS_num)
    print mag_com, com_flux, np.average(com_flu)
    print mag
    return mag

# %%
com1_1 = findmag(QUASAR1_g,refsta1_g,sta1_RA_WORLD,sta1_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_g,k_g)
com2_1 = findmag(QUASAR1_g,refsta1_g,sta2_RA_WORLD,sta2_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_g,k_g)
com3_1 = findmag(QUASAR1_g,refsta1_g,sta3_RA_WORLD,sta3_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_g,k_g)

com1_2 = findmag(QUASAR2_g,refsta2_g,sta1_RA_WORLD,sta1_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_g,k_g)
com2_2 = findmag(QUASAR2_g,refsta2_g,sta2_RA_WORLD,sta2_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_g,k_g)
com3_2 = findmag(QUASAR2_g,refsta2_g,sta3_RA_WORLD,sta3_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_g,k_g)

com1_3 = findmag(QUASAR3_g,refsta3_g,sta1_RA_WORLD,sta1_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_g,k_g)
com2_3 = findmag(QUASAR3_g,refsta3_g,sta2_RA_WORLD,sta2_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_g,k_g)
com3_3 = findmag(QUASAR3_g,refsta3_g,sta3_RA_WORLD,sta3_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_g,k_g)
# Out:
# 13.291
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs108.fits
# 60.0
# [3550.885  3565.245  3554.38   3575.8225 3615.245        nan       nan
#        nan]
# [697.04366667 691.45516667 649.9655    ]
# 0.17016533333333336
# -0.04029866666666662
# 13.291 3572.3154999999997 nan
# [15.02492589 15.03366579 15.10085009]
# 13.291
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs108.fits
# 60.0
# [3550.885  3565.245  3554.38   3575.8225 3615.245        nan       nan
#        nan]
# [3301.915      3251.855      3266.20333333]
# 0.17016533333333336
# -0.04029866666666662
# 13.291 3572.3154999999997 nan
# [13.33616113 13.35274792 13.34796781]
# 13.291
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/g/IMG2017312URs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/g/IMG2017312URs108.fits
# 60.0
# [3550.885  3565.245  3554.38   3575.8225 3615.245        nan       nan
#        nan]
# [2972.405      2980.97       2935.95333333]
# 0.17016533333333336
# -0.04029866666666662
# 13.291 3572.3154999999997 nan
# [13.4503059  13.44718184 13.46370298]
# 11.689
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs105.fits
# 60.0
# [12177.66   12206.2425 12254.0275 12304.7775 12277.065  12316.03
#  12369.965  12354.04  ]
# [703.16566667 705.41933333 705.14333333]
# 0.1620533333333333
# -0.0340746666666667
# 11.689 12282.4759375 12282.4759375
# [14.76049599 14.75702174 14.75744663]
# 11.689
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs105.fits
# 60.0
# [12177.66   12206.2425 12254.0275 12304.7775 12277.065  12316.03
#  12369.965  12354.04  ]
# [3296.15833333 3308.38       3322.17166667]
# 0.1620533333333333
# -0.0340746666666667
# 11.689 12282.4759375 12282.4759375
# [13.08311998 13.07910167 13.07458496]
# 11.689
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/g/IMG2017323URs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/g/IMG2017323URs105.fits
# 60.0
# [12177.66   12206.2425 12254.0275 12304.7775 12277.065  12316.03
#  12369.965  12354.04  ]
# [2944.16166667 2976.975      2969.47666667]
# 0.1620533333333333
# -0.0340746666666667
# 11.689 12282.4759375 12282.4759375
# [13.205736   13.19370217 13.19644035]
# 13.291
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URh017.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URh018.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URh021.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URh022.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URs019.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URs020.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URs023.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URs024.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/g/IMG2017292URs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/g/IMG2017292URs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/g/IMG2017292URs138.fits
# 60.0
# [3374.855  3419.0225 3489.6725 3474.86   3443.624  3454.0855 3457.865
#  3451.576 ]
# [758.252      747.85366667 741.546     ]
# 0.16205866666666666
# -0.10942933333333335
# 13.291 3445.6950625 3445.6950625
# [14.82522886 14.8402212  14.84941753]
# 13.291
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URh017.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URh018.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
# ...
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URs020.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URs023.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/g/IMG2017292URs024.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/g/IMG2017292URs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/g/IMG2017292URs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/g/IMG2017292URs138.fits
# 60.0
# [3374.855  3419.0225 3489.6725 3474.86   3443.624  3454.0855 3457.865
#  3451.576 ]
# [3133.91333333 3151.25666667 3106.52      ]
# 0.16205866666666666
# -0.10942933333333335
# 13.291 3445.6950625 3445.6950625
# [13.28454531 13.27855332 13.29407738]

# %%
print 'g-filter'
print 'Star 1'
print com1_1,com1_2,com1_3
print np.nanmean((com1_1,com1_2,com1_3)), np.nanstd((com1_1,com1_2,com1_3))

print 'Star 2'
print com2_1,com2_2,com2_3
print np.nanmean((com2_1,com2_2,com2_3)), np.nanstd((com2_1,com2_2,com2_3))

print 'Star 3'
print com3_1,com3_2
print np.nanmean((com3_1,com3_2,com3_3)), np.nanstd((com3_1,com3_2,com3_3))
# Out:
# g-filter
# Star 1
# [15.02492589 15.03366579 15.10085009] [14.76049599 14.75702174 14.75744663] [14.82522886 14.8402212  14.84941753]
# 14.883252635184656 0.12615596186917877
# Star 2
# [13.33616113 13.35274792 13.34796781] [13.08311998 13.07910167 13.07458496] [13.17559293 13.17608974 13.19083357]
# 13.201799967935832 0.1100478690513679
# Star 3
# [13.4503059  13.44718184 13.46370298] [13.205736   13.19370217 13.19644035]
# 13.312693917429733 0.10606403685103805

# %%
com1_1 = findmag(QUASAR1_r,refsta1_r,sta1_RA_WORLD,sta1_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_r,k_r)
com2_1 = findmag(QUASAR1_r,refsta1_r,sta2_RA_WORLD,sta2_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_r,k_r)
com3_1 = findmag(QUASAR1_r,refsta1_r,sta3_RA_WORLD,sta3_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_r,k_r)

com1_2 = findmag(QUASAR2_r,refsta2_r,sta1_RA_WORLD,sta1_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_r,k_r)
com2_2 = findmag(QUASAR2_r,refsta2_r,sta2_RA_WORLD,sta2_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_r,k_r)
com3_2 = findmag(QUASAR2_r,refsta2_r,sta3_RA_WORLD,sta3_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_r,k_r)

com1_3 = findmag(QUASAR3_r,refsta3_r,sta1_RA_WORLD,sta1_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_r,k_r)
com2_3 = findmag(QUASAR3_r,refsta3_r,sta2_RA_WORLD,sta2_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_r,k_r)
com3_3 = findmag(QUASAR3_r,refsta3_r,sta3_RA_WORLD,sta3_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_r,k_r)
# Out:
# 12.843
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs108.fits
# 60.0
# [5809.7975 5841.42   5810.205  5836.64   5861.835  5816.01   5889.44
#  5844.805 ]
# [1256.405      1259.30883333 1264.58916667]
# 0.08508266666666668
# -0.02014933333333331
# 12.843 5838.7690625000005 5838.7690625000005
# [14.49082977 14.48832329 14.48378027]
# 12.843
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs108.fits
# 60.0
# [5809.7975 5841.42   5810.205  5836.64   5861.835  5816.01   5889.44
#  5844.805 ]
# [5179.33666667 5169.22166667 5195.43      ]
# 0.08508266666666668
# -0.02014933333333331
# 12.843 5838.7690625000005 5838.7690625000005
# [12.95296856 12.95509102 12.94960017]
# 12.843
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/r/IMG2017312BRs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/r/IMG2017312BRs108.fits
# 60.0
# [5809.7975 5841.42   5810.205  5836.64   5861.835  5816.01   5889.44
#  5844.805 ]
# [4423.11833333 4424.14833333 4406.60666667]
# 0.08508266666666668
# -0.02014933333333331
# 12.843 5838.7690625000005 5838.7690625000005
# [13.12433252 13.12407971 13.12839319]
# 11.491
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs105.fits
# 60.0
# [16592.14   16605.065  16689.05   16658.4725 16771.64   16795.03
#  16810.9    16750.915 ]
# [1228.99816667 1228.723      1226.36716667]
# 0.08102666666666665
# -0.01703733333333335
# 11.491 16709.151562500003 16709.151562500003
# [14.30747057 14.30771369 14.30979738]
# 11.491
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs105.fits
# 60.0
# [16592.14   16605.065  16689.05   16658.4725 16771.64   16795.03
#  16810.9    16750.915 ]
# [5156.38       5153.20166667 5184.50166667]
# 0.08102666666666665
# -0.01703733333333335
# 11.491 16709.151562500003 16709.151562500003
# [12.75048637 12.75115582 12.74458112]
# 11.491
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/r/IMG2017323BRs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/r/IMG2017323BRs105.fits
# 60.0
# [16592.14   16605.065  16689.05   16658.4725 16771.64   16795.03
#  16810.9    16750.915 ]
# [4350.31333333 4359.47166667 4365.195     ]
# 0.08102666666666665
# -0.01703733333333335
# 11.491 16709.151562500003 16709.151562500003
# [12.93504732 12.93276401 12.93133954]
# 12.843
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs138.fits
# 60.0
# [5714.7525 5743.545  5807.5925 5819.9225 5783.305  5811.535  5761.835
#  5815.715 ]
# [1275.317      1258.33233333 1283.0455    ]
# 0.08102933333333333
# -0.054714666666666675
# 12.843 5782.2753125 5782.2753125
# [14.42948688 14.44404386 14.4229271 ]
# 12.843
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs138.fits
# 60.0
# [5714.7525 5743.545  5807.5925 5819.9225 5783.305  5811.535  5761.835
#  5815.715 ]
# [5254.77666667 5246.25333333 5240.74833333]
# 0.08102933333333333
# -0.054714666666666675
# 12.843 5782.2753125 5782.2753125
# [12.89214659 12.8939091  12.89504899]
# 12.843
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/r/IMG2017292BRs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/r/IMG2017292BRs138.fits
# 60.0
# [5714.7525 5743.545  5807.5925 5819.9225 5783.305  5811.535  5761.835
#  5815.715 ]
# [4531.50666667 4498.64833333 4490.57      ]
# 0.08102933333333333
# -0.054714666666666675
# 12.843 5782.2753125 5782.2753125
# [13.05292569 13.06082714 13.06277857]

# %%
print 'r-filter'
print 'Star 1'
print com1_1,com1_2,com1_3
print np.nanmean((com1_1,com1_2,com1_3)), np.nanstd((com1_1,com1_2,com1_3))

print 'Star 2'
print com2_1,com2_2,com2_3
print np.nanmean((com2_1,com2_2,com2_3)), np.nanstd((com2_1,com2_2,com2_3))

print 'Star 3'
print com3_1,com3_2
print np.nanmean((com3_1,com3_2,com3_3)), np.nanstd((com3_1,com3_2,com3_3))
# Out:
# r-filter
# Star 1
# [14.49082977 14.48832329 14.48378027] [14.30747057 14.30771369 14.30979738] [14.42948688 14.44404386 14.4229271 ]
# 14.409374756801416 0.07515108437481245
# Star 2
# [12.95296856 12.95509102 12.94960017] [12.75048637 12.75115582 12.74458112] [12.89214659 12.8939091  12.89504899]
# 12.864998637162596 0.0856752518795895
# Star 3
# [13.12433252 13.12407971 13.12839319] [12.93504732 12.93276401 12.93133954]
# 13.039165299079924 0.07988177520798305

# %%
com1_1 = findmag(QUASAR1_i,refsta1_i,sta1_RA_WORLD,sta1_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_i,k_i)
com2_1 = findmag(QUASAR1_i,refsta1_i,sta2_RA_WORLD,sta2_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_i,k_i)
com3_1 = findmag(QUASAR1_i,refsta1_i,sta3_RA_WORLD,sta3_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_i,k_i)

com1_2 = findmag(QUASAR2_i,refsta2_i,sta1_RA_WORLD,sta1_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_i,k_i)
com2_2 = findmag(QUASAR2_i,refsta2_i,sta2_RA_WORLD,sta2_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_i,k_i)
com3_2 = findmag(QUASAR2_i,refsta2_i,sta3_RA_WORLD,sta3_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_i,k_i)

com1_3 = findmag(QUASAR3_i,refsta3_i,sta1_RA_WORLD,sta1_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_i,k_i)
com2_3 = findmag(QUASAR3_i,refsta3_i,sta2_RA_WORLD,sta2_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_i,k_i)
com3_3 = findmag(QUASAR3_i,refsta3_i,sta3_RA_WORLD,sta3_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_i,k_i)
# Out:
# 12.668
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs108.fits
# 60.0
# [3852.335  3893.1425 3880.67   3882.755  3933.668  3964.3955 3919.412
#  3900.082 ]
# [845.06816667 873.447      823.02433333]
# 0.02127066666666667
# -0.005037333333333328
# 12.668 3903.3075 3903.3075
# [14.32431523 14.28845319 14.35301289]
# 12.668
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs108.fits
# 60.0
# [3852.335  3893.1425 3880.67   3882.755  3933.668  3964.3955 3919.412
#  3900.082 ]
# [2780.89333333 2772.73333333 2713.35666667]
# 0.02127066666666667
# -0.005037333333333328
# 12.668 3903.3075 3903.3075
# [13.03108375 13.03427432 13.05777737]
# 12.668
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/i/IMG2017312ULs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/i/IMG2017312ULs108.fits
# 60.0
# [3852.335  3893.1425 3880.67   3882.755  3933.668  3964.3955 3919.412
#  3900.082 ]
# [2445.98333333 2453.81833333 2454.4       ]
# 0.02127066666666667
# -0.005037333333333328
# 12.668 3903.3075 3903.3075
# [13.17041085 13.16693856 13.16668123]
# 11.465
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs105.fits
# 60.0
# [10295.1725 10315.465  10343.815  10338.275  10372.22   10401.21
#  10370.83   10339.425 ]
# [886.99866667 871.79266667 856.61466667]
# 0.020256666666666662
# -0.004259333333333337
# 11.465 10347.051562499999 10347.051562499999
# [14.12797478 14.14674917 14.16581844]
# 11.465
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs105.fits
# 60.0
# [10295.1725 10315.465  10343.815  10338.275  10372.22   10401.21
#  10370.83   10339.425 ]
# [3350.01833333 3353.47666667 3401.985     ]
# 0.020256666666666662
# -0.004259333333333337
# 11.465 10347.051562499999 10347.051562499999
# [12.68516424 12.68404398 12.66845121]
# 11.465
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/i/IMG2017323ULs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/i/IMG2017323ULs105.fits
# 60.0
# [10295.1725 10315.465  10343.815  10338.275  10372.22   10401.21
#  10370.83   10339.425 ]
# [2760.74166667 2755.09666667 2762.885     ]
# 0.020256666666666662
# -0.004259333333333337
# 11.465 10347.051562499999 10347.051562499999
# [12.89521778 12.8974401  12.89437518]
# 12.668
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs138.fits
# 60.0
# [3785.3025 3812.1425 3784.8275 3810.115  3853.2815 3832.0705 3802.227
#  3853.845 ]
# [890.794      871.37883333 875.40533333]
# 0.020257333333333332
# -0.013678666666666669
# 12.668 3816.7264375000004 3816.7264375000004
# [14.23410571 14.2580314  14.25302595]
# 12.668
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs138.fits
# 60.0
# [3785.3025 3812.1425 3784.8275 3810.115  3853.2815 3832.0705 3802.227
#  3853.845 ]
# [3430.01833333 3436.49333333 3412.42833333]
# 0.020257333333333332
# -0.013678666666666669
# 12.668 3816.7264375000004 3816.7264375000004
# [12.77030781 12.76826015 12.77589007]
# 12.668
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh017.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh018.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs020.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs023.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/i/IMG2017292ULs024.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/i/IMG2017292ULs138.fits
# 60.0
# [3785.3025 3812.1425 3784.8275 3810.115  3853.2815 3832.0705 3802.227
#  3853.845 ]
# [2604.30666667 2613.64333333 2573.33833333]
# 0.020257333333333332
# -0.013678666666666669
# 12.668 3816.7264375000004 3816.7264375000004
# [13.06931861 13.06543311 13.08230669]

# %%
print 'i-filter'
print 'Star 1'
print com1_1,com1_2,com1_3
print np.nanmean((com1_1,com1_2,com1_3)), np.nanstd((com1_1,com1_2,com1_3))

print 'Star 2'
print com2_1,com2_2,com2_3
print np.nanmean((com2_1,com2_2,com2_3)), np.nanstd((com2_1,com2_2,com2_3))

print 'Star 3'
print com3_1,com3_2
print np.nanmean((com3_1,com3_2,com3_3)), np.nanstd((com3_1,com3_2,com3_3))
# Out:
# i-filter
# Star 1
# [14.32431523 14.28845319 14.35301289] [14.12797478 14.14674917 14.16581844] [14.23410571 14.2580314  14.25302595]
# 14.239054083342356 0.0741608239078279
# Star 2
# [13.03108375 13.03427432 13.05777737] [12.68516424 12.68404398 12.66845121] [12.77030781 12.76826015 12.77589007]
# 12.83058365693545 0.153739880719112
# Star 3
# [13.17041085 13.16693856 13.16668123] [12.89521778 12.8974401  12.89437518]
# 13.045346900287608 0.11289095280730549

# %%
com1_1 = findmag(QUASAR1_z,refsta1_z,sta1_RA_WORLD,sta1_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_z,k_z)
com2_1 = findmag(QUASAR1_z,refsta1_z,sta2_RA_WORLD,sta2_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_z,k_z)
com3_1 = findmag(QUASAR1_z,refsta1_z,sta3_RA_WORLD,sta3_DEC_WORLD,refsta1_RA,refsta1_DEC,mag_refsta1_z,k_z)

com1_2 = findmag(QUASAR2_z,refsta2_z,sta1_RA_WORLD,sta1_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_z,k_z)
com2_2 = findmag(QUASAR2_z,refsta2_z,sta2_RA_WORLD,sta2_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_z,k_z)
com3_2 = findmag(QUASAR2_z,refsta2_z,sta3_RA_WORLD,sta3_DEC_WORLD,refsta2_RA,refsta2_DEC,mag_refsta2_z,k_z)

com1_3 = findmag(QUASAR3_z,refsta3_z,sta1_RA_WORLD,sta1_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_z,k_z)
com2_3 = findmag(QUASAR3_z,refsta3_z,sta2_RA_WORLD,sta2_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_z,k_z)
com3_3 = findmag(QUASAR3_z,refsta3_z,sta3_RA_WORLD,sta3_DEC_WORLD,refsta3_RA,refsta3_DEC,mag_refsta3_z,k_z)
# Out:
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh017.fits
# 40.0
# nan
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh018.fits
# 40.0
# nan
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh021.fits
# 40.0
# nan
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh022.fits
# 40.0
# nan
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs108.fits
# 60.0
# [      nan       nan       nan       nan 203.87625       nan       nan
#        nan]
# [186.7025     191.34016667 175.853     ]
# 0.010635333333333335
# -0.002518666666666664
# nan 203.87625 nan
# [nan nan nan]
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh017.fits
# 40.0
# nan
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh018.fits
# 40.0
# nan
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh021.fits
# 40.0
# nan
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh022.fits
# 40.0
# nan
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs108.fits
# 60.0
# [      nan       nan       nan       nan 203.87625       nan       nan
#        nan]
# [655.1595     636.9215     639.03116667]
# 0.010635333333333335
# -0.002518666666666664
# nan 203.87625 nan
# [nan nan nan]
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh017.fits
# 40.0
# nan
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh018.fits
# 40.0
# nan
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh021.fits
# 40.0
# nan
# Frame nr.  3 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLh022.fits
# 40.0
# nan
# Frame nr.  4 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs019.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/10-11-17-P525-E/z/IMG2017312BLs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs106.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs107.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/10-11-17-H0557/z/IMG2017312BLs108.fits
# 60.0
# [      nan       nan       nan       nan 203.87625       nan       nan
#        nan]
# [528.0385     533.3975     535.16066667]
# 0.010635333333333335
# -0.002518666666666664
# nan 203.87625 nan
# [nan nan nan]
# 11.5
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs105.fits
# 60.0
# [2088.79375 2070.94675 2044.945   2041.36125 2054.606   2086.4575
#  2089.6615  2081.712  ]
# [212.86566667 211.382      218.0285    ]
# 0.010128333333333331
# -0.0021296666666666686
# 11.5 2069.81046875 2069.81046875
# [13.96743273 13.97502677 13.94141361]
# 11.5
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs105.fits
# 60.0
# [2088.79375 2070.94675 2044.945   2041.36125 2054.606   2086.4575
#  2089.6615  2081.712  ]
# [770.046      763.95766667 753.385     ]
# 0.010128333333333331
# -0.0021296666666666686
# 11.5 2069.81046875 2069.81046875
# [12.57140511 12.58002355 12.59515436]
# 11.5
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh001.fits
# 40.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh002.fits
# 40.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh005.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLh006.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs003.fits
# 20.0
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs004.fits
# 20.0
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs007.fits
# 20.0
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-11-17-SA092_342/z/IMG2017323BLs008.fits
# 20.0
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs103.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs104.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-11-17-H0557/z/IMG2017323BLs105.fits
# 60.0
# [2088.79375 2070.94675 2044.945   2041.36125 2054.606   2086.4575
#  2089.6615  2081.712  ]
# [639.13033333 621.847      626.74933333]
# 0.010128333333333331
# -0.0021296666666666686
# 11.5 2069.81046875 2069.81046875
# [12.77372321 12.80348792 12.79496208]
# 12.593
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh017.fits
# 40.0
# nan
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh018.fits
# 40.0
# nan
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs019.fits
# 20.0
# nan
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs138.fits
# 60.0
# [      nan       nan 901.07725 896.57675       nan       nan       nan
#        nan]
# [181.77333333 182.173      197.09566667]
# 0.010128666666666666
# -0.006839333333333334
# 12.593 898.827 nan
# [14.32152551 14.31914092 14.23365825]
# 12.593
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh017.fits
# 40.0
# nan
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh018.fits
# 40.0
# nan
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs019.fits
# 20.0
# nan
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs138.fits
# 60.0
# [      nan       nan 901.07725 896.57675       nan       nan       nan
#        nan]
# [760.21116667 751.966      745.77133333]
# 0.010128666666666666
# -0.006839333333333334
# 12.593 898.827 nan
# [12.76801533 12.77985543 12.78883673]
# 12.593
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh017.fits
# 40.0
# nan
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh018.fits
# 40.0
# nan
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh021.fits
# 40.0
# Frame nr.  3 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLh022.fits
# 40.0
# Frame nr.  4 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs019.fits
# 20.0
# nan
# Frame nr.  5 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs020.fits
# 20.0
# nan
# Frame nr.  6 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs023.fits
# 20.0
# nan
# Frame nr.  7 /media/lynge/LACIE/Calibration/21-10-17-P525-E/z/IMG2017292BLs024.fits
# 20.0
# nan
# Frame nr.  0 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs139.fits
# 60.0
# Frame nr.  1 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs140.fits
# 60.0
# Frame nr.  2 /media/lynge/LACIE/Calibration/21-10-17-H0557/z/IMG2017292BLs138.fits
# 60.0
# [      nan       nan 901.07725 896.57675       nan       nan       nan
#        nan]
# [613.11966667 600.08483333 588.24483333]
# 0.010128666666666666
# -0.006839333333333334
# 12.593 898.827 nan
# [13.00148782 13.02481931 13.04645564]

# %%
print 'z-filter'
print 'Star 1'
print com1_1,com1_2,com1_3
print np.nanmean((com1_1,com1_2,com1_3)), np.nanstd((com1_1,com1_2,com1_3))

print 'Star 2'
print com2_1,com2_2,com2_3
print np.nanmean((com2_1,com2_2,com2_3)), np.nanstd((com2_1,com2_2,com2_3))

print 'Star 3'
print com3_1,com3_2,com3_2
print np.nanmean((com3_1,com3_2,com3_3)), np.nanstd((com3_1,com3_2,com3_3))
# Out:
# z-filter
# Star 1
# [nan nan nan] [13.96743273 13.97502677 13.94141361] [14.32152551 14.31914092 14.23365825]
# 14.126366300194505 0.16789468926488083
# Star 2
# [nan nan nan] [12.57140511 12.58002355 12.59515436] [12.76801533 12.77985543 12.78883673]
# 12.680548416817901 0.09878289176830149
# Star 3
# [nan nan nan] [12.77372321 12.80348792 12.79496208] [12.77372321 12.80348792 12.79496208]
# 12.907489330922436 0.11781746289564006
