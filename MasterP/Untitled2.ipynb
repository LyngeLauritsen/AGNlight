# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_i = np.loadtxt('NOVEMBER/NOV-NGC3783-i_short')

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_i[:,0],data_i[:,1])
plt.ylim([1e-15,2e-14])
plt.show()
