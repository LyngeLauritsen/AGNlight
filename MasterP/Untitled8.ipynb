# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn

# %%
K_width = 390#*10**(-9)  #Width of K band in m
H_width = 307#*10**(-9)  #Width of H band in m
J_width = 213#*10**(-9)  #Width of J band in m
g_width = 99.6#*10**(-9)  #Width of g band in m
r_width = 95.7#*10**(-9)  #Width of r band in m
i_width = 105.6#*10**(-9)  #Width of i band in m
z_width = 122.7#*10**(-9)  #Width of z band in m

K_cen = 21603#*10**(-9)   #Center of K band in m
H_cen = 16458#*10**(-9)   #Center of H band in m
J_cen = 12355#*10**(-9)   #Center of J band in m
g_cen = 4670#*10**(-9)   #Center of g band in m
r_cen = 6156#*10**(-9)   #Center of r band in m
i_cen = 7472#*10**(-9)   #Center of i band in m
z_cen = 8917#*10**(-9)   #Center of z band in m

# %%
data_K = np.loadtxt('NOVEMBER/NOV-NGC3783-K') #'NOVEMBER/Kelly-NGC3783K')
error_K = np.loadtxt('NOVEMBER/NGC3783_NOISE_K.txt') #Load data

data_H = np.loadtxt('NOVEMBER/NOV-NGC3783-H') #'NOVEMBER/Kelly-NGC3783K')
error_H = np.loadtxt('NOVEMBER/NGC3783_NOISE_H.txt') #Load data

data_J = np.loadtxt('NOVEMBER/NOV-NGC3783-J') #'NOVEMBER/Kelly-NGC3783K')
error_J = np.loadtxt('NOVEMBER/NGC3783_NOISE_J.txt') #Load data

data_Ks8 = np.loadtxt('NOVEMBER/NOV-NGC3783-Ks8') #'NOVEMBER/Kelly-NGC3783K')
error_Ks8 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Ks8.txt') #Load data

data_Hs8 = np.loadtxt('NOVEMBER/NOV-NGC3783-Hs8') #'NOVEMBER/Kelly-NGC3783K')
error_Hs8 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Hs8.txt') #Load data

data_Js8 = np.loadtxt('NOVEMBER/NOV-NGC3783-Js8') #'NOVEMBER/Kelly-NGC3783K')
error_Js8 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Js8.txt') #Load data

data_Ks = np.loadtxt('NOVEMBER/NOV-NGC3783-K_small') #'NOVEMBER/Kelly-NGC3783K')
error_Ks = np.loadtxt('NOVEMBER/NGC3783_NOISE_K_small.txt') #Load data

data_Hs = np.loadtxt('NOVEMBER/NOV-NGC3783-H_small') #'NOVEMBER/Kelly-NGC3783K')
error_Hs = np.loadtxt('NOVEMBER/NGC3783_NOISE_H_small.txt') #Load data

data_Js = np.loadtxt('NOVEMBER/NOV-NGC3783-J_small') #'NOVEMBER/Kelly-NGC3783K')
error_Js = np.loadtxt('NOVEMBER/NGC3783_NOISE_J_small.txt') #Load data

data_g = np.loadtxt('NOVEMBER/NOV-NGC3783-g') #'NOVEMBER/NOV-NGC3783-g_short')
error_g = np.loadtxt('NOVEMBER/NGC3783_NOISE_g.txt') #Load data

data_r = np.loadtxt('NOVEMBER/NOV-NGC3783-r') #'NOVEMBER/NOV-NGC3783-r_short')
error_r = np.loadtxt('NOVEMBER/NGC3783_NOISE_r.txt') #Load data

data_i = np.loadtxt('NOVEMBER/NOV-NGC3783-i') #'NOVEMBER/NOV-NGC3783-i_short')
error_i = np.loadtxt('NOVEMBER/NGC3783_NOISE_i.txt') #Load data

data_z = np.loadtxt('NOVEMBER/NOV-NGC3783-z') #'NOVEMBER/NOV-NGC3783-z_short')
error_z = np.loadtxt('NOVEMBER/NGC3783_NOISE_z.txt') #Load data

data_gs = np.loadtxt('NOVEMBER/NOV-NGC3783-gs7') #'NOVEMBER/NOV-NGC3783-g_short')
error_gs = np.loadtxt('NOVEMBER/NGC3783_NOISE_gs7.txt') #Load data

data_rs = np.loadtxt('NOVEMBER/NOV-NGC3783-rs7') #'NOVEMBER/NOV-NGC3783-r_short')
error_rs = np.loadtxt('NOVEMBER/NGC3783_NOISE_rs7.txt') #Load data

data_is = np.loadtxt('NOVEMBER/NOV-NGC3783-is7') #'NOVEMBER/NOV-NGC3783-i_short')
error_is = np.loadtxt('NOVEMBER/NGC3783_NOISE_is7.txt') #Load data

data_gs2 = np.loadtxt('NOVEMBER/NOV-NGC3783-gs2') #'NOVEMBER/NOV-NGC3783-g_short')
error_gs2 = np.loadtxt('NOVEMBER/NGC3783_NOISE_gs2.txt') #Load data

data_rs2 = np.loadtxt('NOVEMBER/NOV-NGC3783-rs2') #'NOVEMBER/NOV-NGC3783-r_short')
error_rs2 = np.loadtxt('NOVEMBER/NGC3783_NOISE_rs2.txt') #Load data

data_is2 = np.loadtxt('NOVEMBER/NOV-NGC3783-is2') #'NOVEMBER/NOV-NGC3783-i_short')
error_is2 = np.loadtxt('NOVEMBER/NGC3783_NOISE_is2.txt') #Load data

data_Ks2 = np.loadtxt('NOVEMBER/NOV-NGC3783-Ks2') #'NOVEMBER/Kelly-NGC3783K')
error_Ks2 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Ks2.txt') #Load data

data_Hs2 = np.loadtxt('NOVEMBER/NOV-NGC3783-Hs2') #'NOVEMBER/Kelly-NGC3783K')
error_Hs2 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Hs2.txt') #Load data

data_Js2 = np.loadtxt('NOVEMBER/NOV-NGC3783-Js2') #'NOVEMBER/Kelly-NGC3783K')
error_Js2 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Js2.txt') #Load data


data_comp_K = np.zeros((len(data_K[:,1]),4))
data_comp_K[:,0] = data_K[:,0]
data_comp_K[:,1] = data_K[:,1]
data_comp_K[:,2] = 0
data_comp_K[:,3] = error_K[:,1]

mask = ~np.isnan(data_comp_K[:,1])
data_comp_K = data_comp_K[mask,:]
mask = ~np.isnan(data_comp_K[:,3])
data_comp_K = data_comp_K[mask,:]
data_comp_K = data_comp_K[np.ma.masked_where(0<data_comp_K[:,1],data_comp_K[:,1]).mask,:]
data_comp_K = data_comp_K[np.ma.masked_where(1e-15>data_comp_K[:,3],data_comp_K[:,3]).mask,:]



data_comp_H = np.zeros((len(data_H[:,1]),4))
data_comp_H[:,0] = data_H[:,0]
data_comp_H[:,1] = data_H[:,1]
data_comp_H[:,2] = 0
data_comp_H[:,3] = error_H[:,1]
data_comp_H = data_comp_H[np.ma.masked_where(0<data_comp_H[:,1],data_comp_H[:,1]).mask,:]
data_comp_H = data_comp_H[np.ma.masked_where(1e-15>data_comp_H[:,3],data_comp_H[:,3]).mask,:]


mask = ~np.isnan(data_comp_H[:,1])
data_comp_H = data_comp_H[mask,:]
mask = ~np.isnan(data_comp_H[:,3])
data_comp_H = data_comp_H[mask,:]

data_comp_J = np.zeros((len(data_J[:,1]),4))
data_comp_J[:,0] = data_J[:,0]
data_comp_J[:,1] = data_J[:,1]
data_comp_J[:,2] = 0
data_comp_J[:,3] = error_J[:,1]
data_comp_J = data_comp_J[np.ma.masked_where(0<data_comp_J[:,1],data_comp_J[:,1]).mask,:]
data_comp_J = data_comp_J[np.ma.masked_where(1e-15>data_comp_J[:,3],data_comp_J[:,3]).mask,:]


mask = ~np.isnan(data_comp_J[:,1])
data_comp_J = data_comp_J[mask,:]
mask = ~np.isnan(data_comp_J[:,3])
data_comp_J = data_comp_J[mask,:]

data_comp_g = np.zeros((len(data_g[:,1]),4))
data_comp_g[:,0] = data_g[:,0]
data_comp_g[:,1] = data_g[:,2]
data_comp_g[:,2] = 0
data_comp_g[:,3] = error_g[:,2]
data_comp_g = data_comp_g[np.ma.masked_where(0<data_comp_g[:,1],data_comp_g[:,1]).mask,:]
data_comp_g = data_comp_g[np.ma.masked_where(1e-15>data_comp_g[:,3],data_comp_g[:,3]).mask,:]


mask = ~np.isnan(data_comp_g[:,1])
data_comp_g = data_comp_g[mask,:]
mask = ~np.isnan(data_comp_g[:,3])
data_comp_g = data_comp_g[mask,:]

data_comp_r = np.zeros((len(data_r[:,1]),4))
data_comp_r[:,0] = data_r[:,0]
data_comp_r[:,1] = data_r[:,2]
data_comp_r[:,2] = 0
data_comp_r[:,3] = error_r[:,2]
data_comp_r = data_comp_r[np.ma.masked_where(0<data_comp_r[:,1],data_comp_r[:,1]).mask,:]
data_comp_r = data_comp_r[np.ma.masked_where(1e-15>data_comp_r[:,3],data_comp_r[:,3]).mask,:]

mask = ~np.isnan(data_comp_r[:,1])
data_comp_r = data_comp_r[mask,:]
mask = ~np.isnan(data_comp_r[:,3])
data_comp_r = data_comp_r[mask,:]

data_comp_i = np.zeros((len(data_i[:,1]),4))
data_comp_i[:,0] = data_i[:,0]
data_comp_i[:,1] = data_i[:,2]
data_comp_i[:,2] = 0
data_comp_i[:,3] = error_i[:,2]
data_comp_i = data_comp_i[np.ma.masked_where(0<data_comp_i[:,1],data_comp_i[:,1]).mask,:]
data_comp_i = data_comp_i[np.ma.masked_where(1e-15>data_comp_i[:,3],data_comp_i[:,3]).mask,:]


#print data_comp_i[:,3]
mask = ~np.isnan(data_comp_i[:,1])
data_comp_i = data_comp_i[mask,:]
mask = ~np.isnan(data_comp_i[:,3])
data_comp_i = data_comp_i[mask,:]
#print data_comp_i[:,3]

data_comp_z = np.zeros((len(data_z[:,1]),4))
data_comp_z[:,0] = data_z[:,0]
data_comp_z[:,1] = data_z[:,2]
data_comp_z[:,2] = 0
data_comp_z[:,3] = error_z[:,2]
data_comp_z = data_comp_z[np.ma.masked_where(0<data_comp_z[:,1],data_comp_z[:,1]).mask,:]
data_comp_z = data_comp_z[np.ma.masked_where(1e-15>data_comp_z[:,3],data_comp_z[:,3]).mask,:]


mask = ~np.isnan(data_comp_z[:,1])
data_comp_z = data_comp_z[mask,:]
mask = ~np.isnan(data_comp_z[:,3])
data_comp_z = data_comp_z[mask,:]

# %%
data_Ks7 = np.loadtxt('NOVEMBER/NOV-NGC3783-Ks7') #'NOVEMBER/Kelly-NGC3783K')
error_Ks7 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Ks7.txt') #Load data

data_Hs7 = np.loadtxt('NOVEMBER/NOV-NGC3783-Hs7') #'NOVEMBER/Kelly-NGC3783K')
error_Hs7 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Hs7.txt') #Load data

data_Js7 = np.loadtxt('NOVEMBER/NOV-NGC3783-Js7') #'NOVEMBER/Kelly-NGC3783K')
error_Js7 = np.loadtxt('NOVEMBER/NGC3783_NOISE_Js7.txt') #Load data

# %%
data_comp_Ks2 = np.zeros((len(data_Ks2[:,1]),4))
data_comp_Ks2[:,0] = data_Ks2[:,0]
data_comp_Ks2[:,1] = data_Ks2[:,1]
data_comp_Ks2[:,2] = 0
data_comp_Ks2[:,3] = error_Ks2[:,1]

mask = ~np.isnan(data_comp_Ks2[:,1])
data_comp_Ks2 = data_comp_Ks2[mask,:]
mask = ~np.isnan(data_comp_Ks2[:,3])
data_comp_Ks2 = data_comp_Ks2[mask,:]
data_comp_Ks2 = data_comp_Ks2[np.ma.masked_where(0<data_comp_Ks2[:,1],data_comp_Ks2[:,1]).mask,:]
data_comp_Ks2 = data_comp_Ks2[np.ma.masked_where(1e-15>data_comp_Ks2[:,3],data_comp_Ks2[:,3]).mask,:]



data_comp_Hs2 = np.zeros((len(data_Hs2[:,1]),4))
data_comp_Hs2[:,0] = data_Hs2[:,0]
data_comp_Hs2[:,1] = data_Hs2[:,1]
data_comp_Hs2[:,2] = 0
data_comp_Hs2[:,3] = error_Hs2[:,1]
data_comp_Hs2 = data_comp_Hs2[np.ma.masked_where(0<data_comp_Hs2[:,1],data_comp_Hs2[:,1]).mask,:]
data_comp_Hs2 = data_comp_Hs2[np.ma.masked_where(1e-15>data_comp_Hs2[:,3],data_comp_Hs2[:,3]).mask,:]


mask = ~np.isnan(data_comp_Hs2[:,1])
data_comp_Hs2 = data_comp_Hs2[mask,:]
mask = ~np.isnan(data_comp_Hs2[:,3])
data_comp_Hs2 = data_comp_Hs2[mask,:]

data_comp_Js2 = np.zeros((len(data_Js2[:,1]),4))
data_comp_Js2[:,0] = data_Js2[:,0]
data_comp_Js2[:,1] = data_Js2[:,1]
data_comp_Js2[:,2] = 0
data_comp_Js2[:,3] = error_Js2[:,1]
data_comp_Js2 = data_comp_Js2[np.ma.masked_where(0<data_comp_Js2[:,1],data_comp_Js2[:,1]).mask,:]
data_comp_Js2 = data_comp_Js2[np.ma.masked_where(1e-15>data_comp_Js2[:,3],data_comp_Js2[:,3]).mask,:]


mask = ~np.isnan(data_comp_Js2[:,1])
data_comp_Js2 = data_comp_Js2[mask,:]
mask = ~np.isnan(data_comp_Js2[:,3])
data_comp_Js2 = data_comp_Js2[mask,:]

# %%
data_comp_Ks8 = np.zeros((len(data_Ks8[:,1]),4))
data_comp_Ks8[:,0] = data_Ks8[:,0]
data_comp_Ks8[:,1] = data_Ks8[:,1]
data_comp_Ks8[:,2] = 0
data_comp_Ks8[:,3] = error_Ks8[:,1]

mask = ~np.isnan(data_comp_Ks8[:,1])
data_comp_Ks8 = data_comp_Ks8[mask,:]
mask = ~np.isnan(data_comp_Ks8[:,3])
data_comp_Ks8 = data_comp_Ks8[mask,:]
data_comp_Ks8 = data_comp_Ks8[np.ma.masked_where(0<data_comp_Ks8[:,1],data_comp_Ks8[:,1]).mask,:]
data_comp_Ks8 = data_comp_Ks8[np.ma.masked_where(1e-15>data_comp_Ks8[:,3],data_comp_Ks8[:,3]).mask,:]



data_comp_Hs8 = np.zeros((len(data_Hs8[:,1]),4))
data_comp_Hs8[:,0] = data_Hs8[:,0]
data_comp_Hs8[:,1] = data_Hs8[:,1]
data_comp_Hs8[:,2] = 0
data_comp_Hs8[:,3] = error_Hs8[:,1]
data_comp_Hs8 = data_comp_Hs8[np.ma.masked_where(0<data_comp_Hs8[:,1],data_comp_Hs8[:,1]).mask,:]
data_comp_Hs8 = data_comp_Hs8[np.ma.masked_where(1e-15>data_comp_Hs8[:,3],data_comp_Hs8[:,3]).mask,:]


mask = ~np.isnan(data_comp_Hs8[:,1])
data_comp_Hs8 = data_comp_Hs8[mask,:]
mask = ~np.isnan(data_comp_Hs8[:,3])
data_comp_Hs8 = data_comp_Hs8[mask,:]

data_comp_Js8 = np.zeros((len(data_Js8[:,1]),4))
data_comp_Js8[:,0] = data_Js8[:,0]
data_comp_Js8[:,1] = data_Js8[:,1]
data_comp_Js8[:,2] = 0
data_comp_Js8[:,3] = error_Js8[:,1]
data_comp_Js8 = data_comp_Js8[np.ma.masked_where(0<data_comp_Js8[:,1],data_comp_Js8[:,1]).mask,:]
data_comp_Js8 = data_comp_Js8[np.ma.masked_where(1e-15>data_comp_Js8[:,3],data_comp_Js8[:,3]).mask,:]


mask = ~np.isnan(data_comp_Js8[:,1])
data_comp_Js8 = data_comp_Js8[mask,:]
mask = ~np.isnan(data_comp_Js8[:,3])
data_comp_Js8 = data_comp_Js8[mask,:]

# %%
data_comp_Ks7 = np.zeros((len(data_Ks7[:,1]),4))
data_comp_Ks7[:,0] = data_Ks7[:,0]
data_comp_Ks7[:,1] = data_Ks7[:,1]
data_comp_Ks7[:,2] = 0
data_comp_Ks7[:,3] = error_Ks7[:,1]

mask = ~np.isnan(data_comp_Ks7[:,1])
data_comp_Ks7 = data_comp_Ks7[mask,:]
mask = ~np.isnan(data_comp_Ks7[:,3])
data_comp_Ks7 = data_comp_Ks7[mask,:]
data_comp_Ks7 = data_comp_Ks7[np.ma.masked_where(0<data_comp_Ks7[:,1],data_comp_Ks7[:,1]).mask,:]
data_comp_Ks7 = data_comp_Ks7[np.ma.masked_where(1e-15>data_comp_Ks7[:,3],data_comp_Ks7[:,3]).mask,:]



data_comp_Hs7 = np.zeros((len(data_Hs7[:,1]),4))
data_comp_Hs7[:,0] = data_Hs7[:,0]
data_comp_Hs7[:,1] = data_Hs7[:,1]
data_comp_Hs7[:,2] = 0
data_comp_Hs7[:,3] = error_Hs7[:,1]
data_comp_Hs7 = data_comp_Hs7[np.ma.masked_where(0<data_comp_Hs7[:,1],data_comp_Hs7[:,1]).mask,:]
data_comp_Hs7 = data_comp_Hs7[np.ma.masked_where(1e-15>data_comp_Hs7[:,3],data_comp_Hs7[:,3]).mask,:]


mask = ~np.isnan(data_comp_Hs7[:,1])
data_comp_Hs7 = data_comp_Hs7[mask,:]
mask = ~np.isnan(data_comp_Hs7[:,3])
data_comp_Hs7 = data_comp_Hs7[mask,:]

data_comp_Js7 = np.zeros((len(data_Js7[:,1]),4))
data_comp_Js7[:,0] = data_Js7[:,0]
data_comp_Js7[:,1] = data_Js7[:,1]
data_comp_Js7[:,2] = 0
data_comp_Js7[:,3] = error_Js7[:,1]
data_comp_Js7 = data_comp_Js7[np.ma.masked_where(0<data_comp_Js7[:,1],data_comp_Js7[:,1]).mask,:]
data_comp_Js7 = data_comp_Js7[np.ma.masked_where(1e-15>data_comp_Js7[:,3],data_comp_Js7[:,3]).mask,:]


mask = ~np.isnan(data_comp_Js7[:,1])
data_comp_Js7 = data_comp_Js7[mask,:]
mask = ~np.isnan(data_comp_Js7[:,3])
data_comp_Js7 = data_comp_Js7[mask,:]

# %%
data_comp_Ks = np.zeros((len(data_Ks[:,1]),4))
data_comp_Ks[:,0] = data_Ks[:,0]
data_comp_Ks[:,1] = data_Ks[:,1]
data_comp_Ks[:,2] = 0
data_comp_Ks[:,3] = error_Ks[:,1]

mask = ~np.isnan(data_comp_Ks[:,1])
data_comp_Ks = data_comp_Ks[mask,:]
mask = ~np.isnan(data_comp_Ks[:,3])
data_comp_Ks = data_comp_Ks[mask,:]
data_comp_Ks = data_comp_Ks[np.ma.masked_where(0<data_comp_Ks[:,1],data_comp_Ks[:,1]).mask,:]
data_comp_Ks = data_comp_Ks[np.ma.masked_where(1e-15>data_comp_Ks[:,3],data_comp_Ks[:,3]).mask,:]



data_comp_Hs = np.zeros((len(data_Hs[:,1]),4))
data_comp_Hs[:,0] = data_Hs[:,0]
data_comp_Hs[:,1] = data_Hs[:,1]
data_comp_Hs[:,2] = 0
data_comp_Hs[:,3] = error_Hs[:,1]
data_comp_Hs = data_comp_Hs[np.ma.masked_where(0<data_comp_Hs[:,1],data_comp_Hs[:,1]).mask,:]
data_comp_Hs = data_comp_Hs[np.ma.masked_where(1e-15>data_comp_Hs[:,3],data_comp_Hs[:,3]).mask,:]


mask = ~np.isnan(data_comp_Hs[:,1])
data_comp_Hs = data_comp_Hs[mask,:]
mask = ~np.isnan(data_comp_Hs[:,3])
data_comp_Hs = data_comp_Hs[mask,:]

data_comp_Js = np.zeros((len(data_Js[:,1]),4))
data_comp_Js[:,0] = data_Js[:,0]
data_comp_Js[:,1] = data_Js[:,1]
data_comp_Js[:,2] = 0
data_comp_Js[:,3] = error_Js[:,1]
data_comp_Js = data_comp_Js[np.ma.masked_where(0<data_comp_Js[:,1],data_comp_Js[:,1]).mask,:]
data_comp_Js = data_comp_Js[np.ma.masked_where(1e-15>data_comp_Js[:,3],data_comp_Js[:,3]).mask,:]


mask = ~np.isnan(data_comp_Js[:,1])
data_comp_Js = data_comp_Js[mask,:]
mask = ~np.isnan(data_comp_Js[:,3])
data_comp_Js = data_comp_Js[mask,:]


data_comp_gs = np.zeros((len(data_gs[:,1]),4))
data_comp_gs[:,0] = data_gs[:,0]
data_comp_gs[:,1] = data_gs[:,2]
data_comp_gs[:,2] = 0
data_comp_gs[:,3] = error_gs[:,2]
data_comp_gs = data_comp_gs[np.ma.masked_where(0<data_comp_gs[:,1],data_comp_gs[:,1]).mask,:]
data_comp_gs = data_comp_gs[np.ma.masked_where(1e-15>data_comp_gs[:,3],data_comp_gs[:,3]).mask,:]


mask = ~np.isnan(data_comp_gs[:,1])
data_comp_gs = data_comp_gs[mask,:]
mask = ~np.isnan(data_comp_gs[:,3])
data_comp_gs = data_comp_gs[mask,:]


data_comp_rs = np.zeros((len(data_rs[:,1]),4))
data_comp_rs[:,0] = data_rs[:,0]
data_comp_rs[:,1] = data_rs[:,2]
data_comp_rs[:,2] = 0
data_comp_rs[:,3] = error_rs[:,2]
data_comp_rs = data_comp_rs[np.ma.masked_where(0<data_comp_rs[:,1],data_comp_rs[:,1]).mask,:]
data_comp_rs = data_comp_rs[np.ma.masked_where(1e-15>data_comp_rs[:,3],data_comp_rs[:,3]).mask,:]

mask = ~np.isnan(data_comp_rs[:,1])
data_comp_rs = data_comp_rs[mask,:]
mask = ~np.isnan(data_comp_rs[:,3])
data_comp_rs = data_comp_rs[mask,:]

data_comp_is = np.zeros((len(data_is[:,1]),4))
data_comp_is[:,0] = data_is[:,0]
data_comp_is[:,1] = data_is[:,2]
data_comp_is[:,2] = 0
data_comp_is[:,3] = error_is[:,2]
data_comp_is = data_comp_is[np.ma.masked_where(0<data_comp_is[:,1],data_comp_is[:,1]).mask,:]
data_comp_is = data_comp_is[np.ma.masked_where(1e-15>data_comp_is[:,3],data_comp_is[:,3]).mask,:]


#print data_comp_is[:,3]
mask = ~np.isnan(data_comp_is[:,1])
data_comp_is = data_comp_is[mask,:]
mask = ~np.isnan(data_comp_is[:,3])
data_comp_is = data_comp_is[mask,:]
#print data_comp_is[:,3]

# %%
data_comp_gs2 = np.zeros((len(data_gs[:,1]),4))
data_comp_gs2[:,0] = data_gs2[:,0]
data_comp_gs2[:,1] = data_gs2[:,2]
data_comp_gs2[:,2] = 0
data_comp_gs2[:,3] = error_gs2[:,2]
data_comp_gs2 = data_comp_gs2[np.ma.masked_where(0<data_comp_gs2[:,1],data_comp_gs2[:,1]).mask,:]
data_comp_gs2 = data_comp_gs2[np.ma.masked_where(1e-15>data_comp_gs2[:,3],data_comp_gs2[:,3]).mask,:]


mask = ~np.isnan(data_comp_gs2[:,1])
data_comp_gs2 = data_comp_gs2[mask,:]
mask = ~np.isnan(data_comp_gs2[:,3])
data_comp_gs2 = data_comp_gs2[mask,:]


data_comp_rs2 = np.zeros((len(data_rs2[:,1]),4))
data_comp_rs2[:,0] = data_rs2[:,0]
data_comp_rs2[:,1] = data_rs2[:,2]
data_comp_rs2[:,2] = 0
data_comp_rs2[:,3] = error_rs2[:,2]
data_comp_rs2 = data_comp_rs2[np.ma.masked_where(0<data_comp_rs2[:,1],data_comp_rs2[:,1]).mask,:]
data_comp_rs2 = data_comp_rs2[np.ma.masked_where(1e-15>data_comp_rs2[:,3],data_comp_rs2[:,3]).mask,:]

mask = ~np.isnan(data_comp_rs2[:,1])
data_comp_rs2 = data_comp_rs2[mask,:]
mask = ~np.isnan(data_comp_rs2[:,3])
data_comp_rs2 = data_comp_rs2[mask,:]

data_comp_is2 = np.zeros((len(data_is[:,1]),4))
data_comp_is2[:,0] = data_is2[:,0]
data_comp_is2[:,1] = data_is2[:,2]
data_comp_is2[:,2] = 0
data_comp_is2[:,3] = error_is[:,2]
data_comp_is2 = data_comp_is2[np.ma.masked_where(0<data_comp_is2[:,1],data_comp_is2[:,1]).mask,:]
data_comp_is2 = data_comp_is2[np.ma.masked_where(1e-15>data_comp_is2[:,3],data_comp_is2[:,3]).mask,:]

mask = ~np.isnan(data_comp_is2[:,1])
data_comp_is2 = data_comp_is2[mask,:]
mask = ~np.isnan(data_comp_is2[:,3])
data_comp_is2 = data_comp_is2[mask,:]

# %%
data_comp_K1 = np.zeros((len(data_K[:,1]),4))
data_comp_K1[:,0] = data_K[:,0]
data_comp_K1[:,1] = data_K[:,2]
data_comp_K1[:,2] = 0
data_comp_K1[:,3] = error_K[:,2]

mask = ~np.isnan(data_comp_K1[:,1])
data_comp_K1 = data_comp_K1[mask,:]
mask = ~np.isnan(data_comp_K1[:,3])
data_comp_K1 = data_comp_K1[mask,:]
data_comp_K1 = data_comp_K1[np.ma.masked_where(0<data_comp_K1[:,1],data_comp_K1[:,1]).mask,:]
data_comp_K1 = data_comp_K1[np.ma.masked_where(1e-15>data_comp_K1[:,3],data_comp_K1[:,3]).mask,:]



data_comp_H1 = np.zeros((len(data_H[:,1]),4))
data_comp_H1[:,0] = data_H[:,0]
data_comp_H1[:,1] = data_H[:,2]
data_comp_H1[:,2] = 0
data_comp_H1[:,3] = error_H[:,2]
data_comp_H1 = data_comp_H1[np.ma.masked_where(0<data_comp_H1[:,1],data_comp_H1[:,1]).mask,:]
data_comp_H1 = data_comp_H1[np.ma.masked_where(1e-15>data_comp_H1[:,3],data_comp_H1[:,3]).mask,:]


mask = ~np.isnan(data_comp_H1[:,1])
data_comp_H1 = data_comp_H1[mask,:]
mask = ~np.isnan(data_comp_H1[:,3])
data_comp_H1 = data_comp_H1[mask,:]

data_comp_J1 = np.zeros((len(data_J[:,1]),4))
data_comp_J1[:,0] = data_J[:,0]
data_comp_J1[:,1] = data_J[:,2]
data_comp_J1[:,2] = 0
data_comp_J1[:,3] = error_J[:,2]
data_comp_J1 = data_comp_J1[np.ma.masked_where(0<data_comp_J1[:,1],data_comp_J1[:,1]).mask,:]
data_comp_J1 = data_comp_J1[np.ma.masked_where(1e-15>data_comp_J1[:,3],data_comp_J1[:,3]).mask,:]


mask = ~np.isnan(data_comp_J1[:,1])
data_comp_J1 = data_comp_J1[mask,:]
mask = ~np.isnan(data_comp_J1[:,3])
data_comp_J1 = data_comp_J1[mask,:]

data_comp_K2 = np.copy(data_comp_K)
#data_comp_K2[:,1:] = data_comp_K2[:,1:]*10**((-0.13)/2.5)
#data_comp_K2[:,1:] = data_comp_K2[:,1:]*10**((-1.85)/2.5)

data_comp_H2 = np.copy(data_comp_H)
#data_comp_H2[:,1:] = data_comp_H2[:,1:]*10**((0.03)/2.5)
#data_comp_H2[:,1:] = data_comp_H2[:,1:]*10**((-1.39)/2.5)

data_comp_J2 = np.copy(data_comp_J)
#data_comp_J2[:,1:] = data_comp_J2[:,1:]*10**((0.18)/2.5)
#data_comp_J2[:,1:] = data_comp_J2[:,1:]*10**((-0.91)/2.5)

data_comp_g2 = np.copy(data_comp_g)
#data_comp_g2[:,1:] = data_comp_g2[:,1:]*10**((-0.08)/2.5)

data_comp_r2 = np.copy(data_comp_r)
#data_comp_r2[:,1:] = data_comp_r2[:,1:]*10**((0.16)/2.5)

data_comp_i2 = np.copy(data_comp_i)
#data_comp_i2[:,1:] = data_comp_i2[:,1:]*10**((0.37)/2.5)

data_comp_z2 = np.copy(data_comp_z)
#data_comp_z2[:,1:] = data_comp_z2[:,1:]*10**((0.54)/2.5)

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 18})

plt.figure(figsize=(10,10))
plt.errorbar(data_comp_K[:,0],data_comp_K[:,1],yerr=data_comp_K[:,3],fmt='x',label='K')
plt.errorbar(data_comp_H[:,0],data_comp_H[:,1],yerr=data_comp_H[:,3],fmt='x',label='H')
plt.errorbar(data_comp_J[:,0],data_comp_J[:,1],yerr=data_comp_J[:,3],fmt='x',label='J')
plt.errorbar(data_comp_g[:,0],data_comp_g[:,1],yerr=data_comp_g[:,3],fmt='x',label='g')
plt.errorbar(data_comp_r[:,0],data_comp_r[:,1],yerr=data_comp_r[:,3],fmt='x',label='r')
plt.errorbar(data_comp_i[:,0],data_comp_i[:,1],yerr=data_comp_i[:,3],fmt='x',label='i')
#plt.errorbar(data_comp_z[:,0],data_comp_z[:,1],yerr=data_comp_z[:,3],fmt='x',label='z')
plt.legend()
plt.ylim([6e-15,1.5e-14])
plt.show()

plt.figure(figsize=(10,10))
plt.errorbar(data_comp_K[:,0],data_comp_K[:,1],yerr=data_comp_K[:,3],fmt='x',label='K',color='b')
plt.errorbar(data_comp_H[:,0],data_comp_H[:,1],yerr=data_comp_H[:,3],fmt='x',label='H',color='r')
plt.errorbar(data_comp_J[:,0],data_comp_J[:,1],yerr=data_comp_J[:,3],fmt='x',label='J',color='g')
plt.errorbar(data_comp_Ks[:,0],data_comp_Ks[:,1],yerr=data_comp_Ks[:,3],fmt='o',label='K small',color='b')
plt.errorbar(data_comp_Hs[:,0],data_comp_Hs[:,1],yerr=data_comp_Hs[:,3],fmt='o',label='H small',color='r')
plt.errorbar(data_comp_Js[:,0],data_comp_Js[:,1],yerr=data_comp_Js[:,3],fmt='o',label='J small',color='g')
#plt.errorbar(data_comp_z[:,0],data_comp_z[:,1],yerr=data_comp_z[:,3],fmt='x',label='z')
plt.xlabel('MJD-OBS')
plt.ylabel('Flux in aperture (erg/cm^2/s/A)')
plt.legend()
plt.ylim([4e-15,1.7e-14])
plt.show()


plt.figure(figsize=(10,10))
plt.errorbar(data_comp_Ks[:,0],data_comp_Ks[:,1],yerr=data_comp_Ks[:,3],fmt='x',label='K')
plt.errorbar(data_comp_Hs[:,0],data_comp_Hs[:,1],yerr=data_comp_Hs[:,3],fmt='x',label='H')
plt.errorbar(data_comp_Js[:,0],data_comp_Js[:,1],yerr=data_comp_Js[:,3],fmt='x',label='J')
plt.errorbar(data_comp_gs[:,0],data_comp_gs[:,1],yerr=data_comp_gs[:,3],fmt='x',label='g')
plt.errorbar(data_comp_rs[:,0],data_comp_rs[:,1],yerr=data_comp_rs[:,3],fmt='x',label='r')
plt.errorbar(data_comp_is[:,0],data_comp_is[:,1],yerr=data_comp_is[:,3],fmt='x',label='i')
#plt.errorbar(data_comp_z[:,0],data_comp_z[:,1],yerr=data_comp_z[:,3],fmt='x',label='z')
plt.ylim([4e-15,1.6e-14])
plt.legend()
plt.show()

# %%
print np.shape(data_comp_gs), np.shape(data_comp_Ks)
data_comp1_K =  np.copy(data_comp_K)
data_comp1_H =  np.copy(data_comp_H)
data_comp1_J =  np.copy(data_comp_J)
data_comp1_g =  np.copy(data_comp_g)
data_comp1_r =  np.copy(data_comp_r)
data_comp1_i =  np.copy(data_comp_i)
data_comp1_z =  np.copy(data_comp_z)
data_comp1_K1 =  np.copy(data_comp_K1)
data_comp1_H1 =  np.copy(data_comp_H1)
data_comp1_J1 =  np.copy(data_comp_J1)

data_comp1_K[:,1:] =  data_comp_K[:,1:]/K_width
data_comp1_H[:,1:] =  data_comp_H[:,1:]/H_width
data_comp1_J[:,1:] =  data_comp_J[:,1:]/J_width
data_comp1_g[:,1:] =  data_comp_g[:,1:]/g_width
data_comp1_r[:,1:] =  data_comp_r[:,1:]/r_width
data_comp1_i[:,1:] =  data_comp_i[:,1:]/i_width
data_comp1_z[:,1:] =  data_comp_z[:,1:]/z_width
data_comp1_K1[:,1:] =  data_comp_K1[:,1:]/K_width
data_comp1_H1[:,1:] =  data_comp_H1[:,1:]/H_width
data_comp1_J1[:,1:] =  data_comp_J1[:,1:]/J_width
# Out:
# (100, 4) (41, 4)

# %%
plt.figure(figsize=(10,10))
plt.errorbar(data_comp1_K[:,0],data_comp1_K[:,1],yerr=data_comp1_K[:,3],fmt='x',label='K',color='b')
plt.errorbar(data_comp1_H[:,0],data_comp1_H[:,1],yerr=data_comp1_H[:,3],fmt='x',label='H',color='orange')
plt.errorbar(data_comp1_J[:,0],data_comp1_J[:,1],yerr=data_comp1_J[:,3],fmt='x',label='J',color='g')
plt.errorbar(data_comp1_K1[:,0],data_comp1_K1[:,1],yerr=data_comp1_K1[:,3],fmt='o',label='K',color='b')
plt.errorbar(data_comp1_H1[:,0],data_comp1_H1[:,1],yerr=data_comp1_H1[:,3],fmt='o',label='H',color='orange')
plt.errorbar(data_comp1_J1[:,0],data_comp1_J1[:,1],yerr=data_comp1_J1[:,3],fmt='o',label='J',color='g')
plt.errorbar(data_comp1_g[:,0],data_comp1_g[:,1],yerr=data_comp1_g[:,3],fmt='x',label='g',color='k')
plt.errorbar(data_comp1_r[:,0],data_comp1_r[:,1],yerr=data_comp1_r[:,3],fmt='x',label='r',color='purple')
plt.errorbar(data_comp1_i[:,0],data_comp1_i[:,1],yerr=data_comp1_i[:,3],fmt='x',label='i',color='brown')
#plt.errorbar(data_comp_z[:,0],data_comp_z[:,1],yerr=data_comp_z[:,3],fmt='x',label='z')
plt.legend()
plt.ylim([1e-17,1.7e-16])
plt.show()

plt.figure(figsize=(10,10))
plt.subplot(211)
plt.errorbar(data_comp_r[:,0],data_comp_r[:,1],yerr=data_comp_r[:,3],fmt='x',label='r (0.72 arcsec radius)')
plt.errorbar(data_comp_rs[:,0],data_comp_rs[:,1],yerr=data_comp_rs[:,3],fmt='o',label='rs (1.8 arcsec radius)')
plt.subplot(212)
plt.errorbar(data_comp_g[:,0],data_comp_g[:,1],yerr=data_comp_g[:,3],fmt='x',label='r (0.72 arcsec radius)')
plt.errorbar(data_comp_gs[:,0],data_comp_gs[:,1],yerr=data_comp_gs[:,3],fmt='o',label='rs (1.8 arcsec radius)')

#plt.errorbar(data_comp_z[:,0],data_comp_z[:,1],yerr=data_comp_z[:,3],fmt='x',label='z')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,18))

matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16) 


plt.subplot(311)
plt.errorbar(data_comp_Ks[:,0],data_comp_Ks[:,1],yerr=data_comp_Ks[:,3],fmt='x',label='K (1.8 arcsec radius)')
plt.errorbar(data_comp_K[:,0],data_comp_K[:,1],yerr=data_comp_K[:,3],fmt='v',label='K (3.6 arcsec radius)')
plt.errorbar(data_comp_Ks2[:,0],data_comp_Ks2[:,1],yerr=data_comp_Ks2[:,3],fmt='*',label='K (0.72 arcsec radius)')
plt.errorbar(data_comp_Ks8[:,0],data_comp_Ks8[:,1],yerr=data_comp_Ks8[:,3],fmt='8',label='K (2.88 arcsec radius)')
plt.errorbar(data_comp_Ks7[:,0],data_comp_Ks7[:,1],yerr=data_comp_Ks7[:,3],fmt='.',label='K (2.57 arcsec radius)')

plt.ylim([2e-15,10e-15])
plt.title('Aperture comparisons on NGC3783 \n $K_{s}$-band',fontsize=24)
plt.ylabel('Flux ($erg\ cm^{-2}s^{-1}\AA^{-1}$)',fontsize=18)
plt.legend(fontsize=18,loc='5')
plt.grid('off')
plt.xticks([])

plt.subplots_adjust(hspace=0.2)

plt.subplot(312)

plt.errorbar(data_comp_Hs[:,0],data_comp_Hs[:,1],yerr=data_comp_Hs[:,3],fmt='x',label='H (1.8 arcsec radius)')
plt.errorbar(data_comp_H[:,0],data_comp_H[:,1],yerr=data_comp_H[:,3],fmt='v',label='H (3.6 arcsec radius)')
plt.errorbar(data_comp_Hs2[:,0],data_comp_Hs2[:,1],yerr=data_comp_Hs2[:,3],fmt='*',label='H (0.72 arcsec radius)')
plt.errorbar(data_comp_Hs8[:,0],data_comp_Hs8[:,1],yerr=data_comp_Hs8[:,3],fmt='8',label='H (2.88 arcsec radius)')
plt.errorbar(data_comp_Hs7[:,0],data_comp_Hs7[:,1],yerr=data_comp_Hs7[:,3],fmt='.',label='H (2.57 arcsec radius)')

#plt.ylim([4e-15,11e-15])
plt.title('$H$-band',fontsize=24)
plt.ylabel('Flux ($erg\ cm^{-2}s^{-1}\AA^{-1}$)',fontsize=18)
#plt.legend()
plt.xticks([])
plt.grid('off')


plt.subplot(313)

plt.errorbar(data_comp_Js[:,0],data_comp_Js[:,1],yerr=data_comp_Js[:,3],fmt='x',label='J (1.8 arcsec radius)')
plt.errorbar(data_comp_J[:,0],data_comp_J[:,1],yerr=data_comp_J[:,3],fmt='v',label='J (3.6 arcsec radius)')
plt.errorbar(data_comp_Js2[:,0],data_comp_Js2[:,1],yerr=data_comp_Js2[:,3],fmt='*',label='J (0.72 arcsec radius)')
plt.errorbar(data_comp_Js8[:,0],data_comp_Js8[:,1],yerr=data_comp_Js8[:,3],fmt='8',label='J (2.88 arcsec radius)')
plt.errorbar(data_comp_Js7[:,0],data_comp_Js7[:,1],yerr=data_comp_Js7[:,3],fmt='.',label='J (2.57 arcsec radius)')

#plt.ylim([6e-15,14e-15])
plt.title('$J$-band',fontsize=24)
plt.ylabel('Flux ($erg\ cm^{-2}s^{-1}\AA^{-1}$)',fontsize=18)
plt.xlabel('MJD-OBS',fontsize=18)
#plt.legend(fontsize=10)
plt.grid('off')


plt.subplots_adjust(hspace=0.2)

plt.savefig('/home/lynge/MasterP/paper_here/Figure/NGC3783_ap_JHK.png',bbox_inches='tight')

plt.show()

plt.title('JHK band light curves from NGC3783 at varying aperture sizes')

plt.xlabel('MJD-OBS')
plt.show()

# %%
f, plt = plt.subplots(4, sharex=True, sharey=True,figsize=(15,25))
f.suptitle('griz band light curves from NGC3783 at varying aperture sizes',y=0.91)
#plt[3].errorbar(data_comp_z[:,0],data_comp_z[:,1],yerr=data_comp_z[:,3],fmt='x',label='z (1.8 arcsec radius)')
#plt[3].errorbar(data_comp_zs[:,0],data_comp_zs[:,1],yerr=data_comp_zs[:,3],fmt='o',label='zs (0.72 arcsec radius)')

plt.errorbar(data_comp_is2[:,0],data_comp_is2[:,1],yerr=data_comp_is2[:,3],fmt='x',label='r (3.6 arcsec radius)')
plt.errorbar(data_comp_is[:,0],data_comp_is[:,1],yerr=data_comp_is[:,3],fmt='x',label='i (1.8 arcsec radius)')
plt[2].errorbar(data_comp_i[:,0],data_comp_i[:,1],yerr=data_comp_i[:,3],fmt='v',label='i (0.72 arcsec radius)')

plt[1].errorbar(data_comp_rs2[:,0],data_comp_rs2[:,1],yerr=data_comp_rs2[:,3],fmt='x',label='r (3.6 arcsec radius)')
plt[1].errorbar(data_comp_rs[:,0],data_comp_rs[:,1],yerr=data_comp_rs[:,3],fmt='x',label='r (1.8 arcsec radius)')
plt[1].errorbar(data_comp_r[:,0],data_comp_r[:,1],yerr=data_comp_r[:,3],fmt='v',label='r (0.72 arcsec radius)')

plt[0].errorbar(data_comp_gs2[:,0],data_comp_gs2[:,1],yerr=data_comp_gs2[:,3],fmt='x',label='g (3.6 arcsec radius)')
plt[0].errorbar(data_comp_gs[:,0],data_comp_gs[:,1],yerr=data_comp_gs[:,3],fmt='x',label='g (1.8 arcsec radius)')
plt[0].errorbar(data_comp_g[:,0],data_comp_g[:,1],yerr=data_comp_g[:,3],fmt='v',label='g (0.72 arcsec radius)')

# Bring subplots close to each other.

plt[0].legend()
plt[1].legend()
plt[2].legend()
plt[3].legend()

plt[0].set_ylim([1e-15,1.6e-14])
plt[1].set_ylim([1e-15,1.6e-14])
plt[2].set_ylim([1e-15,1.6e-14])
plt[3].set_ylim([1e-15,1.6e-14])

plt[0].set_ylabel('Flux ($erg\ cm^{-2}s^{-1}\AA^{-1}$)')
plt[1].set_ylabel('Flux ($erg\ cm^{-2}s^{-1}\AA^{-1}$)')
plt[2].set_ylabel('Flux ($erg\ cm^{-2}s^{-1}\AA^{-1}$)')
plt[3].set_ylabel('Flux ($erg\ cm^{-2}s^{-1}\AA^{-1}$)')
f.subplots_adjust(hspace=0.05)
# Hide x labels and tick labels for all but bottom plot.
for ax in plt:
    ax.label_outer()
plt.xlabel('MJD-OBS')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-28b3c0ceb2a7> in <module>()
#       4 #plt[3].errorbar(data_comp_zs[:,0],data_comp_zs[:,1],yerr=data_comp_zs[:,3],fmt='o',label='zs (0.72 arcsec radius)')
#       5
# ----> 6 plt.errorbar(data_comp_is2[:,0],data_comp_is2[:,1],yerr=data_comp_is2[:,3],fmt='x',label='r (3.6 arcsec radius)')
#       7 plt.errorbar(data_comp_is[:,0],data_comp_is[:,1],yerr=data_comp_is[:,3],fmt='x',label='i (1.8 arcsec radius)')
#       8 plt[2].errorbar(data_comp_i[:,0],data_comp_i[:,1],yerr=data_comp_i[:,3],fmt='v',label='i (0.72 arcsec radius)')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'errorbar'

# %%
x = np.array([1,2,3,4])
print x[1:]

# %%
center = np.array([K_cen,H_cen,J_cen,g_cen,r_cen,i_cen])
flux = np.array([np.mean(data_comp_Ks[:,1]),np.mean(data_comp_Hs[:,1]),np.mean(data_comp_Js[:,1]),\
                 np.mean(data_comp_gs[:,1]),np.mean(data_comp_rs[:,1]),np.mean(data_comp_is[:,1])])

# %%
error = np.array([np.mean(data_comp_Ks[:,3]),np.mean(data_comp_Hs[:,3]),np.mean(data_comp_Js[:,3]),\
                 np.mean(data_comp_gs[:,3]),np.mean(data_comp_rs[:,3]),np.mean(data_comp_is[:,3])])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.errorbar(center,flux,yerr=error,fmt='x')
plt.ylim([5e-15,1.2e-14])
plt.show()
