# %%
import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LogNorm
import scipy.stats as stats
from matplotlib import gridspec
import aplpy as apl #The Astronomy Plotting Library for python
import astropy
from astropy.stats import sigma_clip
from astropy.modeling import functional_models, models, fitting
import astropy.units as U
from astropy.coordinates import ICRS, Galactic, FK4, FK5, Angle, Latitude, Longitude
import astropy.constants as C
from astropy import wcs
import astropy.io.fits as fits
from astropy.io import ascii
import astropy.coordinates as coord
from astropy.coordinates import SkyCoord
from astropy.stats import signal_to_noise_oir_ccd as SNRas
#import spectral_cube as SC
#from spectral_cube import SpectralCube as sc
from astropy.wcs import WCS
matplotlib.use('Agg')
import matplotlib.cm as cm
#import astrometry as ast
import pyfits
import requests
import json
import os
from sklearn import datasets, linear_model
from scipy.optimize import curve_fit
import numpy.ma as ma
from astropy.table import Table, Column
import pyextract
import sewpy
import pandas as pd
from astropy import units as u
#import alipy
# Out:
# /home/lynge/anaconda2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:25: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/lynge/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/lynge/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-47c8d63312f7>", line 5, in <module>
#     get_ipython().magic(u'matplotlib inline')
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2158, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2079, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-104>", line 2, in matplotlib
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py", line 100, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2949, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/IPython/core/pylabtools.py", line 308, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py", line 232, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/lynge/anaconda2/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()

# %%
quas_K = [os.path.join('/../home/lynge/MasterP/ESO323/K',f) \
        for f in os.listdir('/../home/lynge/MasterP/ESO323/K')]

quas_H = [os.path.join('/../home/lynge/MasterP/ESO323/H',f) \
        for f in os.listdir('/../home/lynge/MasterP/ESO323/H')]

quas_J = [os.path.join('/../home/lynge/MasterP/ESO323/J',f) \
        for f in os.listdir('/../home/lynge/MasterP/ESO323/J')]


qua1_RA_WORLD = SkyCoord('13:06:26.115 -40:24:52.63', unit=(u.hourangle, u.deg)).ra.degree
qua1_DEC_WORLD = SkyCoord('13:06:26.115 -40:24:52.63', unit=(u.hourangle, u.deg)).dec.degree

print qua1_RA_WORLD

sta1_RA_WORLD = SkyCoord('13:06:23.368 -40:24:47.36', unit=(u.hourangle, u.deg)).ra.degree #TYC 7777-7-1
sta1_DEC_WORLD = SkyCoord('13:06:23.368 -40:24:47.36', unit=(u.hourangle, u.deg)).dec.degree

sta2_RA_WORLD = SkyCoord('13:06:20.816 -40:24:00.86', unit=(u.hourangle, u.deg)).ra.degree #2MASS J13062081-4024008
sta2_DEC_WORLD = SkyCoord('13:06:20.816 -40:24:00.86', unit=(u.hourangle, u.deg)).dec.degree

sta3_RA_WORLD = SkyCoord('13:06:31.543 -40:29:53.57', unit=(u.hourangle, u.deg)).ra.degree #UCAC2 14614825
sta3_DEC_WORLD = SkyCoord('13:06:31.543 -40:29:53.57', unit=(u.hourangle, u.deg)).dec.degree

sky1_RA_WORLD = SkyCoord('13:06:26 -40:24:29', unit=(u.hourangle, u.deg)).ra.degree #Random patch of sky
sky1_DEC_WORLD = SkyCoord('13:06:26 -40:24:29', unit=(u.hourangle, u.deg)).dec.degree

sky2_RA_WORLD = SkyCoord('13:06:28 -40:25:03', unit=(u.hourangle, u.deg)).ra.degree #Random patch of sky
sky2_DEC_WORLD = SkyCoord('13:06:28 -40:25:03', unit=(u.hourangle, u.deg)).dec.degree

sky3_RA_WORLD = SkyCoord('13:06:25 -40:25:26', unit=(u.hourangle, u.deg)).ra.degree #Random patch of sky
sky3_DEC_WORLD = SkyCoord('13:06:25 -40:25:26', unit=(u.hourangle, u.deg)).dec.degree


MAG_STA1_J = 10.513 
MAG_STA1_H = 10.226
MAG_STA1_K = 10.207

MAG_STA2_J = 8.294
MAG_STA2_H = 7.447
MAG_STA2_K = 7.105

MAG_STA3_J = 10.672
MAG_STA3_H = 10.142
MAG_STA3_K = 10.005

MAG_err_STA1_J = 0.026
MAG_err_STA1_H = 0.022
MAG_err_STA1_K = 0.025

MAG_err_STA2_J = 0.027
MAG_err_STA2_H = 0.038
MAG_err_STA2_K = 0.026

MAG_err_STA3_J = 0.022
MAG_err_STA3_H = 0.024
MAG_err_STA3_K = 0.021

MAG_VEGA_B = 0.
MAG_VEGA_V = 0.
MAG_VEGA_G = 0.
MAG_VEGA_J = 0.
MAG_VEGA_H = 0.
MAG_VEGA_K = 0.

MAG_VEGA_g = 0.
MAG_VEGA_r = 0.
MAG_VEGA_i = 0.
MAG_VEGA_z = 0.

FLUX_LAMBDA_VEGA_B = 632*10**(-11) #erg/cm**2/s/A
FLUX_LAMBDA_VEGA_V = 363.1*10**(-11)
FLUX_LAMBDA_VEGA_G = float('nan')
FLUX_LAMBDA_VEGA_J = 3.14*10**(-10)
FLUX_LAMBDA_VEGA_H = 1.11*10**(-10)
FLUX_LAMBDA_VEGA_K = 4.29*10**(-11)

FLUX_LAMBDA_VEGA_g = 466.9*10**(-11) #erg/cm**2/s/A
FLUX_LAMBDA_VEGA_r = 278.0*10**(-11)
FLUX_LAMBDA_VEGA_i = 185.2*10**(-11)
FLUX_LAMBDA_VEGA_z = 131.5*10**(-11)


FLUX_V_VEGA_B = 4.063*10**(-20) #erg/cm**2/s/Hz
FLUX_V_VEGA_V = 3.636*10**(-20)
FLUX_V_VEGA_G = float('nan')
FLUX_V_VEGA_J = 1.589*10**(-20)
FLUX_V_VEGA_H = 1.021*10**(-20)
FLUX_V_VEGA_K = 0.64*10**(-20)

FLUX_V_VEGA_g = 3.631*10**(-20) #erg/cm**2/s/Hz
FLUX_V_VEGA_r = 3.631*10**(-20)
FLUX_V_VEGA_i = 3.631*10**(-20)
FLUX_V_VEGA_z = 3.631*10**(-20)
# Out:
# 196.6088125

# %%
def dist(mid,end):
    return np.sqrt((mid[0] - end[0])**2 + (mid[1] - end[1])**2)

# %%
def flux_cal(A_mag,B_mag,B_flux):
    '''Flux of A found through magnitude and flux of B'''
    return B_flux*10**((B_mag-A_mag)/2.5)

# %%
def Basic(quasar,header):
    '''Provides a basic list of neccesities from the fits header file for use in the later \
    flux determination, it does not serve an individual purpose beyound that'''
    AGNdata = quasar #np.rot90(np.rot90(np.fliplr(quasar)))
    #header = data[0].header
    #print header
    RAstd = header['CRVAL1']
    DECstd = header['CRVAL2']
    #print RAstd, DECstd
    pixspa = header['PIXSCALE']/(3600.)
    #print pixspa
    RAstdpix = header['CRPIX1']
    DECstdpix = header['CRPIX2']
    exptime = 10 # header['EXPTIME']
    return header,AGNdata,RAstd,DECstd,pixspa,RAstdpix,DECstdpix,exptime

# %%
def curve(quasar,header,w,center,apparature):
    '''Determines the FLUX of the stellar object given the the numpy array of the image, \
    the header of the fits file, the astropy coordinate representation, \
    the object position and the apparature of interest'''
    header,AGNdata,RAstd,DECstd,pixspa,RAstdpix,DECstdpix,exptime = Basic(quasar,header)
    #AGNdata = np.swapaxes(AGNdata,0,1)
    y, x = np.ogrid[0:header['NAXIS1'],0:header['NAXIS1']]
    #w = np.swapaxes(w,0,1)
    #F_AGN = np.zeros((512,512,3)) #((int(2*apparature/pixspa)+1,int(2*apparature/pixspa)+1,3))
    #print center
    x1 = w.all_world2pix(center[0],center[1],0)
    x1,y1 = (x1[0]),(x1[1])
    if 15 < x1 < header['NAXIS1'] - 15 and 15 < y1 < header['NAXIS2'] - 15:
        try:
            mask = ((y-y1)**2 + (x-x1)**2) > (apparature/float(pixspa))**2
            AGNdata[mask] = float(0)
            mask = AGNdata == 0.
            rows = np.flatnonzero((~mask).sum(axis=1))
            cols = np.flatnonzero((~mask).sum(axis=0))
            AGNdata = AGNdata[rows.min():rows.max()+1, cols.min():cols.max()+1]
            #print apparature/float(pixspa)
        except:
            AGNdata = np.array([[float('nan'),float('nan')],[float('nan'),float('nan')]])
    else:
        AGNdata = np.array([[float('nan'),float('nan')],[float('nan'),float('nan')]])
    #if np.sum(AGNdata) < 500:
    #    AGNdata = np.array([[float('nan'),float('nan')],[float('nan'),float('nan')]])
    return AGNdata, x1, y1

# %%
def comp1(qua,sta):
    '''Code to determine the relation between the AGN and the Stellar flux as determined by either me \
    or by the SExtractor program respectively'''
    comp = qua/sta
    return comp

# %%
def SXtable(quas,aperture):
    header = pyfits.getheader(quas)
    phot_app = aperture*3600/header['PIXSCALE']
    np.set_printoptions(threshold=np.inf)
    sew = sewpy.SEW(params=['XMODEL_WORLD', 'YMODEL_WORLD', 'X2MODEL_WORLD', 'Y2MODEL_WORLD', 
                            'XMODEL_IMAGE', 'YMODEL_IMAGE', 'FLUX_RADIUS(1)', 'FLUX_APER','ELLIPTICITY'],
                    config={"DETECT_THRESH":3, 'DETECT_MINAREA':5, 'DETECT_MAXAREA':10000, 
                            "PHOT_FLUXFRAC":"0.5", 'PHOT_APERTURES':2*phot_app, 
                            'PIXEL_SCALE':header['PIXSCALE']}
                    , sexpath='/usr/bin/sextractor')
    out = sew(quas)
    print out
    return out

# %%
def flux(quas,aperture,main_RA_WORLD,main_DEC_WORLD):
    header = pyfits.getheader(quas)
    RAmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,1)[0]
    DECmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,1)[1]
    output = float('nan')
    if 15 < RAmain < header['NAXIS1'] - 15 and 15 < DECmain < header['NAXIS2'] - 15: 
        out = SXtable(quas,aperture)
        RAmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,0)[0]
        DECmain = WCS(quas).all_world2pix(main_RA_WORLD,main_DEC_WORLD,0)[1]
        #print out['table']['XMODEL_IMAGE'], out['table']['YMODEL_IMAGE']
        #print RAmain, DECmain

        for j in range(len(out['table']['XMODEL_IMAGE'])):
            #output['time'][i] = header['MJD-OBS']
            if RAmain - 10. < out['table']['XMODEL_IMAGE'][j] <  RAmain + 10. and \
            DECmain - 10. < out['table']['YMODEL_IMAGE'][j] < DECmain + 10.:
                #print 'YES'
                output = out['table']['FLUX_APER'][j]
                break
    else:
        output = float('nan')
        #print 'Done'
    return output

# %%
def SNR(data1,data2,header,ap1,ap2):
    npix1 = np.pi*ap1**2/((header['PIXSCALE']/3600.)**2)
    npix2 = np.pi*ap2**2/((header['PIXSCALE']/3600.)**2)
    #data2_1 = ((data2-data1)/npix2)*npix1
    data1_2 = data1
    data2_2 = abs(data2)
    
    return float(header['GAIN'])*data1_2*header['DIT']*header['NDIT']/(np.sqrt
                                                        (float(header['GAIN'])*data1_2*header['DIT']*header['NDIT'] 
                                                         + float(header['GAIN'])*npix1*data2_2*header['DIT']
                                                         *header['NDIT']
                                                         +header['NDIT']*npix1*header['RON']**2))

def SNR11(data1,data2,header,ap1,ap2):
    npix1 = np.pi*ap1**2/((header['PIXSCALE']/3600.)**2)
    npix2 = np.pi*ap2**2/((header['PIXSCALE']/3600.)**2)
    #data2_1 = ((data2-data1)/npix2)*npix1
    data1_2 = data1
    data2_2 = abs(data2)
    
    return float(((header['GAIN'])*data1_2*header['DIT']*header['NDIT']))

def SNR22(data1,data2,header,ap1,ap2):
    npix1 = np.pi*ap1**2/((header['PIXSCALE']/3600.)**2)
    npix2 = np.pi*ap2**2/((header['PIXSCALE']/3600.)**2)
    #data2_1 = ((data2-data1)/npix2)*npix1
    data1_2 = data1
    data2_2 = abs(data2)
    
    return float(header['GAIN']*npix1*data2_2*header['DIT']*header['NDIT'])

def SNR33(data1,data2,header,ap1,ap2):
    npix1 = np.pi*ap1**2/((header['PIXSCALE']/3600.)**2)
    npix2 = np.pi*ap2**2/((header['PIXSCALE']/3600.)**2)
    #data2_1 = ((data2-data1)/npix2)*npix1
    data1_2 = data1
    data2_2 = abs(data2)
    
    return float((header['NDIT']*npix1*header['RON']**2))

def SNR44(data1,data2,header,ap1,ap2):
    npix1 = np.pi*ap1**2/((header['PIXSCALE']/3600.)**2)
    npix2 = np.pi*ap2**2/((header['PIXSCALE']/3600.)**2)
    #data2_1 = ((data2-data1)/npix2)*npix1
    data1_2 = data1
    data2_2 = abs(data2)
    
    return float(((header['GAIN'])*data1_2*header['DIT']*header['NDIT'] + 
                  header['GAIN']*npix1*data2_2*header['DIT']*header['NDIT'] +
                  header['NDIT']*npix1*header['RON']**2))

#SNRas(10.,data1_2,abs(data2_2),0,header['RON'],npix1,gain=header['GAIN'])

# %%
for i in range(len(quas_K)):
    data, header = fits.getdata(quas_K[i],header=True) #RA---TAN
    #print header['CTYPE2']
    #header['CTYPE1'] = "RA---TAN"
    #header['CTYPE2'] = "DEC--TAN"
    header['NDIT'] = 5
    '''header['A_ORDER'] = "0"
    header['B_ORDER'] = "0"
    header['AP_ORDER'] = "0"
    header['BP_ORDER'] = "0"
    header['A_0_2'] = "0"
    header['A_1_1'] = "0"
    header['A_2_0'] = "0"
    header['B_0_2'] = "0"
    header['B_1_1'] = "0"
    header['B_2_0'] = "0"
    header['AP_0_2'] = "0"
    header['AP_1_1'] = "0"
    header['AP_2_0'] = "0"
    header['AP_0_1'] = "0"
    header['AP_1_0'] = "0"
    header['BP_0_1'] = "0"
    header['BP_0_2'] = "0"
    header['BP_1_0'] = "0"
    header['BP_1_1'] = "0"
    header['BP_2_0'] = "0"'''
    fits.writeto(quas_K[i],data,header,clobber=True)
    #print fits.getheader(quasH[i])['A_ORDER']
    
for i in range(len(quas_H)):
    data, header = fits.getdata(quas_H[i],header=True) #RA---TAN
    #print header['CTYPE2']
    #header['CTYPE1'] = "RA---TAN"
    #header['CTYPE2'] = "DEC--TAN"
    header['NDIT'] = 5
    '''header['A_ORDER'] = "0"
    header['B_ORDER'] = "0"
    header['AP_ORDER'] = "0"
    header['BP_ORDER'] = "0"
    header['A_0_2'] = "0"
    header['A_1_1'] = "0"
    header['A_2_0'] = "0"
    header['B_0_2'] = "0"
    header['B_1_1'] = "0"
    header['B_2_0'] = "0"
    header['AP_0_2'] = "0"
    header['AP_1_1'] = "0"
    header['AP_2_0'] = "0"
    header['AP_0_1'] = "0"
    header['AP_1_0'] = "0"
    header['BP_0_1'] = "0"
    header['BP_0_2'] = "0"
    header['BP_1_0'] = "0"
    header['BP_1_1'] = "0"
    header['BP_2_0'] = "0"'''
    fits.writeto(quas_H[i],data,header,clobber=True)
    #print fits.getheader(quasH[i])['A_ORDER']

for i in range(len(quas_J)):
    data, header = fits.getdata(quas_J[i],header=True) #RA---TAN
    #print header['CTYPE2']
    #header['CTYPE1'] = "RA---TAN"
    #header['CTYPE2'] = "DEC--TAN"
    header['NDIT'] = 5
    '''header['A_ORDER'] = "0"
    header['B_ORDER'] = "0"
    header['AP_ORDER'] = "0"
    header['BP_ORDER'] = "0"
    header['A_0_2'] = "0"
    header['A_1_1'] = "0"
    header['A_2_0'] = "0"
    header['B_0_2'] = "0"
    header['B_1_1'] = "0"
    header['B_2_0'] = "0"
    header['AP_0_2'] = "0"
    header['AP_1_1'] = "0"
    header['AP_2_0'] = "0"
    header['AP_0_1'] = "0"
    header['AP_1_0'] = "0"
    header['BP_0_1'] = "0"
    header['BP_0_2'] = "0"
    header['BP_1_0'] = "0"
    header['BP_1_1'] = "0"
    header['BP_2_0'] = "0"'''
    fits.writeto(quas_J[i],data,header,clobber=True)
    #print fits.getheader(quasH[i])['A_ORDER']
# Out:
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]

# %%
def error(SIGNAL_AGN,SIGNAL_STAR,SNR_AGN,SNR_STAR,STAR_MAG,STAR_MAG_err,VEGA_FLUX,VEGA_MAG):
    
    SIGNAL_ERR = abs(SIGNAL_AGN/SIGNAL_STAR)*np.sqrt(SNR_AGN**(-2) + SNR_STAR**(-2))
    
    FLUX_CAL_ERR = STAR_MAG_err
    
    SIGNAL = VEGA_FLUX*10**((VEGA_MAG-STAR_MAG)/2.5)
    
    FLUX_CAL = abs(SIGNAL_AGN/SIGNAL_STAR)*VEGA_FLUX*((np.log(10)/2.5)*10**((VEGA_MAG - STAR_MAG)/2.5))
    
    return np.sqrt((SIGNAL**2*SIGNAL_ERR**2 + FLUX_CAL**2*FLUX_CAL_ERR**2))

# %%
def relerror(SIGNAL_AGN,SIGNAL_STAR,SNR_AGN,SNR_STAR,STAR_MAG,STAR_MAG_err,VEGA_FLUX,VEGA_MAG):
    
    SIGNAL_ERR = abs(SIGNAL_AGN/SIGNAL_STAR)*np.sqrt(SNR_AGN**(-2) + SNR_STAR**(-2))
    
    SIGNAL = VEGA_FLUX*10**((VEGA_MAG-STAR_MAG)/2.5)
    
    return np.sqrt((SIGNAL**2*SIGNAL_ERR**2))

# %%
def SEXAGNflux(quas,aperture1):
    aperture2 = aperture1 + 0.003
    date = []
    flucompsta1 = []
    flucompsta2 = []
    flucompsta3 = []
    flucompsta4 = []
    flucompsta5 = []
    flucompsta6 = []
    flucompsta7 = []
    poissonAGN = []
    poisson529 = []
    poisson22 = []
    poissonHD = []
    ABS_FLUX_LAMBDA_1 = 0
    ABS_FLUX_LAMBDA_2 = 0
    ABS_FLUX_LAMBDA_3 = 0
    ABS_FLUX_V_1 = 0
    ABS_FLUX_V_2 = 0
    ABS_FLUX_V_3 = 0
    SNR_comp = []
    comp_array = np.zeros((len(quas),6))
    SNR_array = np.zeros((len(quas),8))
    SNR_part = np.zeros((len(quas),5))
    SNR_star = np.zeros((len(quas),4))
    noise_quasar = np.zeros((len(quas),7))
    signal = np.zeros((len(quas),4))
    #-----------------------------------------------------------------------------------------------
    for i in range(len(quas)):
        print 'Frame nr. ', i, quas[i]
        header = pyfits.getheader(quas[i])
        a_AGN = flux(quas[i],2*aperture1,qua1_RA_WORLD,qua1_DEC_WORLD)/header['DIT']
        a2 = flux(quas[i],2*aperture1,sta1_RA_WORLD,sta1_DEC_WORLD)/header['DIT']
        a3 = flux(quas[i],2*aperture1,sta2_RA_WORLD,sta2_DEC_WORLD)/header['DIT']
        a4 = flux(quas[i],2*aperture1,sta3_RA_WORLD,sta3_DEC_WORLD)/header['DIT']
        a_sky1 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky1_RA_WORLD,sky1_DEC_WORLD),aperture1)[0]/header['DIT']
        a_sky2 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky2_RA_WORLD,sky2_DEC_WORLD),aperture1)[0]/header['DIT']
        a_sky3 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky3_RA_WORLD,sky3_DEC_WORLD),aperture1)[0]/header['DIT']
        #a_AGN_1 = flux(quas[i],2*aperture2,qua1_RA_WORLD,qua1_DEC_WORLD)/header['DIT']
        #a2_1 = flux(quas[i],2*aperture2,sta1_RA_WORLD,sta1_DEC_WORLD)/header['DIT']
        #a3_1 = flux(quas[i],2*aperture2,sta2_RA_WORLD,sta2_DEC_WORLD)/header['DIT']
        #a4_1 = flux(quas[i],2*aperture2,sta3_RA_WORLD,sta3_DEC_WORLD)/header['DIT']
        signal[i,0] = a_AGN
        signal[i,1] = a2
        signal[i,2] = a3
        signal[i,3] = a4
        #-------------------------------------------------------------------------------------------
        #plt.figure(figsize=(3,3))
        #plt.imshow(a2)
        #plt.show()
        #-------------------------------------------------------------------------------------------
        a_AGN_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a2_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a3_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a4_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a_sky_pix = np.count_nonzero(a_sky1)
        a_sky_2 = np.sum(a_sky1)/float(np.count_nonzero(a_sky1))
        a_sky = np.concatenate((a_sky1.ravel(),a_sky2.ravel(),a_sky3.ravel()),axis=0)
        a_sky_var = np.nanvar(a_sky)
        #print header['MJD-OBS']
        print a_sky_2,a_sky_var
        #a_AGN_pix_1 = np.pi*(2*aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a2_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a3_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a4_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a_AGN_2 = (np.sum(a_AGN_1) - np.sum(a_AGN))/(float(np.count_nonzero(a_AGN_1)) - float(np.count_nonzero(a_AGN)))
        #a2_2 = (np.sum(a2_1) - np.sum(a2))/(float(np.count_nonzero(a2_1)) - float(np.count_nonzero(a2)))
        #a3_2 = (np.sum(a3_1) - np.sum(a3))/(float(np.count_nonzero(a3_1)) - float(np.count_nonzero(a3)))
        #a4_2 = (np.sum(a4_1) - np.sum(a4))/(float(np.count_nonzero(a4_1)) - float(np.count_nonzero(a4)))
        a_AGN_3 = a_AGN/a_AGN_pix #- (a_AGN_1 - a_AGN)/(a_AGN_pix_1 - a_AGN_pix) #Background subtracted flux/pixel/sec
        a2_3 = a2/a2_pix #- (a2_1 - a2)/(a2_pix_1 - a2_pix)
        a3_3 = a3/a3_pix #- (a3_1 - a3)/(a3_pix_1 - a3_pix)
        a4_3 = a4/a4_pix #- (a4_1 - a4)/(a4_pix_1 - a4_pix)
        #-------------------------------------------------------------------------------------------
        date.append(header['MJD-OBS'])
        #-------------------------------------------------------------------------------------------
        poissonAGN.append(np.sqrt(np.sum(a_AGN)*header['DIT']*header['GAIN'])) #header['DIT']))
        poissonHD.append(np.sqrt(np.sum(a2)*header['DIT']*header['GAIN'])) #header['DIT']))
        poisson22.append(np.sqrt(np.sum(a3)*header['DIT']*header['GAIN'])) #header['DIT']))
        poisson529.append(np.sqrt(np.sum(a4)*header['DIT']*header['GAIN'])) #header['DIT']))
        #-------------------------------------------------------------------------------------------
        #if SNR1[i] < 70:
        #    flucompsta_AGN.append(float('nan'))
        #    flucompsta2.append(float('nan'))
        #    flucompsta3.append(float('nan'))
        #    flucompsta4.append(float('nan'))
        #    flucompsta6.append(float('nan'))
        #    comp_array[i,0] = int(date[i])
        #    comp_array[i,1] = float('nan')
        #    comp_array[i,2] = float('nan')
        #    comp_array[i,3] = float('nan')
        #else:
        flucompsta1.append(comp1(a_AGN_3,a2_3))
        flucompsta2.append(comp1(a_AGN_3,a3_3))
        flucompsta3.append(comp1(a_AGN_3,a4_3))
        SNR1 = SNR(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        #flucompsta4.append(comp1(a_AGN_3,a5_3))
        #flucompsta5.append(comp1(a_AGN_3,a6_3))
        #flucompsta6.append(comp1(a_AGN_3,a7_3))
        comp_array[i,0] = int(date[i])
        comp_array[i,1] = flucompsta1[i]
        comp_array[i,2] = flucompsta2[i]
        comp_array[i,3] = flucompsta3[i]
        comp_array[i,4] = SNR1
        comp_array[i,5] = a_AGN
        #comp_array[i,5] = flucompsta5[i]
        #comp_array[i,6] = flucompsta6[i]
        print a_AGN, a2, a3, a4
        SNR_part[i,0] = date[i]
        SNR_part[i,1] = SNR(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,2] = SNR11(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,3] = SNR22(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,4] = SNR33(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,0] = header['MJD-OBS']
        SNR_star[i,1] = SNR(a2,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,2] = SNR(a3,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,3] = SNR(a4,np.sum(a_sky),header,aperture1,aperture1)
        noise_quasar[i,0] = header['MJD-OBS']
        noise_quasar[i,1] = float('nan')
        noise_quasar[i,2] = float('nan')
        noise_quasar[i,3] = float('nan')
        #SNR_array[i,0] = int(date[i])
        #SNR_array[i,1] = SNR(a_AGN,a_sky,header,aperture1,aperture1)
        #SNR_array[i,2] = SNR(a2,a_sky,header,aperture1,aperture1)
        #SNR_array[i,3] = SNR(a3,a_sky,header,aperture1,aperture1)
        #SNR_array[i,4] = SNR(a4,a_sky,header,aperture1,aperture1)
        #SNR_array[i,5] = SNR(a5,a_sky,header,aperture1,aperture1)
        #SNR_array[i,6] = SNR(a6,a_sky,header,aperture1,aperture1)
        #SNR_array[i,7] = SNR(a7,a_sky,header,aperture1,aperture1)
    #print 'YES'
    #-----------------------------------------------------------------------------------------------
    poissonAGN = np.array(poissonAGN)
    poissonHD = np.array(poissonHD)
    poisson22 = np.array(poisson22)
    poisson529 = np.array(poisson529)
    comp_array = comp_array[comp_array[:,0].argsort()]
    
    comp_array[:,1] = comp_array[:,1]*flux_cal(MAG_STA1_K,MAG_VEGA_K,FLUX_LAMBDA_VEGA_K)
    comp_array[:,2] = comp_array[:,2]*flux_cal(MAG_STA2_K,MAG_VEGA_K,FLUX_LAMBDA_VEGA_K)
    comp_array[:,3] = comp_array[:,3]*flux_cal(MAG_STA3_K,MAG_VEGA_K,FLUX_LAMBDA_VEGA_K)
    
    noise_quasar[:,1] = error(signal[:,0],signal[:,1],SNR_part[:,1],SNR_star[:,1],MAG_STA1_K,\
                              MAG_err_STA1_K,FLUX_LAMBDA_VEGA_K,MAG_VEGA_K)
    noise_quasar[:,2] = error(signal[:,0],signal[:,2],SNR_part[:,1],SNR_star[:,2],MAG_STA2_K,\
                              MAG_err_STA2_K,FLUX_LAMBDA_VEGA_K,MAG_VEGA_K)
    noise_quasar[:,3] = error(signal[:,0],signal[:,3],SNR_part[:,1],SNR_star[:,3],MAG_STA3_K,\
                              MAG_err_STA3_K,FLUX_LAMBDA_VEGA_K,MAG_VEGA_K)
    
    noise_quasar[:,4] = relerror(signal[:,0],signal[:,1],SNR_part[:,1],SNR_star[:,1],MAG_STA1_K,\
                              MAG_err_STA1_K,FLUX_LAMBDA_VEGA_K,MAG_VEGA_K)
    noise_quasar[:,5] = relerror(signal[:,0],signal[:,2],SNR_part[:,1],SNR_star[:,2],MAG_STA2_K,\
                              MAG_err_STA2_K,FLUX_LAMBDA_VEGA_K,MAG_VEGA_K)
    noise_quasar[:,6] = relerror(signal[:,0],signal[:,3],SNR_part[:,1],SNR_star[:,3],MAG_STA3_K,\
                              MAG_err_STA3_K,FLUX_LAMBDA_VEGA_K,MAG_VEGA_K)

    #-----------------------------------------------------------------------------------------------
    return comp_array,SNR_array,ABS_FLUX_LAMBDA_1,ABS_FLUX_LAMBDA_2,ABS_FLUX_LAMBDA_3,\
ABS_FLUX_V_1,ABS_FLUX_V_2,ABS_FLUX_V_3,date,SNR_part,SNR_star,noise_quasar

# %%
comp_array,SNR_array,ABS_FLUX_LAMBDA_1_1,ABS_FLUX_LAMBDA_2_1,ABS_FLUX_LAMBDA_3_1,\
ABS_FLUX_V_1_1,ABS_FLUX_V_2_1,ABS_FLUX_V_3_1,date_1,SNR_part_1,SNR_star_1,noise_quasar_1 = SEXAGNflux(quas_K,0.0007)
# Out:
# Frame nr.  0 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (20)
# WARNING: FITSFixedWarning: RADECSYS= 'ICRS ' / [string] Coordinates reference sys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units: 'degrees' -> 'deg', 'degrees' -> 'deg''. [astropy.wcs.wcs]
# No handlers could be found for logger "sewpy.sewpy"
# {'catfilepath': '/tmp/sewpy_workdir_vTP84_/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_vTP84_/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_vTP84_'}
# {'catfilepath': '/tmp/sewpy_workdir_gQPT2X/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_gQPT2X/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_gQPT2X'}
# {'catfilepath': '/tmp/sewpy_workdir_qZPsIm/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_qZPsIm/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_qZPsIm'}
# {'catfilepath': '/tmp/sewpy_workdir_V_wfFm/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_V_wfFm/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_V_wfFm'}
# -0.10000000000000003 1.0644193786982248
# nan nan nan nan
# Frame nr.  1 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (8)
# {'catfilepath': '/tmp/sewpy_workdir_lwhaJC/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_lwhaJC/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_lwhaJC'}
# {'catfilepath': '/tmp/sewpy_workdir_zgL6Wz/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_zgL6Wz/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_zgL6Wz'}
# {'catfilepath': '/tmp/sewpy_workdir_TUl3kX/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_TUl3kX/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_TUl3kX'}
# {'catfilepath': '/tmp/sewpy_workdir_3KLwoq/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_3KLwoq/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_3KLwoq'}
# 0.10000000000000002 1.7158333333333333
# nan nan nan nan
# Frame nr.  2 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (6)
# {'catfilepath': '/tmp/sewpy_workdir_7yMEfs/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_7yMEfs/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_7yMEfs'}
# {'catfilepath': '/tmp/sewpy_workdir_TK739v/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_TK739v/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_TK739v'}
# {'catfilepath': '/tmp/sewpy_workdir_oGT5me/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_oGT5me/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_oGT5me'}
# 0.23177083333333334 1.2394376
# nan nan nan nan
# Frame nr.  3 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (38)
# {'catfilepath': '/tmp/sewpy_workdir_xg5rFC/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_xg5rFC/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_xg5rFC'}
# {'catfilepath': '/tmp/sewpy_workdir_rmzV6b/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_rmzV6b/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_rmzV6b'}
# {'catfilepath': '/tmp/sewpy_workdir_bX4h4R/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_bX4h4R/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_bX4h4R'}
# 0.9307692601130559 0.9635909
# nan nan nan nan
# Frame nr.  4 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (10)
# {'catfilepath': '/tmp/sewpy_workdir_JrGWd2/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_JrGWd2/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_JrGWd2'}
# {'catfilepath': '/tmp/sewpy_workdir_PTxpVU/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_PTxpVU/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_PTxpVU'}
# {'catfilepath': '/tmp/sewpy_workdir_pcEtWW/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_pcEtWW/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_pcEtWW'}
# {'catfilepath': '/tmp/sewpy_workdir_dVCLYV/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_dVCLYV/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_dVCLYV'}
# 0.6000000408717564 2.359566
# nan nan nan nan
# Frame nr.  5 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (28)
# {'catfilepath': '/tmp/sewpy_workdir_WxcW7Q/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_WxcW7Q/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_WxcW7Q'}
# {'catfilepath': '/tmp/sewpy_workdir_l1L5Aw/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_l1L5Aw/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_l1L5Aw'}
# {'catfilepath': '/tmp/sewpy_workdir_rYnMK9/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_rYnMK9/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_rYnMK9'}
# {'catfilepath': '/tmp/sewpy_workdir_e88nKQ/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_e88nKQ/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_e88nKQ'}
# 1.0583333333333333 2.0046831597222226
# nan nan nan nan
# Frame nr.  6 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (1)
# {'catfilepath': '/tmp/sewpy_workdir_ir1qPM/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ir1qPM/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_ir1qPM'}
# {'catfilepath': '/tmp/sewpy_workdir_Mbfk4V/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_
# 196.63123049 -40.497322679 2.8943974958e-07 ...  17918.03       0.128
# 196.49002801 -40.484037231 6.9961642988e-06 ...   2122.39       0.447
# 196.55412363 -40.510961643 8.2125586623e-07 ...  54199.62       0.078
# 196.57014535 -40.380716032 0.00044045318232 ...   1278.73       0.323
# 196.54200112 -40.380218113 3.6452356372e-06 ...  3713.834       0.226
# 196.58664284 -40.400330148 6.2806450288e-08 ...  279701.9       0.163, 'logfilepath': '/tmp/sewpy_workdir_owwTB4/ESO323_5_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_owwTB4'}
# 0.41428571428571426 2.1824999999999997
# 3230.652 1525.4879999999998 27970.190000000002 1791.8029999999999
# Frame nr.  8 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (34)
# {'catfilepath': '/tmp/sewpy_workdir_F40rps/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_F40rps/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_F40rps'}
# {'catfilepath': '/tmp/sewpy_workdir_tDhuCI/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_tDhuCI/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_tDhuCI'}
# {'catfilepath': '/tmp/sewpy_workdir_5peSxD/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_5peSxD/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_5peSxD'}
# 1.028571401323591 1.184809
# nan nan nan nan
# Frame nr.  9 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (24)
# {'catfilepath': '/tmp/sewpy_workdir_JIDhOo/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_JIDhOo/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_JIDhOo'}
# {'catfilepath': '/tmp/sewpy_workdir_iIZzMg/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_iIZzMg/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_iIZzMg'}
# {'catfilepath': '/tmp/sewpy_workdir_6zpVlo/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_6zpVlo/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_6zpVlo'}
# 0.9916667143503824 0.9196153
# nan nan nan nan
# Frame nr.  10 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (14)
# {'catfilepath': '/tmp/sewpy_workdir_jbKmBs/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_jbKmBs/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_jbKmBs'}
# {'catfilepath': '/tmp/sewpy_workdir_kf2OMr/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_kf2OMr/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_kf2OMr'}
# {'catfilepath': '/tmp/sewpy_workdir_YtT_EP/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_YtT_EP/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_YtT_EP'}
# 1.0181818008422852 1.7925893
# nan nan nan nan
# Frame nr.  11 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (11)
# {'catfilepath': '/tmp/sewpy_workdir_bsGwJV/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_bsGwJV/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_bsGwJV'}
# {'catfilepath': '/tmp/sewpy_workdir_CzsvTh/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_CzsvTh/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_CzsvTh'}
# {'catfilepath': '/tmp/sewpy_workdir_z9bt8M/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_z9bt8M/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_z9bt8M'}
# 0.21818184852600098 1.8586416
# nan nan nan nan
# Frame nr.  12 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (31)
# {'catfilepath': '/tmp/sewpy_workdir_ilHIcn/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ilHIcn/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_ilHIcn'}
# {'catfilepath': '/tmp/sewpy_workdir_lf0xzQ/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_lf0xzQ/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_lf0xzQ'}
# {'catfilepath': '/tmp/sewpy_workdir_L8htPQ/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_L8htPQ/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_L8htPQ'}
# 0.274999996026357 2.6237328
# nan nan nan nan
# Frame nr.  13 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (32)
# {'catfilepath': '/tmp/sewpy_workdir_7SysH_/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_7SysH_/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_7SysH_'}
# {'catfilepath': '/tmp/sewpy_workdir_QyZ_Oy/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_QyZ_Oy/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_QyZ_Oy'}
# {'catfilepath': '/tmp/sewpy_workdir_0Fuaaj/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_0Fuaaj/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_0Fuaaj'}
# {'catfilepath': '/tmp/sewpy_workdir_C7PPZI/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_C7PPZI/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_C7PPZI'}
# 1.3571428571428572 2.0069675
# nan nan nan nan
# Frame nr.  14 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (25)
# {'catfilepath': '/tmp/sewpy_workdir_AKx4av/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_AKx4av/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_AKx4av'}
# {'catfilepath': '/tmp/sewpy_workdir_xIOTN7/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_xIOTN7/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_xIOTN7'}
# {'catfilepath': '/tmp/sewpy_workdir_knT_cK/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_knT_cK/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_knT_cK'}
# -0.8615385202261118 1.863954
# nan nan nan nan
# Frame nr.  15 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (39)
# {'catfilepath': '/tmp/sewpy_workdir_9MrueY/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_9MrueY/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_9MrueY'}
# WARNING: FITSFixedWarning: RADECSYS= ' ' / [string] Coordinates reference sys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# {'catfilepath': '/tmp/sewpy_workdir_o3qDly/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_o3qDly/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_o3qDly'}
# {'catfilepath': '/tmp/sewpy_workdir_GybRoi/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_GybRoi/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_GybRoi'}
# {'catfilepath': '/tmp/sewpy_workdir_6Nog0o/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_6Nog0o/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_6Nog0o'}
# 1.3916667302449544 7.181776
# nan nan nan nan
# Frame nr.  16 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (41)
# {'catfilepath': '/tmp/sewpy_workdir_ocPBX2/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ocPBX2/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_ocPBX2'}
# {'catfilepath': '/tmp/sewpy_workdir_qBrHy4/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_qBrHy4/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_qBrHy4'}
# {'catfilepath': '/tmp/sewpy_workdir_mkCpvR/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_mkCpvR/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_mkCpvR'}
# {'catfilepath': '/tmp/sewpy_workdir_AMQQ7a/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_AMQQ7a/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_AMQQ7a'}
# 0.0785714285714286 0.7034829346949745
# nan nan nan nan
# Frame nr.  17 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (21)
# {'catfilepath': '/tmp/sewpy_workdir_e4JWiN/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_e4JWiN/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_e4JWiN'}
# {'catfilepath': '/tmp/sewpy_workdir_5jLcRk/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_5jLcRk/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_5jLcRk'}
# {'catfilepath': '/tmp/sewpy_workdir_5fiXwg/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_5fiXwg/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_5fiXwg'}
# 0.4923076629638672 0.9840051
# nan nan nan nan
# Frame nr.  18 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (3)
# {'catfilepath': '/tmp/sewpy_workdir_JZEMep/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_JZEMep/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_JZEMep'}
# {'catfilepath': '/tmp/sewpy_workdir__7ulDW/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir__7ulDW/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir__7ulDW'}
# {'catfilepath': '/tmp/sewpy_workdir_n8O2CL/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_n8O2CL/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_n8O2CL'}
# -0.01696427379335676 1.2429057
# nan nan nan nan
# Frame nr.  19 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (5)
# {'catfilepath': '/tmp/sewpy_workdir_bSKcI6/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_bSKcI6/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_bSKcI6'}
# {'catfilepath': '/tmp/sewpy_workdir_lkCEMm/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_lkCEMm/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_lkCEMm'}
# {'catfilepath': '/tmp/sewpy_workdir_FUdVjR/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_FUdVjR/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_FUdVjR'}
# 0.13846157147334173 1.0010418
# nan nan nan nan
# Frame nr.  20 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (16)
# {'catfilepath': '/tmp/sewpy_workdir_6sHVxN/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_6sHVxN/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_6sHVxN'}
# {'catfilepath': '/tmp/sewpy_workdir_J3zGdT/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_J3zGdT/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_J3zGdT'}
# {'catfilepath': '/tmp/sewpy_workdir_LgXAN2/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_LgXAN2/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir_LgXAN2'}
# 1.1357142584664481 1.4002084
# nan nan nan nan
# Frame nr.  21 /../home/lynge/MasterP/ESO323/K/ESO323_3_10_K.fits (12)
# {'catfilepath': '/tmp/sewpy_workdir_fpgtIP/ESO323_3_10_K.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_fpgtIP/ESO323_3_10_K.log.txt', 'workdir': '/tmp/sewpy_workdir
.txt',noise_quasar_1)
np.savetxt('../NOVEMBER/NOV-ESO323-Ks7',comp_array)
np.savetxt('../NOVEMBER/ESO323_SNR_Ks7.txt',SNR_part_1)

# %%
def SEXAGNflux(quas,aperture1):
    aperture2 = aperture1 + 0.003
    date = []
    flucompsta1 = []
    flucompsta2 = []
    flucompsta3 = []
    flucompsta4 = []
    flucompsta5 = []
    flucompsta6 = []
    flucompsta7 = []
    poissonAGN = []
    poisson529 = []
    poisson22 = []
    poissonHD = []
    ABS_FLUX_LAMBDA_1 = 0
    ABS_FLUX_LAMBDA_2 = 0
    ABS_FLUX_LAMBDA_3 = 0
    ABS_FLUX_V_1 = 0
    ABS_FLUX_V_2 = 0
    ABS_FLUX_V_3 = 0
    SNR_comp = []
    comp_array = np.zeros((len(quas),6))
    SNR_array = np.zeros((len(quas),8))
    SNR_part = np.zeros((len(quas),5))
    SNR_star = np.zeros((len(quas),4))
    noise_quasar = np.zeros((len(quas),7))
    signal = np.zeros((len(quas),4))
    #-----------------------------------------------------------------------------------------------
    for i in range(len(quas)):
        print 'Frame nr. ', i, quas[i]
        header = pyfits.getheader(quas[i])
        a_AGN = flux(quas[i],2*aperture1,qua1_RA_WORLD,qua1_DEC_WORLD)/header['DIT']
        a2 = flux(quas[i],2*aperture1,sta1_RA_WORLD,sta1_DEC_WORLD)/header['DIT']
        a3 = flux(quas[i],2*aperture1,sta2_RA_WORLD,sta2_DEC_WORLD)/header['DIT']
        a4 = flux(quas[i],2*aperture1,sta3_RA_WORLD,sta3_DEC_WORLD)/header['DIT']
        a_sky1 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky1_RA_WORLD,sky1_DEC_WORLD),aperture1)[0]/header['DIT']
        a_sky2 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky2_RA_WORLD,sky2_DEC_WORLD),aperture1)[0]/header['DIT']
        a_sky3 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky3_RA_WORLD,sky3_DEC_WORLD),aperture1)[0]/header['DIT']
        #a_AGN_1 = flux(quas[i],2*aperture2,qua1_RA_WORLD,qua1_DEC_WORLD)/header['DIT']
        #a2_1 = flux(quas[i],2*aperture2,sta1_RA_WORLD,sta1_DEC_WORLD)/header['DIT']
        #a3_1 = flux(quas[i],2*aperture2,sta2_RA_WORLD,sta2_DEC_WORLD)/header['DIT']
        #a4_1 = flux(quas[i],2*aperture2,sta3_RA_WORLD,sta3_DEC_WORLD)/header['DIT']
        signal[i,0] = a_AGN
        signal[i,1] = a2
        signal[i,2] = a3
        signal[i,3] = a4
        #-------------------------------------------------------------------------------------------
        #plt.figure(figsize=(3,3))
        #plt.imshow(a2)
        #plt.show()
        #-------------------------------------------------------------------------------------------
        a_AGN_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a2_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a3_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a4_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a_sky_pix = np.count_nonzero(a_sky1)
        a_sky_2 = np.sum(a_sky1)/float(np.count_nonzero(a_sky1))
        a_sky = np.concatenate((a_sky1.ravel(),a_sky2.ravel(),a_sky3.ravel()),axis=0)
        a_sky_var = np.nanvar(a_sky)
        print a_sky_2,a_sky_var
        #a_AGN_pix_1 = np.pi*(2*aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a2_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a3_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a4_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a_AGN_2 = (np.sum(a_AGN_1) - np.sum(a_AGN))/(float(np.count_nonzero(a_AGN_1)) - float(np.count_nonzero(a_AGN)))
        #a2_2 = (np.sum(a2_1) - np.sum(a2))/(float(np.count_nonzero(a2_1)) - float(np.count_nonzero(a2)))
        #a3_2 = (np.sum(a3_1) - np.sum(a3))/(float(np.count_nonzero(a3_1)) - float(np.count_nonzero(a3)))
        #a4_2 = (np.sum(a4_1) - np.sum(a4))/(float(np.count_nonzero(a4_1)) - float(np.count_nonzero(a4)))
        a_AGN_3 = a_AGN/a_AGN_pix #- (a_AGN_1 - a_AGN)/(a_AGN_pix_1 - a_AGN_pix) #Background subtracted flux/pixel/sec
        a2_3 = a2/a2_pix #- (a2_1 - a2)/(a2_pix_1 - a2_pix)
        a3_3 = a3/a3_pix #- (a3_1 - a3)/(a3_pix_1 - a3_pix)
        a4_3 = a4/a4_pix #- (a4_1 - a4)/(a4_pix_1 - a4_pix)
        #-------------------------------------------------------------------------------------------
        date.append(header['MJD-OBS'])
        #-------------------------------------------------------------------------------------------
        poissonAGN.append(np.sqrt(np.sum(a_AGN)*header['DIT']*header['GAIN'])) #header['DIT']))
        poissonHD.append(np.sqrt(np.sum(a2)*header['DIT']*header['GAIN'])) #header['DIT']))
        poisson22.append(np.sqrt(np.sum(a3)*header['DIT']*header['GAIN'])) #header['DIT']))
        poisson529.append(np.sqrt(np.sum(a4)*header['DIT']*header['GAIN'])) #header['DIT']))
        #-------------------------------------------------------------------------------------------
        #if SNR1[i] < 70:
        #    flucompsta_AGN.append(float('nan'))
        #    flucompsta2.append(float('nan'))
        #    flucompsta3.append(float('nan'))
        #    flucompsta4.append(float('nan'))
        #    flucompsta6.append(float('nan'))
        #    comp_array[i,0] = int(date[i])
        #    comp_array[i,1] = float('nan')
        #    comp_array[i,2] = float('nan')
        #    comp_array[i,3] = float('nan')
        #else:
        flucompsta1.append(comp1(a_AGN_3,a2_3))
        flucompsta2.append(comp1(a_AGN_3,a3_3))
        flucompsta3.append(comp1(a_AGN_3,a4_3))
        SNR1 = SNR(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        #flucompsta4.append(comp1(a_AGN_3,a5_3))
        #flucompsta5.append(comp1(a_AGN_3,a6_3))
        #flucompsta6.append(comp1(a_AGN_3,a7_3))
        comp_array[i,0] = int(date[i])
        comp_array[i,1] = flucompsta1[i]
        comp_array[i,2] = flucompsta2[i]
        comp_array[i,3] = flucompsta3[i]
        comp_array[i,4] = SNR1
        comp_array[i,5] = a_AGN
        #comp_array[i,5] = flucompsta5[i]
        #comp_array[i,6] = flucompsta6[i]
        print a_AGN, a2, a3, a4
        SNR_part[i,0] = date[i]
        SNR_part[i,1] = SNR(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,2] = SNR11(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,3] = SNR22(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,4] = SNR33(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,0] = header['MJD-OBS']
        SNR_star[i,1] = SNR(a2,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,2] = SNR(a3,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,3] = SNR(a4,np.sum(a_sky),header,aperture1,aperture1)
        noise_quasar[i,0] = header['MJD-OBS']
        noise_quasar[i,1] = float('nan')
        noise_quasar[i,2] = float('nan')
        noise_quasar[i,3] = float('nan')
        #SNR_array[i,0] = int(date[i])
        #SNR_array[i,1] = SNR(a_AGN,a_sky,header,aperture1,aperture1)
        #SNR_array[i,2] = SNR(a2,a_sky,header,aperture1,aperture1)
        #SNR_array[i,3] = SNR(a3,a_sky,header,aperture1,aperture1)
        #SNR_array[i,4] = SNR(a4,a_sky,header,aperture1,aperture1)
        #SNR_array[i,5] = SNR(a5,a_sky,header,aperture1,aperture1)
        #SNR_array[i,6] = SNR(a6,a_sky,header,aperture1,aperture1)
        #SNR_array[i,7] = SNR(a7,a_sky,header,aperture1,aperture1)
    #print 'YES'
    #-----------------------------------------------------------------------------------------------
    poissonAGN = np.array(poissonAGN)
    poissonHD = np.array(poissonHD)
    poisson22 = np.array(poisson22)
    poisson529 = np.array(poisson529)
    comp_array = comp_array[comp_array[:,0].argsort()]
    
    comp_array[:,1] = comp_array[:,1]*flux_cal(MAG_STA1_H,MAG_VEGA_H,FLUX_LAMBDA_VEGA_H)
    comp_array[:,2] = comp_array[:,2]*flux_cal(MAG_STA2_H,MAG_VEGA_H,FLUX_LAMBDA_VEGA_H)
    comp_array[:,3] = comp_array[:,3]*flux_cal(MAG_STA3_H,MAG_VEGA_H,FLUX_LAMBDA_VEGA_H)
    
    noise_quasar[:,1] = error(signal[:,0],signal[:,1],SNR_part[:,1],SNR_star[:,1],MAG_STA1_H,\
                              MAG_err_STA1_H,FLUX_LAMBDA_VEGA_H,MAG_VEGA_H)
    noise_quasar[:,2] = error(signal[:,0],signal[:,2],SNR_part[:,1],SNR_star[:,2],MAG_STA2_H,\
                              MAG_err_STA2_H,FLUX_LAMBDA_VEGA_H,MAG_VEGA_H)
    noise_quasar[:,3] = error(signal[:,0],signal[:,3],SNR_part[:,1],SNR_star[:,3],MAG_STA3_H,\
                              MAG_err_STA3_H,FLUX_LAMBDA_VEGA_H,MAG_VEGA_H)
    
    noise_quasar[:,4] = relerror(signal[:,0],signal[:,1],SNR_part[:,1],SNR_star[:,1],MAG_STA1_H,\
                              MAG_err_STA1_H,FLUX_LAMBDA_VEGA_H,MAG_VEGA_H)
    noise_quasar[:,5] = relerror(signal[:,0],signal[:,2],SNR_part[:,1],SNR_star[:,2],MAG_STA2_H,\
                              MAG_err_STA2_H,FLUX_LAMBDA_VEGA_H,MAG_VEGA_H)
    noise_quasar[:,6] = relerror(signal[:,0],signal[:,3],SNR_part[:,1],SNR_star[:,3],MAG_STA3_H,\
                              MAG_err_STA3_H,FLUX_LAMBDA_VEGA_H,MAG_VEGA_H)

    #-----------------------------------------------------------------------------------------------
    return comp_array,SNR_array,ABS_FLUX_LAMBDA_1,ABS_FLUX_LAMBDA_2,ABS_FLUX_LAMBDA_3,\
ABS_FLUX_V_1,ABS_FLUX_V_2,ABS_FLUX_V_3,date,SNR_part,SNR_star,noise_quasar

# %%
comp_array,SNR_array,ABS_FLUX_LAMBDA_1_1,ABS_FLUX_LAMBDA_2_1,ABS_FLUX_LAMBDA_3_1,\
ABS_FLUX_V_1_1,ABS_FLUX_V_2_1,ABS_FLUX_V_3_1,date_1,SNR_part_1,SNR_star_1,noise_quasar_1 = SEXAGNflux(quas_H,0.0007)
# Out:
# Frame nr.  0 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (1)
# {'catfilepath': '/tmp/sewpy_workdir_2PmeKn/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_2PmeKn/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_2PmeKn'}
# {'catfilepath': '/tmp/sewpy_workdir__emuY4/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir__emuY4/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir__emuY4'}
# {'catfilepath': '/tmp/sewpy_workdir_nIneMY/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_nIneMY/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_nIneMY'}
# -0.36923078390268177 1.0603957
# nan nan nan nan
# Frame nr.  1 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (45)
# {'catfilepath': '/tmp/sewpy_workdir_HoWm3C/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_HoWm3C/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_HoWm3C'}
# {'catfilepath': '/tmp/sewpy_workdir_qJ7ne_/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_qJ7ne_/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_qJ7ne_'}
# {'catfilepath': '/tmp/sewpy_workdir_vq24QA/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_vq24QA/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_vq24QA'}
# {'catfilepath': '/tmp/sewpy_workdir_eYtlc5/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_eYtlc5/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_eYtlc5'}
# -1.4642857142857142 1.9244082
# nan nan nan nan
# Frame nr.  2 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (14)
# {'catfilepath': '/tmp/sewpy_workdir_ccGjW5/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ccGjW5/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_ccGjW5'}
# {'catfilepath': '/tmp/sewpy_workdir_7invMZ/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_7invMZ/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_7invMZ'}
# {'catfilepath': '/tmp/sewpy_workdir_q7KAEJ/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_q7KAEJ/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_q7KAEJ'}
# -0.2642857347215925 0.44916233
# nan nan nan nan
# Frame nr.  3 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (22)
# {'catfilepath': '/tmp/sewpy_workdir_UHdT6j/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_UHdT6j/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_UHdT6j'}
# {'catfilepath': '/tmp/sewpy_workdir_F6C5_7/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_F6C5_7/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_F6C5_7'}
# {'catfilepath': '/tmp/sewpy_workdir_u9OrYh/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_u9OrYh/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_u9OrYh'}
# {'catfilepath': '/tmp/sewpy_workdir_9QFslz/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_9QFslz/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_9QFslz'}
# -1.0153846153846153 0.8016620498614957
# nan nan nan nan
# Frame nr.  4 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (8)
# {'catfilepath': '/tmp/sewpy_workdir_dLagvp/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_dLagvp/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_dLagvp'}
# {'catfilepath': '/tmp/sewpy_workdir_xfFWzC/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_xfFWzC/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_xfFWzC'}
# {'catfilepath': '/tmp/sewpy_workdir_ZrXwEM/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ZrXwEM/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_ZrXwEM'}
# {'catfilepath': '/tmp/sewpy_workdir_h_dTHc/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_h_dTHc/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_h_dTHc'}
# -0.9692307692307692 0.7551498724489795
# nan nan nan nan
# Frame nr.  5 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (15)
# {'catfilepath': '/tmp/sewpy_workdir_07qOhN/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_07qOhN/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_07qOhN'}
# {'catfilepath': '/tmp/sewpy_workdir_UehHdY/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_UehHdY/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_UehHdY'}
# {'catfilepath': '/tmp/sewpy_workdir_6I1CFT/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_6I1CFT/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_6I1CFT'}
# {'catfilepath': '/tmp/sewpy_workdir_1eRKuF/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_1eRKuF/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_1eRKuF'}
# -0.2833333333333333 0.3629437869822486
# nan nan nan nan
# Frame nr.  6 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (11)
# {'catfilepath': '/tmp/sewpy_workdir_6dkKxx/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_6dkKxx/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_6dkKxx'}
# {'catfilepath': '/tmp/sewpy_workdir_xhMhvB/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_xhMhvB/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_xhMhvB'}
# {'catfilepath': '/tmp/sewpy_workdir_vBs1vz/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_vBs1vz/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_vBs1vz'}
# -0.23076923076923078 0.30026042
# nan nan nan nan
# Frame nr.  7 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (44)
# {'catfilepath': '/tmp/sewpy_workdir_0QiYEH/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_0QiYEH/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_0QiYEH'}
# {'catfilepath': '/tmp/sewpy_workdir_X0eJOX/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_X0eJOX/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_X0eJOX'}
# {'catfilepath': '/tmp/sewpy_workdir_Bckg9p/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_Bckg9p/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_Bckg9p'}
# -0.9142856597900391 0.59831595
# nan nan nan nan
# Frame nr.  8 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (34)
# {'catfilepath': '/tmp/sewpy_workdir_q0xM2l/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_q0xM2l/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_q0xM2l'}
# {'catfilepath': '/tmp/sewpy_workdir_JhTzwT/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_JhTzwT/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_JhTzwT'}
# {'catfilepath': '/tmp/sewpy_workdir_ExESrz/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ExESrz/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_ExESrz'}
# -0.09166666865348816 0.61860675
# nan nan nan nan
# Frame nr.  9 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (4)
# {'catfilepath': '/tmp/sewpy_workdir_ROsulU/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ROsulU/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_ROsulU'}
# {'catfilepath': '/tmp/sewpy_workdir_DnZwwc/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_DnZwwc/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_DnZwwc'}
# {'catfilepath': '/tmp/sewpy_workdir_LscryL/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_LscryL/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_LscryL'}
# {'catfilepath': '/tmp/sewpy_workdir_5rAXOV/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_5rAXOV/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_5rAXOV'}
# 0.030769230769230795 0.921349826388889
# nan nan nan nan
# Frame nr.  10 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (38)
# {'catfilepath': '/tmp/sewpy_workdir_NHCbYA/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_NHCbYA/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_NHCbYA'}
# {'catfilepath': '/tmp/sewpy_workdir_NO43x5/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_NO43x5/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_NO43x5'}
# {'catfilepath': '/tmp/sewpy_workdir_q7R9NW/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_q7R9NW/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_q7R9NW'}
# {'catfilepath': '/tmp/sewpy_workdir_qNMkM_/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_qNMkM_/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_qNMkM_'}
# 0.07692308609302227 0.6026693
# nan nan nan nan
# Frame nr.  11 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (39)
# {'catfilepath': '/tmp/sewpy_workdir_Lq7PQb/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_Lq7PQb/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_Lq7PQb'}
# {'catfilepath': '/tmp/sewpy_workdir_HEB9wb/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_HEB9wb/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_HEB9wb'}
# {'catfilepath': '/tmp/sewpy_workdir_GoKJmZ/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_GoKJmZ/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_GoKJmZ'}
# {'catfilepath': '/tmp/sewpy_workdir_3KA8tl/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_3KA8tl/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_3KA8tl'}
# 0.10000002384185791 0.4437456
# nan nan nan nan
# Frame nr.  12 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (2)
# {'catfilepath': '/tmp/sewpy_workdir_CFoNaQ/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_CFoNaQ/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_CFoNaQ'}
# {'catfilepath': '/tmp/sewpy_workdir_L3Mdml/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_L3Mdml/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_L3Mdml'}
# {'catfilepath': '/tmp/sewpy_workdir_hag1_n/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_hag1_n/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_hag1_n'}
# {'catfilepath': '/tmp/sewpy_workdir_dqZKls/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_dqZKls/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir
ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_77aHGo'}
# {'catfilepath': '/tmp/sewpy_workdir_VmCWHt/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_VmCWHt/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_VmCWHt'}
# {'catfilepath': '/tmp/sewpy_workdir_qsD9z5/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_qsD9z5/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_qsD9z5'}
# 0.22307693041287935 0.72791225
# nan nan nan nan
# Frame nr.  17 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (33)
# {'catfilepath': '/tmp/sewpy_workdir_mWSTFe/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_mWSTFe/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_mWSTFe'}
# {'catfilepath': '/tmp/sewpy_workdir_cEBKs5/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_cEBKs5/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_cEBKs5'}
# {'catfilepath': '/tmp/sewpy_workdir_zRjgH5/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_zRjgH5/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_zRjgH5'}
# -0.5272726579145952 0.89197487
# nan nan nan nan
# Frame nr.  18 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (30)
# {'catfilepath': '/tmp/sewpy_workdir_75sDjl/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_75sDjl/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_75sDjl'}
# {'catfilepath': '/tmp/sewpy_workdir_IjdXB3/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_IjdXB3/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_IjdXB3'}
# {'catfilepath': '/tmp/sewpy_workdir_I8jzM9/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_I8jzM9/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_I8jzM9'}
# 2.390909021550959 13.305065
# nan nan nan nan
# Frame nr.  19 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (20)
# {'catfilepath': '/tmp/sewpy_workdir_wxHlgp/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_wxHlgp/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_wxHlgp'}
# {'catfilepath': '/tmp/sewpy_workdir_KLvqvo/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_KLvqvo/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_KLvqvo'}
# {'catfilepath': '/tmp/sewpy_workdir_ruOrQX/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ruOrQX/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_ruOrQX'}
# {'catfilepath': '/tmp/sewpy_workdir_QtYUuC/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_QtYUuC/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_QtYUuC'}
# 0.20769231136028582 0.28968316
# nan nan nan nan
# Frame nr.  20 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (42)
# {'catfilepath': '/tmp/sewpy_workdir_LHkdbr/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_LHkdbr/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_LHkdbr'}
# {'catfilepath': '/tmp/sewpy_workdir_N6MoCc/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_N6MoCc/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_N6MoCc'}
# {'catfilepath': '/tmp/sewpy_workdir_pbOfUr/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_pbOfUr/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_pbOfUr'}
# -0.07142857142857142 0.41875002
# nan nan nan nan
# Frame nr.  21 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (28)
# {'catfilepath': '/tmp/sewpy_workdir_bkKeOe/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_bkKeOe/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_bkKeOe'}
# {'catfilepath': '/tmp/sewpy_workdir_JcITOg/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_JcITOg/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_JcITOg'}
# {'catfilepath': '/tmp/sewpy_workdir_OHixbV/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_OHixbV/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_OHixbV'}
# -0.8857142584664481 2.3505557
# nan nan nan nan
# Frame nr.  22 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (32)
# {'catfilepath': '/tmp/sewpy_workdir_mnbDvT/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_mnbDvT/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_mnbDvT'}
# {'catfilepath': '/tmp/sewpy_workdir_YZG8sP/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_YZG8sP/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_YZG8sP'}
# {'catfilepath': '/tmp/sewpy_workdir_JNJM9N/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_JNJM9N/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_JNJM9N'}
# 0.48181815580888226 0.45245564
# nan nan nan nan
# Frame nr.  23 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (3)
# {'catfilepath': '/tmp/sewpy_workdir_4fbT3e/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_4fbT3e/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_4fbT3e'}
# {'catfilepath': '/tmp/sewpy_workdir_e0Nooa/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# ...
# -0.033333336313565574 0.3128513
# nan nan nan nan
# Frame nr.  43 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (17)
# {'catfilepath': '/tmp/sewpy_workdir_eBsNWK/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_eBsNWK/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_eBsNWK'}
# {'catfilepath': '/tmp/sewpy_workdir_2u9Wie/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_2u9Wie/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_2u9Wie'}
# {'catfilepath': '/tmp/sewpy_workdir_GH9ckd/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_GH9ckd/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_GH9ckd'}
# -0.2416666547457377 0.24938981
# nan nan nan nan
# Frame nr.  44 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (27)
# {'catfilepath': '/tmp/sewpy_workdir_LmBw60/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_LmBw60/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_LmBw60'}
# {'catfilepath': '/tmp/sewpy_workdir_nXMoQg/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_nXMoQg/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_nXMoQg'}
# {'catfilepath': '/tmp/sewpy_workdir_9Kzd0m/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_9Kzd0m/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_9Kzd0m'}
# -1.3083333174387615 1.4120822
# nan nan nan nan
# Frame nr.  45 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (23)
# {'catfilepath': '/tmp/sewpy_workdir_G_cnLJ/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_G_cnLJ/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_G_cnLJ'}
# {'catfilepath': '/tmp/sewpy_workdir_u8rKiT/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_u8rKiT/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_u8rKiT'}
# {'catfilepath': '/tmp/sewpy_workdir_qxtzr0/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_qxtzr0/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_qxtzr0'}
# 0.01538461446762085 0.41972223
# nan nan nan nan
# Frame nr.  46 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (19)
# {'catfilepath': '/tmp/sewpy_workdir__4qeVH/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir__4qeVH/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir__4qeVH'}
# {'catfilepath': '/tmp/sewpy_workdir_ZBj61Y/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ZBj61Y/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_ZBj61Y'}
# {'catfilepath': '/tmp/sewpy_workdir_YbuuLz/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_YbuuLz/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_YbuuLz'}
# {'catfilepath': '/tmp/sewpy_workdir_r5hI0n/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_r5hI0n/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_r5hI0n'}
# -0.5199999999999999 0.7775651041666668
# nan nan nan nan
# Frame nr.  47 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (46)
# {'catfilepath': '/tmp/sewpy_workdir_i1YEeP/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_i1YEeP/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_i1YEeP'}
# {'catfilepath': '/tmp/sewpy_workdir_ULh8DM/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ULh8DM/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_ULh8DM'}
# {'catfilepath': '/tmp/sewpy_workdir_CLb6qZ/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_CLb6qZ/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_CLb6qZ'}
# 0.03571428145681109 0.6763424
# nan nan nan nan
# Frame nr.  48 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (37)
# {'catfilepath': '/tmp/sewpy_workdir_2LXvn6/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_2LXvn6/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_2LXvn6'}
# {'catfilepath': '/tmp/sewpy_workdir_R64rlZ/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_R64rlZ/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_R64rlZ'}
# {'catfilepath': '/tmp/sewpy_workdir_f8vj9q/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_f8vj9q/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_f8vj9q'}
# -0.12142857483455113 0.43558595
# nan nan nan nan
# Frame nr.  49 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (29)
# {'catfilepath': '/tmp/sewpy_workdir_jWNj2V/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_jWNj2V/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_jWNj2V'}
# {'catfilepath': '/tmp/sewpy_workdir_vun_Qg/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_vun_Qg/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_vun_Qg'}
# {'catfilepath': '/tmp/sewpy_workdir_Vq68yG/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_Vq68yG/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_Vq68yG'}
# -0.44285716329302105 0.19678251
# nan nan nan nan
# Frame nr.  50 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (26)
# {'catfilepath': '/tmp/sewpy_workdir_E_8Na3/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_E_8Na3/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_E_8Na3'}
# {'catfilepath': '/tmp/sewpy_workdir_VEs2jB/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_VEs2jB/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_VEs2jB'}
# {'catfilepath': '/tmp/sewpy_workdir_QTsca4/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_QTsca4/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_QTsca4'}
# -0.0923076868057251 0.45249626
# nan nan nan nan
# Frame nr.  51 /../home/lynge/MasterP/ESO323/H/ESO323_2_10_H.fits (36)
# {'catfilepath': '/tmp/sewpy_workdir_3lchBe/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_3lchBe/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_3lchBe'}
# {'catfilepath': '/tmp/sewpy_workdir_76uNIj/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_76uNIj/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_76uNIj'}
# {'catfilepath': '/tmp/sewpy_workdir_8iJ59G/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_8iJ59G/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_8iJ59G'}
# {'catfilepath': '/tmp/sewpy_workdir_CXktjI/ESO323_2_10_H.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_CXktjI/ESO323_2_10_H.log.txt', 'workdir': '/tmp/sewpy_workdir_CXktjI'}
# 1.5071427481515067 3.0215974
# nan nan nan nan

# %%
np.savetxt('../NOVEMBER/ESO323_NOISE_Hs7.txt',noise_quasar_1)
np.savetxt('../NOVEMBER/NOV-ESO323-Hs7',comp_array)
np.savetxt('../NOVEMBER/ESO323_SNR_Hs7.txt',SNR_part_1)

# %%
def SEXAGNflux(quas,aperture1):
    aperture2 = aperture1 + 0.003
    date = []
    flucompsta1 = []
    flucompsta2 = []
    flucompsta3 = []
    flucompsta4 = []
    flucompsta5 = []
    flucompsta6 = []
    flucompsta7 = []
    poissonAGN = []
    poisson529 = []
    poisson22 = []
    poissonHD = []
    ABS_FLUX_LAMBDA_1 = 0
    ABS_FLUX_LAMBDA_2 = 0
    ABS_FLUX_LAMBDA_3 = 0
    ABS_FLUX_V_1 = 0
    ABS_FLUX_V_2 = 0
    ABS_FLUX_V_3 = 0
    SNR_comp = []
    comp_array = np.zeros((len(quas),6))
    SNR_array = np.zeros((len(quas),8))
    SNR_part = np.zeros((len(quas),5))
    SNR_star = np.zeros((len(quas),4))
    noise_quasar = np.zeros((len(quas),7))
    signal = np.zeros((len(quas),4))
    #-----------------------------------------------------------------------------------------------
    for i in range(len(quas)):
        print 'Frame nr. ', i, quas[i]
        header = pyfits.getheader(quas[i])
        a_AGN = flux(quas[i],2*aperture1,qua1_RA_WORLD,qua1_DEC_WORLD)/header['DIT']
        a2 = flux(quas[i],2*aperture1,sta1_RA_WORLD,sta1_DEC_WORLD)/header['DIT']
        a3 = flux(quas[i],2*aperture1,sta2_RA_WORLD,sta2_DEC_WORLD)/header['DIT']
        a4 = flux(quas[i],2*aperture1,sta3_RA_WORLD,sta3_DEC_WORLD)/header['DIT']
        a_sky1 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky1_RA_WORLD,sky1_DEC_WORLD),aperture1)[0]/header['DIT']
        a_sky2 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky2_RA_WORLD,sky2_DEC_WORLD),aperture1)[0]/header['DIT']
        a_sky3 = curve(pyfits.getdata(quas[i]),pyfits.getheader(quas[i]),WCS(quas[i]),
                   (sky3_RA_WORLD,sky3_DEC_WORLD),aperture1)[0]/header['DIT']
        #a_AGN_1 = flux(quas[i],2*aperture2,qua1_RA_WORLD,qua1_DEC_WORLD)/header['DIT']
        #a2_1 = flux(quas[i],2*aperture2,sta1_RA_WORLD,sta1_DEC_WORLD)/header['DIT']
        #a3_1 = flux(quas[i],2*aperture2,sta2_RA_WORLD,sta2_DEC_WORLD)/header['DIT']
        #a4_1 = flux(quas[i],2*aperture2,sta3_RA_WORLD,sta3_DEC_WORLD)/header['DIT']
        signal[i,0] = a_AGN
        signal[i,1] = a2
        signal[i,2] = a3
        signal[i,3] = a4
        #-------------------------------------------------------------------------------------------
        #plt.figure(figsize=(3,3))
        #plt.imshow(a2)
        #plt.show()
        #-------------------------------------------------------------------------------------------
        a_AGN_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a2_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a3_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a4_pix = np.pi*(aperture1)**2/((header['PIXSCALE']/3600.)**2)
        a_sky_pix = np.count_nonzero(a_sky1)
        a_sky_2 = np.sum(a_sky1)/float(np.count_nonzero(a_sky1))
        a_sky = np.concatenate((a_sky1.ravel(),a_sky2.ravel(),a_sky3.ravel()),axis=0)
        a_sky_var = np.nanvar(a_sky)
        print a_sky_2,a_sky_var
        #a_AGN_pix_1 = np.pi*(2*aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a2_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a3_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a4_pix_1 = np.pi*(aperture2)**2/((header['PIXSCALE']/3600.)**2)
        #a_AGN_2 = (np.sum(a_AGN_1) - np.sum(a_AGN))/(float(np.count_nonzero(a_AGN_1)) - float(np.count_nonzero(a_AGN)))
        #a2_2 = (np.sum(a2_1) - np.sum(a2))/(float(np.count_nonzero(a2_1)) - float(np.count_nonzero(a2)))
        #a3_2 = (np.sum(a3_1) - np.sum(a3))/(float(np.count_nonzero(a3_1)) - float(np.count_nonzero(a3)))
        #a4_2 = (np.sum(a4_1) - np.sum(a4))/(float(np.count_nonzero(a4_1)) - float(np.count_nonzero(a4)))
        a_AGN_3 = a_AGN/a_AGN_pix #- (a_AGN_1 - a_AGN)/(a_AGN_pix_1 - a_AGN_pix) #Background subtracted flux/pixel/sec
        a2_3 = a2/a2_pix #- (a2_1 - a2)/(a2_pix_1 - a2_pix)
        a3_3 = a3/a3_pix #- (a3_1 - a3)/(a3_pix_1 - a3_pix)
        a4_3 = a4/a4_pix #- (a4_1 - a4)/(a4_pix_1 - a4_pix)
        #-------------------------------------------------------------------------------------------
        date.append(header['MJD-OBS'])
        #-------------------------------------------------------------------------------------------
        poissonAGN.append(np.sqrt(np.sum(a_AGN)*header['DIT']*header['GAIN'])) #header['DIT']))
        poissonHD.append(np.sqrt(np.sum(a2)*header['DIT']*header['GAIN'])) #header['DIT']))
        poisson22.append(np.sqrt(np.sum(a3)*header['DIT']*header['GAIN'])) #header['DIT']))
        poisson529.append(np.sqrt(np.sum(a4)*header['DIT']*header['GAIN'])) #header['DIT']))
        #-------------------------------------------------------------------------------------------
        #if SNR1[i] < 70:
        #    flucompsta_AGN.append(float('nan'))
        #    flucompsta2.append(float('nan'))
        #    flucompsta3.append(float('nan'))
        #    flucompsta4.append(float('nan'))
        #    flucompsta6.append(float('nan'))
        #    comp_array[i,0] = int(date[i])
        #    comp_array[i,1] = float('nan')
        #    comp_array[i,2] = float('nan')
        #    comp_array[i,3] = float('nan')
        #else:
        flucompsta1.append(comp1(a_AGN_3,a2_3))
        flucompsta2.append(comp1(a_AGN_3,a3_3))
        flucompsta3.append(comp1(a_AGN_3,a4_3))
        SNR1 = SNR(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        #flucompsta4.append(comp1(a_AGN_3,a5_3))
        #flucompsta5.append(comp1(a_AGN_3,a6_3))
        #flucompsta6.append(comp1(a_AGN_3,a7_3))
        comp_array[i,0] = int(date[i])
        comp_array[i,1] = flucompsta1[i]
        comp_array[i,2] = flucompsta2[i]
        comp_array[i,3] = flucompsta3[i]
        comp_array[i,4] = SNR1
        comp_array[i,5] = a_AGN
        #comp_array[i,5] = flucompsta5[i]
        #comp_array[i,6] = flucompsta6[i]
        print a_AGN, a2, a3, a4
        SNR_part[i,0] = date[i]
        SNR_part[i,1] = SNR(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,2] = SNR11(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,3] = SNR22(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_part[i,4] = SNR33(a_AGN,np.sum(a_sky),header,aperture1,aperture1)\
        /SNR44(a_AGN,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,0] = header['MJD-OBS']
        SNR_star[i,1] = SNR(a2,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,2] = SNR(a3,np.sum(a_sky),header,aperture1,aperture1)
        SNR_star[i,3] = SNR(a4,np.sum(a_sky),header,aperture1,aperture1)
        noise_quasar[i,0] = header['MJD-OBS']
        noise_quasar[i,1] = float('nan')
        noise_quasar[i,2] = float('nan')
        noise_quasar[i,3] = float('nan')
        #SNR_array[i,0] = int(date[i])
        #SNR_array[i,1] = SNR(a_AGN,a_sky,header,aperture1,aperture1)
        #SNR_array[i,2] = SNR(a2,a_sky,header,aperture1,aperture1)
        #SNR_array[i,3] = SNR(a3,a_sky,header,aperture1,aperture1)
        #SNR_array[i,4] = SNR(a4,a_sky,header,aperture1,aperture1)
        #SNR_array[i,5] = SNR(a5,a_sky,header,aperture1,aperture1)
        #SNR_array[i,6] = SNR(a6,a_sky,header,aperture1,aperture1)
        #SNR_array[i,7] = SNR(a7,a_sky,header,aperture1,aperture1)
    #print 'YES'
    #-----------------------------------------------------------------------------------------------
    poissonAGN = np.array(poissonAGN)
    poissonHD = np.array(poissonHD)
    poisson22 = np.array(poisson22)
    poisson529 = np.array(poisson529)
    comp_array = comp_array[comp_array[:,0].argsort()]
    
    comp_array[:,1] = comp_array[:,1]*flux_cal(MAG_STA1_J,MAG_VEGA_J,FLUX_LAMBDA_VEGA_J)
    comp_array[:,2] = comp_array[:,2]*flux_cal(MAG_STA2_J,MAG_VEGA_J,FLUX_LAMBDA_VEGA_J)
    comp_array[:,3] = comp_array[:,3]*flux_cal(MAG_STA3_J,MAG_VEGA_J,FLUX_LAMBDA_VEGA_J)
    
    noise_quasar[:,1] = error(signal[:,0],signal[:,1],SNR_part[:,1],SNR_star[:,1],MAG_STA1_J,\
                              MAG_err_STA1_J,FLUX_LAMBDA_VEGA_J,MAG_VEGA_J)
    noise_quasar[:,2] = error(signal[:,0],signal[:,2],SNR_part[:,1],SNR_star[:,2],MAG_STA2_J,\
                              MAG_err_STA2_J,FLUX_LAMBDA_VEGA_J,MAG_VEGA_J)
    noise_quasar[:,3] = error(signal[:,0],signal[:,3],SNR_part[:,1],SNR_star[:,3],MAG_STA3_J,\
                              MAG_err_STA3_J,FLUX_LAMBDA_VEGA_J,MAG_VEGA_J)
    
    noise_quasar[:,4] = relerror(signal[:,0],signal[:,1],SNR_part[:,1],SNR_star[:,1],MAG_STA1_J,\
                              MAG_err_STA1_J,FLUX_LAMBDA_VEGA_J,MAG_VEGA_J)
    noise_quasar[:,5] = relerror(signal[:,0],signal[:,2],SNR_part[:,1],SNR_star[:,2],MAG_STA2_J,\
                              MAG_err_STA2_J,FLUX_LAMBDA_VEGA_J,MAG_VEGA_J)
    noise_quasar[:,6] = relerror(signal[:,0],signal[:,3],SNR_part[:,1],SNR_star[:,3],MAG_STA3_J,\
                              MAG_err_STA3_J,FLUX_LAMBDA_VEGA_J,MAG_VEGA_J)

    #-----------------------------------------------------------------------------------------------
    return comp_array,SNR_array,ABS_FLUX_LAMBDA_1,ABS_FLUX_LAMBDA_2,ABS_FLUX_LAMBDA_3,\
ABS_FLUX_V_1,ABS_FLUX_V_2,ABS_FLUX_V_3,date,SNR_part,SNR_star,noise_quasar

# %%
comp_array,SNR_array,ABS_FLUX_LAMBDA_1_1,ABS_FLUX_LAMBDA_2_1,ABS_FLUX_LAMBDA_3_1,\
ABS_FLUX_V_1_1,ABS_FLUX_V_2_1,ABS_FLUX_V_3_1,date_1,SNR_part_1,SNR_star_1,noise_quasar_1 = SEXAGNflux(quas_J,0.0007)
# Out:
# Frame nr.  0 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (1)
# {'catfilepath': '/tmp/sewpy_workdir_uKwURZ/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_uKwURZ/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_uKwURZ'}
# {'catfilepath': '/tmp/sewpy_workdir_pxhkqr/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_pxhkqr/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_pxhkqr'}
# {'catfilepath': '/tmp/sewpy_workdir__qbOvY/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir__qbOvY/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir__qbOvY'}
# -0.11538461538461539 0.1512527
# nan nan nan nan
# Frame nr.  1 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (34)
# {'catfilepath': '/tmp/sewpy_workdir_6ZiqdB/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_6ZiqdB/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_6ZiqdB'}
# {'catfilepath': '/tmp/sewpy_workdir_dTfIq6/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_dTfIq6/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_dTfIq6'}
# {'catfilepath': '/tmp/sewpy_workdir_NfiBh9/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_NfiBh9/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_NfiBh9'}
# -0.22727272727272727 0.09749565972222222
# nan nan nan nan
# Frame nr.  2 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (38)
# {'catfilepath': '/tmp/sewpy_workdir_UB6cRw/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_UB6cRw/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_UB6cRw'}
# {'catfilepath': '/tmp/sewpy_workdir_qn2QzK/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_qn2QzK/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_qn2QzK'}
# {'catfilepath': '/tmp/sewpy_workdir_atRaNU/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_atRaNU/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_atRaNU'}
# {'catfilepath': '/tmp/sewpy_workdir_ne5mus/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ne5mus/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_ne5mus'}
# -0.016466343632111184 0.19199415
# nan nan nan nan
# Frame nr.  3 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (29)
# {'catfilepath': '/tmp/sewpy_workdir_osgeI8/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_osgeI8/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_osgeI8'}
# {'catfilepath': '/tmp/sewpy_workdir_xWJYOF/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_xWJYOF/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_xWJYOF'}
# {'catfilepath': '/tmp/sewpy_workdir_CCdD3g/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_CCdD3g/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_CCdD3g'}
# -0.5999999727521624 0.40968314
# nan nan nan nan
# Frame nr.  4 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (35)
# {'catfilepath': '/tmp/sewpy_workdir_HG3wA2/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_HG3wA2/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_HG3wA2'}
# {'catfilepath': '/tmp/sewpy_workdir_TCl3Wp/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_TCl3Wp/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_TCl3Wp'}
# {'catfilepath': '/tmp/sewpy_workdir_ETLN_K/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ETLN_K/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_ETLN_K'}
# -0.20833333333333334 0.20794939
# nan nan nan nan
# Frame nr.  5 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (32)
# {'catfilepath': '/tmp/sewpy_workdir_oEJg3C/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_oEJg3C/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_oEJg3C'}
# {'catfilepath': '/tmp/sewpy_workdir_SMJDYb/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_SMJDYb/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_SMJDYb'}
# {'catfilepath': '/tmp/sewpy_workdir_vb5YXD/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_vb5YXD/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_vb5YXD'}
# 0.1846153846153846 0.11734375000000001
# nan nan nan nan
# Frame nr.  6 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (18)
# {'catfilepath': '/tmp/sewpy_workdir_zLBtyx/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_zLBtyx/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_zLBtyx'}
# {'catfilepath': '/tmp/sewpy_workdir_81pp3n/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_81pp3n/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_81pp3n'}
# {'catfilepath': '/tmp/sewpy_workdir_wYqMvC/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_wYqMvC/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_wYqMvC'}
# -0.05000000000000001 0.13693417159763313
# nan nan nan nan
# Frame nr.  7 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (24)
# {'catfilepath': '/tmp/sewpy_workdir__e2ter/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir__e2ter/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir__e2ter'}
# {'catfilepath': '/tmp/sewpy_workdir_pH5FgD/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_pH5FgD/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_pH5FgD'}
# {'catfilepath': '/tmp/sewpy_workdir_CPWivd/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_CPWivd/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_CPWivd'}
# {'catfilepath': '/tmp/sewpy_workdir_9oJvac/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_9oJvac/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_9oJvac'}
# -0.5153846153846154 0.10600260416666667
# nan nan nan nan
# Frame nr.  8 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (14)
# {'catfilepath': '/tmp/sewpy_workdir_M1Fn8h/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_M1Fn8h/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_M1Fn8h'}
# {'catfilepath': '/tmp/sewpy_workdir_FLD15i/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_FLD15i/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_FLD15i'}
# {'catfilepath': '/tmp/sewpy_workdir_PK4WrZ/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_PK4WrZ/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_PK4WrZ'}
# -0.19166668256123862 0.17859374
# nan nan nan nan
# Frame nr.  9 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (39)
# {'catfilepath': '/tmp/sewpy_workdir_fU24j4/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_fU24j4/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_fU24j4'}
# {'catfilepath': '/tmp/sewpy_workdir_cekA5J/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_cekA5J/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_cekA5J'}
# {'catfilepath': '/tmp/sewpy_workdir_xsLmjF/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_xsLmjF/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_xsLmjF'}
# {'catfilepath': '/tmp/sewpy_workdir_ioFdtf/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ioFdtf/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_ioFdtf'}
# -0.46153846153846156 0.35232248520710063
# nan nan nan nan
# Frame nr.  10 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (13)
# {'catfilepath': '/tmp/sewpy_workdir_vgVswe/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_vgVswe/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_vgVswe'}
# {'catfilepath': '/tmp/sewpy_workdir_1i4235/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_1i4235/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_1i4235'}
# {'catfilepath': '/tmp/sewpy_workdir_47TIH2/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_47TIH2/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_47TIH2'}
# -0.12857142857142856 0.2248927514792899
# nan nan nan nan
# Frame nr.  11 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (20)
# {'catfilepath': '/tmp/sewpy_workdir_8uqtbX/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_8uqtbX/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_8uqtbX'}
# {'catfilepath': '/tmp/sewpy_workdir_u0JhLT/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_u0JhLT/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_u0JhLT'}
# {'catfilepath': '/tmp/sewpy_workdir_TTl83e/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_TTl83e/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_TTl83e'}
# {'catfilepath': '/tmp/sewpy_workdir_DZnNHb/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_DZnNHb/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_DZnNHb'}
# 0.03313802679379781 0.1743277
# nan nan nan nan
# Frame nr.  12 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (48)
# {'catfilepath': '/tmp/sewpy_workdir_rdCUhB/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_rdCUhB/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_rdCUhB'}
# {'catfilepath': '/tmp/sewpy_workdir_jaJg0m/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_jaJg0m/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_jaJg0m'}
# {'catfilepath': '/tmp/sewpy_workdir_g_iLVI/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_g_iLVI/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_g_iLVI'}
# {'catfilepath': '/tmp/sewpy_workdir_ALkhzR/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ALkhzR/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_ALkhzR'}
# -0.07857142857142858 0.15664930555555556
# nan nan nan nan
# Frame nr.  13 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (40)
# {'catfilepath': '/tmp/sewpy_workdir_Pt731C/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_Pt731C/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_Pt731C'}
# {'catfilepath': '/tmp/sewpy_workdir_7wESwS/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_7wESwS/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_7wESwS'}
# {'catfilepath': '/tmp/sewpy_workdir_OTM6PX/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_OTM6PX/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_OTM6PX'}
# {'catfilepath': '/tmp/sewpy_workdir__eEp1U/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir__eEp1U/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir__eEp1U'}
# -0.0956280048076923 0.31841403
# nan nan nan nan
# Frame nr.  14 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits
# 196.47187851 -40.478644705 2.4821278762e-05 ...  693.2719       0.697
# 196.48274021 -40.369419317  3.208461269e-07 ...  777.0242       0.025
# 196.46083091  -40.49358603 1.5175804144e-08 ... -101.2185       0.385
# 196.67625817 -40.464877845 2.9058063441e-07 ...  1475.026       0.195
# 196.46468069 -40.446059846  1.936571687e-07 ...  366.4247       0.264
# 196.47236149 -40.357164433 5.3528539972e-05 ...  260.6906        0.05
# 196.68897077 -40.345726575 9.3097999982e-06 ...  1636.647       0.292
# 196.66825124 -40.486297165 3.9430123118e-07 ...  1503.182       0.197
# 196.66498898 -40.468250687 1.7288232313e-07 ...  364.1635       0.414
# 196.67635353 -40.369571827 1.2559802961e-07 ...  881.7628        0.25, 'logfilepath': '/tmp/sewpy_workdir_ruPs3Y/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_ruPs3Y'}
# -0.36739782186654896 0.19062011
# 1375.285 2043.185 17207.46 1843.321
# Frame nr.  16 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (12)
# {'catfilepath': '/tmp/sewpy_workdir_ijJkHX/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ijJkHX/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_ijJkHX'}
# {'catfilepath': '/tmp/sewpy_workdir_d37ckG/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_d37ckG/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_d37ckG'}
# {'catfilepath': '/tmp/sewpy_workdir_MqGWpz/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_MqGWpz/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_MqGWpz'}
# 0.030769230769230778 0.15704427083333336
# nan nan nan nan
# Frame nr.  17 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (33)
# {'catfilepath': '/tmp/sewpy_workdir_OVoMKB/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_OVoMKB/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_OVoMKB'}
# {'catfilepath': '/tmp/sewpy_workdir_080VLU/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_080VLU/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_080VLU'}
# {'catfilepath': '/tmp/sewpy_workdir_NE7xUQ/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_NE7xUQ/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_NE7xUQ'}
# {'catfilepath': '/tmp/sewpy_workdir_975RyC/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_975RyC/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_975RyC'}
# -0.49090909090909096 0.15764462809917357
# nan nan nan nan
# Frame nr.  18 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (17)
# {'catfilepath': '/tmp/sewpy_workdir_ttdGzE/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ttdGzE/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_ttdGzE'}
# {'catfilepath': '/tmp/sewpy_workdir_2isen9/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_2isen9/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_2isen9'}
# {'catfilepath': '/tmp/sewpy_workdir_wHyR_B/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_wHyR_B/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_wHyR_B'}
# -0.4142857142857143 0.2728993055555555
# nan nan nan nan
# Frame nr.  19 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (15)
# {'catfilepath': '/tmp/sewpy_workdir_nerXgU/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_nerXgU/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_nerXgU'}
# {'catfilepath': '/tmp/sewpy_workdir_3GaWyq/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_3GaWyq/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_3GaWyq'}
# {'catfilepath': '/tmp/sewpy_workdir_YNtfgB/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_YNtfgB/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_YNtfgB'}
# {'catfilepath': '/tmp/sewpy_workdir_2Fkv1z/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_2Fkv1z/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_2Fkv1z'}
# -0.20833333333333334 0.12493055555555554
# nan nan nan nan
# Frame nr.  20 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (7)
# {'catfilepath': '/tmp/sewpy_workdir_PoXGqy/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_PoXGqy/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_PoXGqy'}
# {'catfilepath': '/tmp/sewpy_workdir_E9wSQL/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_E9wSQL/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_E9wSQL'}
# {'catfilepath': '/tmp/sewpy_workdir_PhxxPz/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_PhxxPz/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_PhxxPz'}
# 0.4583333333333333 89.3417317708333
# nan nan nan nan
# Frame nr.  21 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (22)
# {'catfilepath': '/tmp/sewpy_workdir_ls1n41/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_ls1n41/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_ls1n41'}
# {'catfilepath': '/tmp/sewpy_workdir_EPZkQ6/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_EPZkQ6/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_EPZkQ6'}
# {'catfilepath': '/tmp/sewpy_workdir_uDOy5D/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_uDOy5D/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_uDOy5D'}
# {'catfilepath': '/tmp/sewpy_workdir_HYwmkQ/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_HYwmkQ/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_HYwmkQ'}
# -0.12307692307692307 0.1110204081632653
# nan nan nan nan
# Frame nr.  22 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (41)
# {'catfilepath': '/tmp/sewpy_workdir_26Ccp9/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
# ...
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_4AA7DG/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_4AA7DG'}
# -0.2416666666666667 0.19828402366863906
# nan nan nan nan
# Frame nr.  48 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (5)
# {'catfilepath': '/tmp/sewpy_workdir_MWrPK6/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_MWrPK6/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_MWrPK6'}
# {'catfilepath': '/tmp/sewpy_workdir_faV3wC/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_faV3wC/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_faV3wC'}
# {'catfilepath': '/tmp/sewpy_workdir_hjE4Mm/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_hjE4Mm/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_hjE4Mm'}
# -0.34737723214285715 0.16482218
# nan nan nan nan
# Frame nr.  49 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (28)
# {'catfilepath': '/tmp/sewpy_workdir_7BrVpJ/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_7BrVpJ/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_7BrVpJ'}
# {'catfilepath': '/tmp/sewpy_workdir_oNueZn/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_oNueZn/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_oNueZn'}
# {'catfilepath': '/tmp/sewpy_workdir_CIzECE/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_CIzECE/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_CIzECE'}
# -0.1636363636363636 0.14015902366863905
# nan nan nan nan
# Frame nr.  50 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (16)
# {'catfilepath': '/tmp/sewpy_workdir_Iha685/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_Iha685/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_Iha685'}
# {'catfilepath': '/tmp/sewpy_workdir_vigm4a/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_vigm4a/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_vigm4a'}
# {'catfilepath': '/tmp/sewpy_workdir_Fi626T/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_Fi626T/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_Fi626T'}
# -0.3755859136581421 0.13985077
# nan nan nan nan
# Frame nr.  51 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (25)
# {'catfilepath': '/tmp/sewpy_workdir_Ty7iuW/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_Ty7iuW/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_Ty7iuW'}
# {'catfilepath': '/tmp/sewpy_workdir_F9Cl1y/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_F9Cl1y/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_F9Cl1y'}
# {'catfilepath': '/tmp/sewpy_workdir_eWqB9z/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_eWqB9z/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_eWqB9z'}
# -0.20833333333333334 0.1156206597222222
# nan nan nan nan
# Frame nr.  52 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (31)
# {'catfilepath': '/tmp/sewpy_workdir_gX0QNX/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_gX0QNX/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_gX0QNX'}
# {'catfilepath': '/tmp/sewpy_workdir_z3njZ1/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_z3njZ1/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_z3njZ1'}
# {'catfilepath': '/tmp/sewpy_workdir_LSB3da/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_LSB3da/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_LSB3da'}
# -0.07857142857142858 0.16276041666666666
# nan nan nan nan
# Frame nr.  53 /../home/lynge/MasterP/ESO323/J/ESO323_2_10_J.fits
# {'catfilepath': '/tmp/sewpy_workdir_x1fe_m/ESO323_2_10_J.cat.txt', 'table': <Table length=125>
# XMODEL_WORLD  YMODEL_WORLD  X2MODEL_WORLD   ... FLUX_APER ELLIPTICITY
#     deg           deg            deg2       ...     ct
#   float64       float64        float64      ...  float64    float64
# ------------ ------------- ---------------- ... --------- -----------
# 196
10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_pZflvC'}
# {'catfilepath': '/tmp/sewpy_workdir_QpE77h/ESO323_2_10_J.cat.txt', 'table': <Table length=125>
# XMODEL_WORLD  YMODEL_WORLD  X2MODEL_WORLD   ... FLUX_APER ELLIPTICITY
#     deg           deg            deg2       ...     ct
#   float64       float64        float64      ...  float64    float64
# ------------ ------------- ---------------- ... --------- -----------
# 196.76998657 -40.337998556  0.0002718492429 ...  1600.247       0.345
# 196.76377379 -40.396156509  6.794131029e-06 ...  452.9842       0.764
# 196.76265625 -40.405402389 1.2144041128e-05 ...  533.9427       0.383
#   196.761039 -40.421510769 1.7479380628e-05 ...  390.9357       0.393
# 196.76515319 -40.385226198 7.1609648953e-05 ...  463.1279       0.488
# 196.75920427 -40.440855716 6.3461132696e-05 ...   286.403       0.417
# 196.55488613 -40.333073317 1.6164937006e-07 ...  252.8422       0.401
# 196.52768713 -40.481070039  9.296944459e-08 ...  422.9221       0.541
#  196.5262231 -40.478342498  0.0018012866336 ...  253.8807       0.336
#          ...           ...              ... ...       ...         ...
# 196.74883638 -40.355921262 1.5106139903e-05 ...  476.4992       0.436
# 196.73279758 -40.503290973 5.0230587219e-08 ...  250.1011       0.334
# 196.74317207 -40.471833164 1.9323319849e-06 ...  2089.419        0.09
# 196.74083765 -40.491570254 0.00038714648916 ...  438.7625       0.029
# 196.74454828 -40.479266884 3.7000594698e-05 ...  489.7596         0.3
# 196.54196285 -40.380160661 1.1869121594e-07 ...  3860.807       0.161
# 196.54803863 -40.336117732 9.7124286578e-08 ...  929.1949       0.085
# 196.54530138 -40.392553724 5.8173358143e-08 ...  259.7559       0.386
# 196.54570985 -40.407338496 1.0411493904e-06 ...   643.438       0.231
# 196.53733299 -40.478166397 3.4389511926e-05 ...  273.4049       0.398, 'logfilepath': '/tmp/sewpy_workdir_QpE77h/ESO323_2_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_QpE77h'}
# -0.2859375136239188 0.19688904
# 1477.001 2334.493 19594.6 nan
# Frame nr.  54 /../home/lynge/MasterP/ESO323/J/ESO323_1_10_J.fits (52)
# {'catfilepath': '/tmp/sewpy_workdir_BWGXwY/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_BWGXwY/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_BWGXwY'}
# {'catfilepath': '/tmp/sewpy_workdir_meV4vn/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_meV4vn/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_meV4vn'}
# {'catfilepath': '/tmp/sewpy_workdir_g9E6J1/ESO323_1_10_J.cat.txt', 'table': <Table length=0>
# XMODEL_WORLD YMODEL_WORLD X2MODEL_WORLD ... FLUX_RADIUS FLUX_APER ELLIPTICITY
#     deg          deg           deg2     ...     pix         ct
#    int64        int64         int64     ...    int64      int64      int64
# ------------ ------------ ------------- ... ----------- --------- -----------, 'logfilepath': '/tmp/sewpy_workdir_g9E6J1/ESO323_1_10_J.log.txt', 'workdir': '/tmp/sewpy_workdir_g9E6J1'}
# 0.1533503532409668 0.21048336
# nan nan nan nan

# %%
np.savetxt('../NOVEMBER/ESO323_NOISE_Js7.txt',noise_quasar_1)
np.savetxt('../NOVEMBER/NOV-ESO323-Js7',comp_array)
np.savetxt('../NOVEMBER/ESO323_SNR_Js7.txt',SNR_part_1)
