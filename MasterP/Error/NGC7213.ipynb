# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import scipy as sc

# %%
SNR_g = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_SNR_g.txt')
SNR_r = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_SNR_r.txt')
SNR_i = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_SNR_i.txt')
SNR_z = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_SNR_z.txt')
SNR_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_SNR_H.txt')
SNR_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_SNR_J.txt')
SNR_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_SNR_K.txt')

NOISE_g = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_NOISE_g.txt')
NOISE_r = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_NOISE_r.txt')
NOISE_i = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_NOISE_i.txt')
NOISE_z = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_NOISE_z.txt')
NOISE_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_NOISE_J.txt')
NOISE_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_NOISE_H.txt')
NOISE_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC7213_NOISE_K.txt')

SIGNAL_g = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC7213-g')
SIGNAL_r = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC7213-r')
SIGNAL_i = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC7213-i')
SIGNAL_z = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC7213-z')
SIGNAL_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC7213-J')
SIGNAL_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC7213-H')
SIGNAL_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC7213-K')

# %%
plt.figure(figsize=(20,15))
plt.errorbar(SIGNAL_g[:,0],SIGNAL_g[:,1],yerr=NOISE_g[:,4],fmt='o',capsize=3,color='b',label='g')
plt.errorbar(SIGNAL_g[:,0],SIGNAL_g[:,2],yerr=NOISE_g[:,5],fmt='x',capsize=3,color='b')
plt.errorbar(SIGNAL_g[:,0],SIGNAL_g[:,3],yerr=NOISE_g[:,6],fmt='*',capsize=3,color='b')

plt.errorbar(SIGNAL_r[:,0],SIGNAL_r[:,1],yerr=NOISE_r[:,4],fmt='o',capsize=3,color='r',label='r')
plt.errorbar(SIGNAL_r[:,0],SIGNAL_r[:,2],yerr=NOISE_r[:,5],fmt='x',capsize=3,color='r')
plt.errorbar(SIGNAL_r[:,0],SIGNAL_r[:,3],yerr=NOISE_r[:,6],fmt='*',capsize=3,color='r')

plt.errorbar(SIGNAL_i[:,0],SIGNAL_i[:,1],yerr=NOISE_i[:,4],fmt='o',capsize=3,color='g',label='i')
plt.errorbar(SIGNAL_i[:,0],SIGNAL_i[:,2],yerr=NOISE_i[:,5],fmt='x',capsize=3,color='g')
plt.errorbar(SIGNAL_i[:,0],SIGNAL_i[:,3],yerr=NOISE_i[:,6],fmt='*',capsize=3,color='g')

plt.errorbar(SIGNAL_z[:,0],SIGNAL_z[:,1],yerr=NOISE_z[:,4],fmt='o',capsize=3,color='purple',label='z')
plt.errorbar(SIGNAL_z[:,0],SIGNAL_z[:,2],yerr=NOISE_z[:,5],fmt='x',capsize=3,color='purple')
plt.errorbar(SIGNAL_z[:,0],SIGNAL_z[:,3],yerr=NOISE_z[:,6],fmt='*',capsize=3,color='purple')

plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,4],fmt='o',capsize=3,color='yellow',label='J')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,5],fmt='x',capsize=3,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,6],fmt='*',capsize=3,color='yellow')

plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,4],fmt='o',capsize=3,color='orange',label='H')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,5],fmt='x',capsize=3,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,6],fmt='*',capsize=3,color='orange')

plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,4],fmt='o',capsize=3,color='black',label='K')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,5],fmt='x',capsize=3,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,6],fmt='*',capsize=3,color='black')
plt.legend()
plt.ylim([10*10**(-15),6*10**(-14)])
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.errorbar(SIGNAL_g[:,0],SIGNAL_g[:,1],yerr=NOISE_g[:,4],fmt='o',capsize=3,color='b',label='g')
plt.errorbar(SIGNAL_g[:,0],SIGNAL_g[:,2],yerr=NOISE_g[:,5],fmt='x',capsize=3,color='b')
plt.errorbar(SIGNAL_g[:,0],SIGNAL_g[:,3],yerr=NOISE_g[:,6],fmt='*',capsize=3,color='b')

plt.errorbar(SIGNAL_r[:,0],SIGNAL_r[:,1],yerr=NOISE_r[:,4],fmt='o',capsize=3,color='r',label='r')
plt.errorbar(SIGNAL_r[:,0],SIGNAL_r[:,2],yerr=NOISE_r[:,5],fmt='x',capsize=3,color='r')
plt.errorbar(SIGNAL_r[:,0],SIGNAL_r[:,3],yerr=NOISE_r[:,6],fmt='*',capsize=3,color='r')

plt.errorbar(SIGNAL_i[:,0],SIGNAL_i[:,1],yerr=NOISE_i[:,4],fmt='o',capsize=3,color='g',label='i')
plt.errorbar(SIGNAL_i[:,0],SIGNAL_i[:,2],yerr=NOISE_i[:,5],fmt='x',capsize=3,color='g')
plt.errorbar(SIGNAL_i[:,0],SIGNAL_i[:,3],yerr=NOISE_i[:,6],fmt='*',capsize=3,color='g')

plt.errorbar(SIGNAL_z[:,0],SIGNAL_z[:,1],yerr=NOISE_z[:,4],fmt='o',capsize=3,color='purple',label='z')
plt.errorbar(SIGNAL_z[:,0],SIGNAL_z[:,2],yerr=NOISE_z[:,5],fmt='x',capsize=3,color='purple')
plt.errorbar(SIGNAL_z[:,0],SIGNAL_z[:,3],yerr=NOISE_z[:,6],fmt='*',capsize=3,color='purple')

plt.legend()
plt.ylim([10*10**(-15),4*10**(-14)])
plt.show()

# %%
plt.figure(figsize=(20,15))

plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,4],fmt='o',capsize=3,color='yellow',label='J')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,5],fmt='x',capsize=3,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,6],fmt='*',capsize=3,color='yellow')

plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,4],fmt='o',capsize=3,color='orange',label='H')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,5],fmt='x',capsize=3,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,6],fmt='*',capsize=3,color='orange')

plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,4],fmt='o',capsize=3,color='black',label='K')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,5],fmt='x',capsize=3,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,6],fmt='*',capsize=3,color='black')
plt.legend()
plt.ylim([10*10**(-15),4*10**(-14)])
plt.show()

# %%
plt.figure(figsize=(20,15))

plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,4],fmt='o',capsize=3,color='r',label='J')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,5],fmt='x',capsize=3,color='r')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,6],fmt='*',capsize=3,color='r')

plt.legend()
plt.ylim([30*10**(-15),4*10**(-14)])
plt.show()

plt.figure(figsize=(20,15))

plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,4],fmt='o',capsize=3,color='r',label='H')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,5],fmt='x',capsize=3,color='r')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,6],fmt='*',capsize=3,color='r')

plt.legend()
plt.ylim([23*10**(-15),2.8*10**(-14)])
plt.show()

plt.figure(figsize=(20,15))

plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,4],fmt='o',capsize=3,color='r',label='K')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,5],fmt='x',capsize=3,color='r')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,6],fmt='*',capsize=3,color='r')
plt.legend()
plt.ylim([13*10**(-15),1.7*10**(-14)])
plt.show()
