# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import scipy as sc

# %%
SNR_g = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_g.txt')
SNR_r = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_r.txt')
SNR_i = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_i.txt')
SNR_z = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_z.txt')
SNR_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_H.txt')
SNR_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_J.txt')
SNR_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_K.txt')

SNR_star_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_STAR_H.txt')
SNR_star_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_STAR_J.txt')
SNR_star_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_SNR_STAR_K.txt')

NOISE_g = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE_g.txt')
NOISE_r = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE_r.txt')
NOISE_i = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE_i.txt')
NOISE_z = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE_z.txt')
NOISE_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE_J.txt')
NOISE_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE_H.txt')
NOISE_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE_K.txt')

NOISE_star_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE__STAR_J.txt')
NOISE_star_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE__STAR_H.txt')
NOISE_star_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NGC3783_NOISE__STAR_K.txt')

SIGNAL_g = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-g')
SIGNAL_r = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-r')
SIGNAL_i = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-i')
SIGNAL_z = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-z')
SIGNAL_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-J')
SIGNAL_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-H')
SIGNAL_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-K')

SIGNAL_star_J = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-STAR_J')
SIGNAL_star_H = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-STAR_H')
SIGNAL_star_K = np.loadtxt('/home/lynge/MasterP/NOVEMBER/NOV-NGC3783-STAR_K')

# %%
plt.figure(figsize=(20,15))
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,1],fmt='o',capsize=3,color='yellow',label='J')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,2],fmt='x',capsize=3,color='yellow')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,3],fmt='*',capsize=3,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,4],fmt='o',capsize=8,capthick=2,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,5],fmt='x',capsize=8,capthick=2,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,6],fmt='*',capsize=8,capthick=2,color='yellow')

#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,1],fmt='o',capsize=3,color='orange',label='H')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,2],fmt='x',capsize=3,color='orange')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,3],fmt='*',capsize=3,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,4],fmt='o',capsize=8,capthick=2,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,5],fmt='x',capsize=8,capthick=2,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,6],fmt='*',capsize=8,capthick=2,color='orange')

#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,1],fmt='o',capsize=3,color='black',label='K')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,2],fmt='x',capsize=3,color='black')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,3],fmt='*',capsize=3,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,4],fmt='o',capsize=8,capthick=2,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,5],fmt='x',capsize=8,capthick=2,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,6],fmt='*',capsize=8,capthick=2,color='black')
plt.legend()
plt.ylim([5*10**(-15),1.3*10**(-14)])
plt.show()

plt.figure(figsize=(20,15))
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,1],fmt='o',capsize=3,color='yellow',label='J')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,2],fmt='x',capsize=3,color='yellow')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,3],fmt='*',capsize=3,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,4],fmt='o',capsize=8,capthick=2,color='yellow')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,5],fmt='x',capsize=8,capthick=2,color='yellow')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,6],fmt='*',capsize=8,capthick=2,color='yellow')

plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,1],fmt='o',capsize=3,color='orange',label='H')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,2],fmt='x',capsize=3,color='orange')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,3],fmt='*',capsize=3,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,4],fmt='o',capsize=8,capthick=2,color='orange')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,5],fmt='x',capsize=8,capthick=2,color='orange')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,6],fmt='*',capsize=8,capthick=2,color='orange')

plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,1],fmt='o',capsize=3,color='black',label='K')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,2],fmt='x',capsize=3,color='black')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,3],fmt='*',capsize=3,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,4],fmt='o',capsize=8,capthick=2,color='black')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,5],fmt='x',capsize=8,capthick=2,color='black')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,6],fmt='*',capsize=8,capthick=2,color='black')
plt.legend()
plt.ylim([5*10**(-15),1.3*10**(-14)])
plt.show()

plt.figure(figsize=(20,15))
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,1],fmt='o',capsize=3,color='yellow',label='J')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,2],fmt='x',capsize=3,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,3],fmt='*',capsize=3,color='yellow')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,4],fmt='o',capsize=8,capthick=2,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,5],fmt='x',capsize=8,capthick=2,color='yellow')
plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,6],fmt='*',capsize=8,capthick=2,color='yellow')

#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,1],fmt='o',capsize=3,color='orange',label='H')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,2],fmt='x',capsize=3,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,3],fmt='*',capsize=3,color='orange')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,4],fmt='o',capsize=8,capthick=2,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,5],fmt='x',capsize=8,capthick=2,color='orange')
plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,6],fmt='*',capsize=8,capthick=2,color='orange')

#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,1],fmt='o',capsize=3,color='black',label='K')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,2],fmt='x',capsize=3,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,3],fmt='*',capsize=3,color='black')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,4],fmt='o',capsize=8,capthick=2,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,5],fmt='x',capsize=8,capthick=2,color='black')
plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,6],fmt='*',capsize=8,capthick=2,color='black')
plt.legend()
plt.ylim([5*10**(-15),1.3*10**(-14)])
plt.show()

# %%
plt.figure(figsize=(20,15))
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,1],yerr=NOISE_J[:,1],fmt='o',capsize=3,color='yellow',label='J')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,2],fmt='x',capsize=3,color='yellow')
#plt.errorbar(SIGNAL_J[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,3],fmt='*',capsize=3,color='yellow')
plt.errorbar(SIGNAL_g[:,0],SIGNAL_g[:,2],yerr=NOISE_g[:,5],fmt='o',capsize=8,capthick=2,color='yellow',label='g')
#plt.errorbar(SIGNAL_r[:,0],SIGNAL_J[:,2],yerr=NOISE_J[:,5],fmt='x',capsize=8,capthick=2,color='yellow')
#plt.errorbar(SIGNAL_i[:,0],SIGNAL_J[:,3],yerr=NOISE_J[:,6],fmt='*',capsize=8,capthick=2,color='yellow')

#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,1],fmt='o',capsize=3,color='orange',label='H')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,2],yerr=NOISE_H[:,2],fmt='x',capsize=3,color='orange')
#plt.errorbar(SIGNAL_H[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,3],fmt='*',capsize=3,color='orange')
#plt.errorbar(SIGNAL_g[:,0],SIGNAL_H[:,1],yerr=NOISE_H[:,4],fmt='o',capsize=8,capthick=2,color='orange')
plt.errorbar(SIGNAL_r[:,0],SIGNAL_r[:,2],yerr=NOISE_r[:,5],fmt='x',capsize=8,capthick=2,color='orange',label='r')
#plt.errorbar(SIGNAL_i[:,0],SIGNAL_H[:,3],yerr=NOISE_H[:,6],fmt='*',capsize=8,capthick=2,color='orange')

#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,1],fmt='o',capsize=3,color='black',label='K')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,2],fmt='x',capsize=3,color='black')
#plt.errorbar(SIGNAL_K[:,0],SIGNAL_K[:,3],yerr=NOISE_K[:,3],fmt='*',capsize=3,color='black')
#plt.errorbar(SIGNAL_g[:,0],SIGNAL_K[:,1],yerr=NOISE_K[:,4],fmt='o',capsize=8,capthick=2,color='black')
#plt.errorbar(SIGNAL_r[:,0],SIGNAL_K[:,2],yerr=NOISE_K[:,5],fmt='x',capsize=8,capthick=2,color='black')
plt.errorbar(SIGNAL_i[:,0],SIGNAL_i[:,2],yerr=NOISE_i[:,5],fmt='*',capsize=8,capthick=2,color='black',label='i')
plt.legend()
#plt.ylim([5*10**(-15),1.3*10**(-14)])
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.errorbar(SIGNAL_star_J[:,0],SIGNAL_star_J[:,2],yerr=NOISE_star_J[:,5],fmt='o',capsize=8,capthick=2,color='r',label='J')
plt.errorbar(SIGNAL_star_H[:,0],SIGNAL_star_H[:,2],yerr=NOISE_star_H[:,5],fmt='o',capsize=8,capthick=2,color='b',label='H')
plt.errorbar(SIGNAL_star_K[:,0],SIGNAL_star_K[:,2],yerr=NOISE_star_K[:,5],fmt='o',capsize=8,capthick=2,color='g',label='K')
plt.legend()
plt.ylim([10*10**(-15),8*10**(-14)])
plt.show()

plt.figure(figsize=(20,15))
plt.errorbar(SIGNAL_star_J[:,0],SIGNAL_star_J[:,2],yerr=NOISE_star_J[:,5],fmt='o',capsize=8,capthick=2,color='r',label='J')
#plt.errorbar(SIGNAL_star_H[:,0],SIGNAL_star_H[:,2],yerr=NOISE_star_H[:,5],fmt='o',capsize=8,capthick=2,color='b',label='H')
#plt.errorbar(SIGNAL_star_K[:,0],SIGNAL_star_K[:,2],yerr=NOISE_star_K[:,5],fmt='o',capsize=8,capthick=2,color='g',label='K')
plt.legend()
plt.ylim([66*10**(-15),7.3*10**(-14)])
plt.show()

plt.figure(figsize=(20,15))
#plt.errorbar(SIGNAL_star_J[:,0],SIGNAL_star_J[:,2],yerr=NOISE_star_J[:,5],fmt='o',capsize=8,capthick=2,color='r',label='J')
plt.errorbar(SIGNAL_star_H[:,0],SIGNAL_star_H[:,2],yerr=NOISE_star_H[:,5],fmt='o',capsize=8,capthick=2,color='b',label='H')
#plt.errorbar(SIGNAL_star_K[:,0],SIGNAL_star_K[:,2],yerr=NOISE_star_K[:,5],fmt='o',capsize=8,capthick=2,color='g',label='K')
plt.legend()
#plt.ylim([5*10**(-15),1.3*10**(-14)])
plt.show()

plt.figure(figsize=(20,15))
#plt.errorbar(SIGNAL_star_J[:,0],SIGNAL_star_J[:,2],yerr=NOISE_star_J[:,5],fmt='o',capsize=8,capthick=2,color='r',label='J')
#plt.errorbar(SIGNAL_star_H[:,0],SIGNAL_star_H[:,2],yerr=NOISE_star_H[:,5],fmt='o',capsize=8,capthick=2,color='b',label='H')
plt.errorbar(SIGNAL_star_K[:,0],SIGNAL_star_K[:,2],yerr=NOISE_star_K[:,5],fmt='o',capsize=8,capthick=2,color='g',label='K')
plt.legend()
#plt.ylim([5*10**(-15),1.3*10**(-14)])
plt.show()
