# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lag_thermal = np.loadtxt('NGC3783/long-run-3_lag_thermal.txt')
lag_K = np.loadtxt('NGC3783/long-run-3_mu_power_K.txt')
lag_H = np.loadtxt('NGC3783/long-run-3_mu_power_H.txt')
lag_J = np.loadtxt('NGC3783/long-run-3_mu_power_J.txt')
lag_g = np.loadtxt('NGC3783/long-run-3_mu_power_G.txt')
lag_r = np.loadtxt('NGC3783/long-run-3_mu_power_r.txt')
lag_i = np.loadtxt('NGC3783/long-run-3_mu_power_i.txt')

lag_thermal_2 = np.loadtxt('NGC3783/long-run-4_lag_thermal.txt')
lag_K_2 = np.loadtxt('NGC3783/long-run-4_mu_power_K.txt')
lag_H_2 = np.loadtxt('NGC3783/long-run-4_mu_power_H.txt')
lag_J_2 = np.loadtxt('NGC3783/long-run-4_mu_power_J.txt')
lag_g_2 = np.loadtxt('NGC3783/long-run-4_mu_power_G.txt')
lag_r_2 = np.loadtxt('NGC3783/long-run-4_mu_power_r.txt')
lag_i_2 = np.loadtxt('NGC3783/long-run-4_mu_power_i.txt')

lag_thermal_3 = np.loadtxt('NGC3783/long-run-5_lag_thermal.txt')
lag_K_3 = np.loadtxt('NGC3783/long-run-5_mu_power_K.txt')
lag_H_3 = np.loadtxt('NGC3783/long-run-5_mu_power_H.txt')
lag_J_3 = np.loadtxt('NGC3783/long-run-5_mu_power_J.txt')
lag_g_3 = np.loadtxt('NGC3783/long-run-5_mu_power_G.txt')
lag_r_3 = np.loadtxt('NGC3783/long-run-5_mu_power_r.txt')
lag_i_3 = np.loadtxt('NGC3783/long-run-5_mu_power_i.txt')

thermal_list_5 = np.loadtxt('NGC3783/thermal_list_5')
thermal_list_7 = np.loadtxt('NGC3783/thermal_list_7')

H_list_5 = np.loadtxt('NGC3783/H_list_5')
H_list_5 = H_list_5[np.ma.masked_where(0.1<H_list_5[:,0],H_list_5[:,0]).mask,:]
H_list_7 = np.loadtxt('NGC3783/H_list_7')
H_list_7 = H_list_7[np.ma.masked_where(0.1<H_list_7[:,0],H_list_7[:,0]).mask,:]

K_list_5 = np.loadtxt('NGC3783/K_list_5')
K_list_5 = K_list_5[np.ma.masked_where(0.1<K_list_5[:,0],K_list_5[:,0]).mask,:]
K_list_7 = np.loadtxt('NGC3783/K_list_7')
K_list_7 = K_list_7[np.ma.masked_where(0.1<K_list_7[:,0],K_list_7[:,0]).mask,:]

# %%
thermal_list_5 = np.loadtxt('NGC3783/thermal_list_5')
thermal_list_7 = np.loadtxt('NGC3783/thermal_list_7')

H_list_5 = np.loadtxt('NGC3783/H_list_5')
H_list_5 = H_list_5[np.ma.masked_where(0.1<H_list_5[:,0],H_list_5[:,0]).mask,:]
H_list_7 = np.loadtxt('NGC3783/H_list_7')
H_list_7 = H_list_7[np.ma.masked_where(0.1<H_list_7[:,0],H_list_7[:,0]).mask,:]

K_list_5 = np.loadtxt('NGC3783/K_list_5')
K_list_5 = K_list_5[np.ma.masked_where(0.1<K_list_5[:,0],K_list_5[:,0]).mask,:]
K_list_7 = np.loadtxt('NGC3783/K_list_7')
K_list_7 = K_list_7[np.ma.masked_where(0.1<K_list_7[:,0],K_list_7[:,0]).mask,:]

# %%
mask = ~np.isnan(lag_thermal[:,0])
lag_thermal = lag_thermal[mask,:]
mask = ~np.isnan(lag_K[:,0])
lag_K = lag_K[mask,:]
mask = ~np.isnan(lag_H[:,0])
lag_H = lag_H[mask,:]
mask = ~np.isnan(lag_J[:,0])
lag_J = lag_J[mask,:]
mask = ~np.isnan(lag_g[:,0])
lag_g = lag_g[mask,:]
mask = ~np.isnan(lag_r[:,0])
lag_r = lag_r[mask,:]
mask = ~np.isnan(lag_i[:,0])
lag_i = lag_i[mask,:]
#lag_thermal = np.exp(lag_thermal)
print lag_thermal[9,0]

mask = ~np.isnan(lag_thermal_2[:,0])
lag_thermal_2 = lag_thermal_2[mask,:]
mask = ~np.isnan(lag_K_2[:,0])
lag_K_2 = lag_K_2[mask,:]
mask = ~np.isnan(lag_H_2[:,0])
lag_H_2 = lag_H_2[mask,:]
mask = ~np.isnan(lag_J_2[:,0])
lag_J_2 = lag_J_2[mask,:]
mask = ~np.isnan(lag_g_2[:,0])
lag_g_2 = lag_g_2[mask,:]
mask = ~np.isnan(lag_r_2[:,0])
lag_r_2 = lag_r_2[mask,:]
mask = ~np.isnan(lag_i_2[:,0])
lag_i_2 = lag_i_2[mask,:]
#lag_thermal = np.exp(lag_thermal)
print lag_thermal_2[15,0]

mask = ~np.isnan(lag_thermal_3[:,0])
lag_thermal_3 = lag_thermal_3[mask,:]
mask = ~np.isnan(lag_K_3[:,0])
lag_K_3 = lag_K_3[mask,:]
mask = ~np.isnan(lag_H_3[:,0])
lag_H_3 = lag_H_3[mask,:]
mask = ~np.isnan(lag_J_3[:,0])
lag_J_3 = lag_J_3[mask,:]
mask = ~np.isnan(lag_g_3[:,0])
lag_g_3 = lag_g_3[mask,:]
mask = ~np.isnan(lag_r_3[:,0])
lag_r_3 = lag_r_3[mask,:]
mask = ~np.isnan(lag_i_3[:,0])
lag_i_3 = lag_i_3[mask,:]
#lag_thermal = np.exp(lag_thermal)
print lag_thermal_3[:,0]
print K_list_5[:,0]
# Out:
# 3.20918725028
# 3.60433452365
# [3.6758974  3.9201666  4.26171649 4.28437896 4.20880711 4.23718385
#  4.35083427 4.35167492 4.31421996 4.48873458 4.47233267 4.55171979
#  4.56465769 4.71023798 4.73474906 4.73455042 4.75243942 4.71596311
#  4.54742582 4.52639473 4.49467101 4.52514895 4.50374029 4.45763988
#  4.36125095 4.3569653  4.44902209 4.50516116 4.52779556 4.53371782]
# [2.3271734  2.3624376  2.36945748 2.36551531 2.36540143 2.41902866
#  2.41114428 2.41921523 2.41561136 2.4444287  2.44710894 2.44528057
#  2.44828545 2.44076393 2.44326943 2.43874135 2.45737977 2.44059242
#  2.44396691 2.44701225 2.45159557 2.48021255 2.48365393 2.48697186
#  2.48319811 2.47801556 2.4904055  2.49154694 2.49039388 2.49734002
#  2.5008949  2.50185501 2.53847879 2.54342711 2.56339956 2.58661978
#  2.56750402 2.56269202 2.57082767 2.55363619 2.56107583 2.56010304
#  2.55562243 2.55685281 2.54868203 2.55127639 2.55421586 2.54635218
#  2.53457828 2.52965831 2.52029994 2.52866034 2.51077502 2.51288436
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(lag_thermal[0:8,0])
plt.plot(lag_thermal[9:,0])
plt.plot(lag_thermal_2[0:14,0])
plt.plot(lag_thermal_2[15:,0])
plt.plot(lag_thermal_3[:,0])
plt.plot(thermal_list_5[:,0])
plt.plot(thermal_list_7[:,0])
plt.title('Lag Thermal')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(lag_K[0:8,0])
plt.plot(lag_K[9:,0])
plt.plot(lag_K_2[0:14,0])
plt.plot(lag_K_2[15:,0])
plt.plot(lag_K_3[:,0])
plt.plot(K_list_5[:,0])
plt.plot(K_list_7[:,0])
plt.title('Lag K')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(lag_H[0:8,0])
plt.plot(lag_H[9:,0])
plt.plot(lag_H_2[0:14,0])
plt.plot(lag_H_2[15:,0])
plt.plot(lag_H_3[:,0])
plt.plot(H_list_5[:,0])
plt.plot(H_list_7[:,0])
plt.title('Lag H')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(lag_J[0:8,0])
plt.plot(lag_J[9:,0])
plt.plot(lag_J_2[0:14,0])
plt.plot(lag_J_2[15:,0])
plt.plot(lag_J_3[:,0])
plt.title('Lag J')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(lag_g[0:8,0])
plt.plot(lag_g[9:,0])
plt.plot(lag_g_2[0:14,0])
plt.plot(lag_g_2[15:,0])
plt.plot(lag_g_3[:,0])
plt.title('Lag g')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(lag_r[0:8,0])
plt.plot(lag_r[9:,0])
plt.plot(lag_r_2[0:14,0])
plt.plot(lag_r_2[15:,0])
plt.plot(lag_r_3[:,0])
plt.title('Lag r')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(lag_i[0:8,0])
plt.plot(lag_i[9:,0])
plt.plot(lag_i_2[0:14,0])
plt.plot(lag_i_2[15:,0])
plt.plot(lag_i_3[:,0])
plt.title('Lag i')
plt.show()
