# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
thermal_list_5 = np.loadtxt('NGC3783/thermal_list_5')
thermal_list_7 = np.loadtxt('NGC3783/thermal_list_7')

H_list_5 = np.loadtxt('NGC3783/H_list_5')
H_list_5 = H_list_5[np.ma.masked_where(0.1<H_list_5[:,0],H_list_5[:,0]).mask,:]
H_list_7 = np.loadtxt('NGC3783/H_list_7')
H_list_7 = H_list_7[np.ma.masked_where(0.1<H_list_7[:,0],H_list_7[:,0]).mask,:]

K_list_5 = np.loadtxt('NGC3783/K_list_5')
K_list_5 = K_list_5[np.ma.masked_where(0.1<K_list_5[:,0],K_list_5[:,0]).mask,:]
K_list_7 = np.loadtxt('NGC3783/K_list_7')
K_list_7 = K_list_7[np.ma.masked_where(0.1<K_list_7[:,0],K_list_7[:,0]).mask,:]

# %%
thermal_list_3 = np.loadtxt('NGC3783/thermal_list_3')
thermal_list_4 = np.loadtxt('NGC3783/thermal_list_4')

H_list_3 = np.loadtxt('NGC3783/H_list_3')
H_list_3 = H_list_3[np.ma.masked_where(0.1<H_list_3[:,0],H_list_3[:,0]).mask,:]
H_list_4 = np.loadtxt('NGC3783/H_list_4')
H_list_4 = H_list_4[np.ma.masked_where(0.1<H_list_4[:,0],H_list_4[:,0]).mask,:]

K_list_3 = np.loadtxt('NGC3783/K_list_3')
K_list_3 = K_list_3[np.ma.masked_where(0.1<K_list_3[:,0],K_list_3[:,0]).mask,:]
K_list_4 = np.loadtxt('NGC3783/K_list_4')
K_list_4 = K_list_4[np.ma.masked_where(0.1<K_list_4[:,0],K_list_4[:,0]).mask,:]

# %%
thermal_list_1 = np.loadtxt('NGC3783-2/thermal_list_3')
thermal_list_2 = np.loadtxt('NGC3783-2/thermal_list_4')

H_list_1 = np.loadtxt('NGC3783-2/H_list_1')
H_list_1 = H_list_1[np.ma.masked_where(0.1<H_list_1[:,0],H_list_1[:,0]).mask,:]
H_list_2 = np.loadtxt('NGC3783-2/H_list_2')
H_list_2 = H_list_2[np.ma.masked_where(0.1<H_list_2[:,0],H_list_2[:,0]).mask,:]

K_list_1 = np.loadtxt('NGC3783-2/K_list_1')
K_list_1 = K_list_1[np.ma.masked_where(0.1<K_list_1[:,0],K_list_1[:,0]).mask,:]
K_list_2 = np.loadtxt('NGC3783-2/K_list_2')
K_list_2 = K_list_2[np.ma.masked_where(0.1<K_list_2[:,0],K_list_2[:,0]).mask,:]

# %%
transfer_1 = np.loadtxt('NGC3783-2/transfer_list_1')
transfer_3 = np.loadtxt('NGC3783/transfer_list_3')
transfer_4 = np.loadtxt('NGC3783/transfer_list_4')
transfer_5 = np.loadtxt('NGC3783/transfer_list_5')
transfer_7 = np.loadtxt('NGC3783/transfer_list_7')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-70cfe915a136> in <module>()
# ----> 1 transfer_1 = np.loadtxt('NGC3783-2/transfer_list_1')
#       2 transfer_3 = np.loadtxt('NGC3783/transfer_list_3')
#       3 transfer_4 = np.loadtxt('NGC3783/transfer_list_4')
#       4 transfer_5 = np.loadtxt('NGC3783/transfer_list_5')
#       5 transfer_7 = np.loadtxt('NGC3783/transfer_list_7')
#
# /home/lynge/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     915             fname = str(fname)
#     916         if _is_string_like(fname):
# --> 917             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     918             fencoding = getattr(fh, 'encoding', 'latin1')
#     919             fh = iter(fh)
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(thermal_list_1[:,0])
#plt.plot(thermal_list_2[:,0])
plt.plot(thermal_list_3[:,0])
plt.plot(thermal_list_4[:,0])
plt.plot(thermal_list_5[:,0])
plt.plot(thermal_list_7[:,0])
plt.xlim([0,120])
plt.ylim([1,6])
plt.title('Lag Thermal')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(thermal_list_1[:,1])
#plt.plot(thermal_list_2[:,0])
plt.plot(thermal_list_3[:,1])
plt.plot(thermal_list_4[:,1])
plt.plot(thermal_list_5[:,1])
plt.plot(thermal_list_7[:,1])
plt.xlim([0,120])
plt.ylim([0,0.5])
plt.title('Width Thermal')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(K_list_1[:,0])
#plt.plot(K_list_2[:,0])
plt.plot(K_list_3[:,0])
plt.plot(K_list_4[:,0])
plt.plot(K_list_5[:,0])
plt.plot(K_list_7[:,0])
plt.xlim([0,120])
plt.ylim([2,3])
plt.title('Lag K')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(K_list_1[:,1])
#plt.plot(K_list_2[:,0])
plt.plot(K_list_3[:,1])
plt.plot(K_list_4[:,1])
plt.plot(K_list_5[:,1])
plt.plot(K_list_7[:,1])
plt.xlim([0,120])
#plt.ylim([1,6])
plt.title('Width K')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(H_list_1[:,0])
#plt.plot(H_list_2[:,0])
plt.plot(H_list_3[:,0])
plt.plot(H_list_4[:,0])
plt.plot(H_list_5[:,0])
plt.plot(H_list_7[:,0])
plt.xlim([0,120])
plt.ylim([2,3])
plt.title('Lag H')
plt.show()
plt.figure(figsize=(10,10))
plt.plot(H_list_1[:,1])
#plt.plot(H_list_2[:,0])
plt.plot(H_list_3[:,1])
plt.plot(H_list_4[:,1])
plt.plot(H_list_5[:,1])
plt.plot(H_list_7[:,1])
plt.xlim([0,120])
#plt.ylim([1,6])
plt.title('Width H')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(thermal_list_1[:,3])
#plt.plot(thermal_list_2[:,0])
plt.plot(thermal_list_3[:,3])
plt.plot(thermal_list_4[:,3])
plt.plot(thermal_list_5[:,3])
plt.plot(thermal_list_7[:,3])
plt.xlim([0,120])
#plt.ylim([1,6])
plt.title('A_T')
plt.show()
