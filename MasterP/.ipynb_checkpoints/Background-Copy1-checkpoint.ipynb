# %%
import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LogNorm
import scipy.stats as stats
from matplotlib import gridspec
import aplpy as apl #The Astronomy Plotting Library for python
import astropy
from astropy.stats import sigma_clip
from astropy.modeling import functional_models, models, fitting
import astropy.units as U
from astropy.coordinates import ICRS, Galactic, FK4, FK5, Angle, Latitude, Longitude
import astropy.constants as C
from astropy import wcs
import astropy.io.fits as fits
from astropy.io import ascii
import astropy.coordinates as coord
from astropy.coordinates import SkyCoord
from astropy.stats import signal_to_noise_oir_ccd as SNRas
#import spectral_cube as SC
#from spectral_cube import SpectralCube as sc
from astropy.wcs import WCS
matplotlib.use('Agg')
import matplotlib.cm as cm
#import astrometry as ast
import pyfits
import requests
import json
import os
from sklearn import datasets, linear_model
from scipy.optimize import curve_fit
import numpy.ma as ma
from astropy.table import Table, Column
import pyextract
import sewpy
import pandas as pd
from astropy import units as u
#import alipy

# %%
def dist(mid,end):
    return np.sqrt((mid[0] - end[0])**2 + (mid[1] - end[1])**2)

# %%
def flux_cal(A_mag,B_mag,B_flux):
    '''Flux of A found through magnitude and flux of B'''
    return B_flux*10**((B_mag-A_mag)/2.5)

# %%
def Basic(quasar,header):
    '''Provides a basic list of neccesities from the fits header file for use in the later \
    flux determination, it does not serve an individual purpose beyound that'''
    AGNdata = quasar #np.rot90(np.rot90(np.fliplr(quasar)))
    #header = data[0].header
    #print header
    RAstd = header['CRVAL1']
    DECstd = header['CRVAL2']
    #print RAstd, DECstd
    pixspa = header['PIXSCALE']/(3600.)
    #print pixspa
    RAstdpix = header['CRPIX1']
    DECstdpix = header['CRPIX2']
    exptime = 10 # header['EXPTIME']
    return header,AGNdata,RAstd,DECstd,pixspa,RAstdpix,DECstdpix,exptime

# %%
def curve(quasar,header,w,center,apparature):
    '''Determines the FLUX of the stellar object given the the numpy array of the image, \
    the header of the fits file, the astropy coordinate representation, \
    the object position and the apparature of interest'''
    header,AGNdata,RAstd,DECstd,pixspa,RAstdpix,DECstdpix,exptime = Basic(quasar,header)
    #AGNdata = np.swapaxes(AGNdata,0,1)
    y, x = np.ogrid[0:header['NAXIS1'],0:header['NAXIS1']]
    #w = np.swapaxes(w,0,1)
    #F_AGN = np.zeros((512,512,3)) #((int(2*apparature/pixspa)+1,int(2*apparature/pixspa)+1,3))
    #print center
    x1 = w.all_world2pix(center[0],center[1],0)
    x1,y1 = (x1[0]),(x1[1])
    if 15 < x1 < header['NAXIS1'] - 15 and 15 < y1 < header['NAXIS2'] - 15:
        try:
            mask = ((y-y1)**2 + (x-x1)**2) > (apparature/float(pixspa))**2
            AGNdata[mask] = float(0)
            mask = AGNdata == 0.
            rows = np.flatnonzero((~mask).sum(axis=1))
            cols = np.flatnonzero((~mask).sum(axis=0))
            AGNdata = AGNdata[rows.min():rows.max()+1, cols.min():cols.max()+1]
            #print apparature/float(pixspa)
        except:
            AGNdata = np.array([[float(0),float(0)],[float(0),float(0)]])
    else:
        AGNdata = np.array([[float(0),float(0)],[float(0),float(0)]])
    #if np.sum(AGNdata) < 500:
    #    AGNdata = np.array([[float(0),float(0)],[float(0),float(0)]])
    return AGNdata, x1, y1

# %%
quasJ = [os.path.join('/media/lynge/Lynge-Back-up/NGC3783/r',f) \
        for f in os.listdir('/media/lynge/Lynge-Back-up/NGC3783/r')]

sky_RA_WORLD = SkyCoord('11:38:59 -37:44:44', unit=(u.hourangle, u.deg)).ra.degree #NGC3783
sky_DEC_WORLD = SkyCoord('11:38:59 -37:44:44', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('22:09:11 -47:09:05', unit=(u.hourangle, u.deg)).ra.degree #NGC7213
#sky_DEC_WORLD = SkyCoord('22:09:11 -47:09:05', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('00:24:27 07:49:19', unit=(u.hourangle, u.deg)).ra.degree #P525-E
#sky_DEC_WORLD = SkyCoord('00:24:27 07:49:19', unit=(u.hourangle, u.deg)).dec.degree 

#sky_RA_WORLD = SkyCoord('18:45:10 -62:22:42', unit=(u.hourangle, u.deg)).ra.degree #F51
#sky_DEC_WORLD = SkyCoord('18:45:10 -62:22:42', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('00:55:07 00:42:41', unit=(u.hourangle, u.deg)).ra.degree #SA092_342
#sky_DEC_WORLD = SkyCoord('00:55:07 00:42:41', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('05:58:05.5 -38:20:43.5', unit=(u.hourangle, u.deg)).ra.degree #H0557
#sky_DEC_WORLD = SkyCoord('05:58:05.5 -38:20:43.5', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('01:23:47 -58:49:35', unit=(u.hourangle, u.deg)).ra.degree #F9
#sky_DEC_WORLD = SkyCoord('01:23:47 -58:49:35', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('20:44:09 -10:42:54', unit=(u.hourangle, u.deg)).ra.degree #MARK509
#sky_DEC_WORLD = SkyCoord('20:44:09 -10:42:54', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('05:16:17 -00:09:08', unit=(u.hourangle, u.deg)).ra.degree #AKN120
#sky_DEC_WORLD = SkyCoord('05:16:17 -00:09:08', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('13:06:26 -40:25:33', unit=(u.hourangle, u.deg)).ra.degree #ESO323
#sky_DEC_WORLD = SkyCoord('13:06:26 -40:25:33', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('01:54:38 00:43:41', unit=(u.hourangle, u.deg)).ra.degree #SA093_317
#sky_DEC_WORLD = SkyCoord('01:54:38 00:43:41', unit=(u.hourangle, u.deg)).dec.degree

#sky_RA_WORLD = SkyCoord('08:52:32 -00:39:17', unit=(u.hourangle, u.deg)).ra.degree #SA100_241
#sky_DEC_WORLD = SkyCoord('08:52:32 -00:39:17', unit=(u.hourangle, u.deg)).dec.degree

# %%
for i in range(len(quasJ)):
    print i, quasJ[i]
    data1, header = fits.getdata(quasJ[i],header=True) #RA---TAN data2 = data1
    data1 = np.array(data1,dtype='float')
    data2, header2 = fits.getdata(quasJ[i],header=True)
    data2 = np.array(data2,dtype='float')
    #print data1
    #print header['CTYPE2']
    #header['CTYPE1'] = "RA---TAN -SIP"
    #header['CTYPE2'] = "DEC--TAN -SIP"
    #print data1
    back = np.ones((header['NAXIS1'],header['NAXIS2']))
    a_sky = curve(data1,header,WCS(quasJ[i]),
                   (sky_RA_WORLD,sky_DEC_WORLD),0.003)[0]
    a_sky_mean = a_sky[(a_sky!=0) & (a_sky<1700)].mean()
    back[data2 == 0] *= 0
    back[data2 != 0] *= a_sky_mean
    #print a_sky_mean
    #data1 = np.subtract(data1,back)
    #print data1
    data2 = data2 - back
    #print data2
    #print data2
    #for j in range(len(np.shape(data[0]))):
    #    for k in range(len(np.shape(data[0]))):
    #        if data[j,k] != 0:
    #            data[j,k] = float(data[j,k]) - a_sky_mean
    #header['NDIT'] = 5
    '''header['A_ORDER'] = "0"
    header['B_ORDER'] = "0"
    header['AP_ORDER'] = "0"
    header['BP_ORDER'] = "0"
    header['A_0_2'] = "0"
    header['A_1_1'] = "0"
    header['A_2_0'] = "0"
    header['B_0_2'] = "0"
    header['B_1_1'] = "0"
    header['B_2_0'] = "0"
    header['AP_0_2'] = "0"
    header['AP_1_1'] = "0"
    header['AP_2_0'] = "0"
    header['AP_0_1'] = "0"
    header['AP_1_0'] = "0"
    header['BP_0_1'] = "0"
    header['BP_0_2'] = "0"
    header['BP_1_0'] = "0"
    header['BP_1_1'] = "0"
    header['BP_2_0'] = "0"'''
    fits.writeto(quasJ[i],data2,header,clobber=True)
    #print fits.getheader(quasH[i])['A_ORDER']
# Out:
# 0 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016119URs025.fits
# 1 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016119URs026.fits
# 2 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016119URs027.fits
# 3 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016127URs030.fits
# 4 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016127URs031.fits
# 5 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016127URs032.fits
# 6 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016134URs063.fits
# 7 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016134URs064.fits
# 8 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016134URs065.fits
# 9 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016141URs052.fits
# 10 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016141URs053.fits
# 11 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016141URs054.fits
# 12 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016158URs046.fits
# 13 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016158URs047.fits
# 14 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016158URs048.fits
# 15 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016165URs094.fits
# 16 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016165URs095.fits
# 17 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016165URs096.fits
# 18 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016173URs048.fits
# 19 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016173URs049.fits
# 20 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016173URs050.fits
# 21 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016180URs041.fits
# 22 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016180URs042.fits
# 23 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016180URs043.fits
# 24 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016195URs017.fits
# 25 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016195URs018.fits
# 26 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016195URs019.fits
# 27 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016202URs031.fits
# 28 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016202URs032.fits
# 29 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016202URs033.fits
# 30 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017054URs101.fits
# 31 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017054URs102.fits
# 32 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017054URs103.fits
# 33 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017062URs064.fits
# 34 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017062URs065.fits
# 35 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017062URs066.fits
# 36 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017102URs034.fits
# 37 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017102URs035.fits
# 38 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017102URs036.fits
# 39 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017109URs054.fits
# 40 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017109URs055.fits
# 41 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017109URs056.fits
# 42 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017123URs086.fits
# 43 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017123URs087.fits
# 44 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017123URs088.fits
# 45 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017132URs069.fits
# 46 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017132URs070.fits
# 47 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017132URs071.fits
# 48 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017140URs025.fits
# 49 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017140URs027.fits
# 50 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017148URs056.fits
# 51 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017148URs057.fits
# 52 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017148URs058.fits
# 53 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017156URs025.fits
# 54 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017156URs026.fits
# 55 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017156URs027.fits
# 56 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017163URs028.fits
# 57 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017163URs029.fits
# 58 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017163URs030.fits
# 59 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017170URs044.fits
# 60 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016337URs099.fits
# 61 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016344URs087.fits
# 62 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016344URs088.fits
# 63 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016344URs089.fits
# 64 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016352URs054.fits
# 65 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016352URs055.fits
# 66 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016352URs056.fits
# 67 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016360URs075.fits
# 68 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016360URs076.fits
# 69 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016360URs077.fits
# 70 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017002URs053.fits
# 71 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017002URs054.fits
# 72 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017002URs055.fits
# 73 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017009URs117.fits
# 74 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017009URs118.fits
# 75 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017009URs119.fits
# 76 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017017URs103.fits
# 77 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017017URs104.fits
# 78 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017017URs105.fits
# 79 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017024URs109.fits
# 80 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017024URs110.fits
# 81 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017024URs111.fits
# 82 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017031URs110.fits
# 83 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017031URs111.fits
# 84 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017031URs112.fits
# 85 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017039URs093.fits
# 86 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017039URs094.fits
# 87 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017039URs095.fits
# 88 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017046URs067.fits
# 89 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017046URs068.fits
# 90 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017170URs046.fits
# 91 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017178URs029.fits
# 92 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017178URs030.fits
# 93 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017178URs031.fits
# 94 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017187URs027.fits
# 95 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017187URs028.fits
# 96 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017187URs029.fits
# 97 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017194URs017.fits
# 98 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017194URs018.fits
# 99 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017194URs019.fits
# 100 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017201URs029.fits
# 101 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017201URs030.fits
# 102 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017201URs031.fits
# 103 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017210URs020.fits
# 104 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017210URs021.fits
# 105 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016210URs021.fits
# 106 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016337URs098.fits
# 107 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017046URs069.fits
# 108 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017170URs045.fits
# 109 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017210URs022.fits
# 110 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017300URs113.fits
# 111 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017300URs114.fits
# 112 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017300URs115.fits
# 113 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017307URs120.fits
# 114 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017307URs121.fits
# 115 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017307URs122.fits
# 116 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017315URs129.fits
# 117 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017315URs130.fits
# 118 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017315URs131.fits
# 119 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017324URs087.fits
# 120 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017324URs088.fits
# 121 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017324URs089.fits
# 122 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017331URs070.fits
# 123 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017331URs071.fits
# 124 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017331URs072.fits
# 125 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017339URs100.fits
# 126 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017339URs101.fits
# 127 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2017339URs102.fits
# 128 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016210URs022.fits
# 129 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016302URs069.fits
# /home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in less
#   from ipykernel import kernelapp as app
# /home/lynge/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice.
#   from ipykernel import kernelapp as app
# /home/lynge/.local/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 130 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016302URs070.fits
# 131 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016302URs071.fits
# 132 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016304URs039.fits
# 133 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016304URs040.fits
# 134 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016304URs041.fits
# 135 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016312URs106.fits
# 136 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016312URs107.fits
# 137 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016312URs108.fits
# 138 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016322URs114.fits
# 139 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016322URs115.fits
# 140 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016322URs116.fits
# 141 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016330URs066.fits
# 142 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016330URs067.fits
# 143 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016330URs068.fits
# 144 /media/lynge/Lynge-Back-up/NGC3783/g/IMG2016337URs097.fits
