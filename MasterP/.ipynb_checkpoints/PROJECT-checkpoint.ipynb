# %%
import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LogNorm
from matplotlib import gridspec
import aplpy as apl #The Astronomy Plotting Library for python
import astropy
import astropy.units as U
from astropy.coordinates import ICRS, Galactic, FK4, FK5, Angle, Latitude, Longitude
import astropy.constants as C
import astropy.io.fits as fits
import astropy.coordinates as coord
from astropy.coordinates import SkyCoord
import spectral_cube as SC
from spectral_cube import SpectralCube as sc
from astropy.wcs import WCS
matplotlib.use('Agg')
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:1352: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
data = fits.open('NGC3783_1_10_J.fits')
print data[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard             BITPIX  =                   16 / number of bits per data pixel                  NAXIS   =                    2 / number of data axes                            NAXIS1  =                  512 / length of data axis 1                          NAXIS2  =                  512 / length of data axis 2                          EXTEND  =                    T / FITS dataset may contain extensions            COMMENT   FITS (Flexible Image Transport System) format is defined in 'AstronomyCOMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H BZERO   =             0.000000 / offset data range to that of unsigned short    BSCALE  =             1.000000 / default scaling factor                         EXPOSURE=                 9180 / Total Exposure Time                            OBJECT  = 'NGC3783 '           / [string] Target Name                           IMAGETYP= 'OBJECT  '           / [string] Image type                            OBSCODE =                   10 / [integer] REMOS observing code                 OBSTYPE = 'AGN     '           / [string] observation type                      OBSID   =               189932 / [integer] Observations ID number               SUBID   =                    1 / [integer] Observations sub ID number           PROPID  =                35314 / [integer] Observations sub ID number           OBID    =               215039 / [integer] Observations sub ID number           EXPTIME =               10.000 / [seconds] Exposure time in seconds             FILTER  = 'J       '           / [string] Filter name                           DATE-OBS= '2017-04-21T02:39:59.022' / UTC date of observation                   UT      =              2.65611 / [hours] UT of observation                      MJD-OBS =       57864.11109400 / Modified Julian Day of image acquisition       RON     =            100.00000 / [float] Read-out Noise (e-)                    GAIN    =                5.000 / [float] e-/ADU conversion factor               SATUR   =          65536.00000 / [float] Saturation level in ADU                LINEAR  =          15000.00000 / [float] Linearity limit in ADU                 DIT     =                10.00 / [seconds] DIT in seconds                       NDIT    =                    1 / [integer] Numbers of DITs                      NINT    =                    1 / [integer] Numbers of DIT*NDIT series           DITHID  =                   99 / [integer] Frame number of dither sequence      NDITHERS=                    5 / [integer] Numbers of dither positions          OBSERVAT= 'ESO-LaSilla'        / [string] Observatory name                      GEOLON  =            -70.73450 / [degress] Longitude of site                    GEOLAT  =            -29.25840 / [degress] Latitude of site                     GEOELEV =               2377.0 / [degress] Elevation of site                    TELESCOP= 'REM     '           / [string] Telescope name                        INSTRUME= 'REMIR   '           / [string] Instrument name                       PI-COI  = '                          Darach_Watson' / [string] PI Name          PIHOME  = '                        Univ_Copenhagen' / [string] PI Institution   PIMAIL  = '               darach@dark-cosmology.dk' / [string] PI email address TEMPDATE= 'Fri Apr 21 02:35:01 2017' / [string] Date of start temperature       TEMPCHIP=              -180.00 / [K] Chip temperature at start                  TEMPCFC =              -180.30 / [K] Head temperature at start                  PRESDATE= 'Fri Apr 21 02:35:03 2017' / [string] Date of start pressure          PRESINST= 2.75000000000000E-06 / [double] Pressure at start                     PROCSTAT=                    0 / [integer] Processing status                    HUMIDITY=                47.00 / [%] Humidity at dome                           TEMP    =                12.07 / [K] Temperature at dome                         ...

# %%
def pixel(x,y):
    RA = RAstd + x*pixspa - RAstdpix*pixspa
    DEC = DECstd + y*pixspa - DECstdpix*pixspa
    return RA, DEC

# %%
plt.figure()
plt.imshow(data[0].data, cmap='pink')
AGNdata = data[0].data
header = data[0].header
RAstd = header['CRVAL1']
DECstd = header['CRVAL2']
#print RAstd, DECstd
pixspa = header['PIXSCALE']/(3600.)
#print pixspa
RAstdpix = header['CRPIX1']
DECstdpix = header['CRPIX2']

d = 512 - 295
f = 512 - 305
g = 512 - 255
h = 512 - 265
#print d,f,g,h
#print pixel(40,100)
#print pixel(300,300)
#print pixel(450,500)
print pixel(300,305)
print AGNdata[295:310,305:315]
#for i in range(500):
#    print i, max(AGNdata[:,i])
#    print pixel(i,300)
#print AGNdata[290:300,160:170]
# Out:
# (174.78755005563335, -37.73606360310001)
# [[   3   12    8    4    6    5   29   23   15   12]
#  [  13   19   26   29   34   23   23   24   20   17]
#  [  26   33   39   70  114  103   77   38   20   21]
#  [  33   48   91  393  897  796  372  146   72   32]
#  [  45   91  293 1484 3101 2553 1140  373  126   47]
#  [  50  187  755 2435 3962 3038 1508  541  156   51]
#  [  77  485 1600 2958 4565 3677 1837  672  218   85]
#  [ 127  937 2713 3227 3325 3253 1897  734  250  113]
#  [ 110  914 2975 3116 2170 1754 1188  558  190   82]
#  [  70  486 1695 2184 1635 1004  561  274  123   59]
#  [  44  187  591  921  859  552  274  128   72   58]
#  [  23   77  184  255  274  232  139   66   38   45]
#  [  14   32   59   70   86   74   57   37   28   32]
#  [  12   26   24   25   37   26   22   20   19   23]
#  [   8   18   18   11   19   19   16   22   21   12]]

# %%
c = SkyCoord('11h39m01.68s', '-37d44m18.2s')
c1 = SkyCoord('11h39m50s', '-37d44m18.2s')
print c.ra.deg, c.dec.deg
#c.dec.lat
sc = SkyCoord(header['GEOLAT'],header['GEOLON'],header['GEOELEV'],frame='barycentrictrueecliptic',unit='deg',representation = 'unitspherical')
print sc.galactic
print sc.obsgeoloc

astropy.coordinates.ICRS().representation_info
# Out:
# 174.757 -37.7383888889
# <SkyCoord (Galactic): (l, b) in deg
#     (289.80685891, -45.97381024)>
# None
# {astropy.coordinates.representation.CartesianRepresentation: {u'names': [u'x',
#    u'y',
#    u'z'],
#   u'units': [None, None, None]},
#  astropy.coordinates.representation.UnitSphericalRepresentation: {u'names': (u'ra',
#    u'dec'),
#   u'units': (Unit("deg"), Unit("deg"))},
#  astropy.coordinates.representation.SphericalRepresentation: {u'names': (u'ra',
#    u'dec',
#    u'distance'),
#   u'units': (Unit("deg"), Unit("deg"), None)},
#  astropy.coordinates.representation.PhysicsSphericalRepresentation: {u'names': [u'phi',
#    u'theta',
#    u'r'],
#   u'units': [Unit("deg"), Unit("deg"), None]},
#  astropy.coordinates.representation.CylindricalRepresentation: {u'names': [u'rho',
#    u'phi',
#    u'z'],
#   u'units': [None, Unit("deg"), None]}}

# %%
data = fits.open('NGC3783_1_10_J.fits')[0]
dataW = WCS(data.header)
#sky = fits.open('NGC3783_3_10_K_sky.fits')
#correct = data - sky

# %%
print data.header['CRVAL2']
print data.header['CDELT2']
print data.header['CRVAL1']
print data.header['CDELT1']

ap = apl.FITSFigure(data,figsize=(5,5))
#ap.recenter(c.ra.deg,c.dec.deg,0.0053391667)
ap.show_colorscale(aspect='auto')
ap.add_grid()
ap.show_circles(c.ra.deg,c.dec.deg,0.0053391667)

#ap.set_xaxis_coord_type('longitude')
# Out:
# -37.7279236031
# 0.0003391667
# 174.765504222
# -0.0003391667
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -4.896e+01 [aplpy.core]
# INFO: Auto-setting vmax to  4.733e+01 [aplpy.core]

# %%
ap = apl.FITSFigure(data,figsize=(5,5))
#ap.recenter(c.ra.deg,c.dec.deg,0.0053391667)
ap.show_colorscale(aspect='auto')
ap.add_grid()
ap.show_circles(174.774,-37.7550888889,0.004)
# Out:
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -4.896e+01 [aplpy.core]
# INFO: Auto-setting vmax to  4.733e+01 [aplpy.core]

# %%
ap = apl.FITSFigure(data,figsize=(5,5))
ap.recenter(174.774,-37.7540888889,0.004)
ap.show_colorscale(aspect='auto')
ap.add_grid()
ap.show_circles(174.774,-37.7540888889,0.004)
# Out:
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -4.896e+01 [aplpy.core]
# INFO: Auto-setting vmax to  4.733e+01 [aplpy.core]

# %%
ap = apl.FITSFigure(data,figsize=(5,5))
ap.recenter(c.ra.deg,c.dec.deg,0.007)
ap.show_colorscale(aspect='auto')
ap.add_grid()
ap.show_circles(c.ra.deg,c.dec.deg,0.007)
# Out:
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -4.896e+01 [aplpy.core]
# INFO: Auto-setting vmax to  4.733e+01 [aplpy.core]

# %% [raw]
# ap = apl.FITSFigure('NGC3783_1_10_J.fits',figsize=(5,5))
# ap.recenter(c.ra.hour,c.dec.deg,height=0.0134)
# ap.show_colorscale(aspect='auto')
# ap.add_grid()
#
# ap = apl.FITSFigure('NGC3783_2_10_H.fits',figsize=(5,5))
# ap.show_colorscale(aspect='auto')
# ap.add_grid()
#
# ap = apl.FITSFigure('NGC3783_3_10_K.fits',figsize=(5,5))
# ap.show_colorscale(aspect='auto')
# ap.add_grid()

# %%
ap = apl.FITSFigure(data,figsize=(5,5))
ap.show_colorscale(aspect='auto')
ap.add_colorbar()
ap.add_grid()
# Out:
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -4.896e+01 [aplpy.core]
# INFO: Auto-setting vmax to  4.733e+01 [aplpy.core]

# %%
print AGNdata[200:300][200:300] #sum(AGNdata[200:300,200:300]), sum(AGNdata), np.shape(AGNdata)
# Out:
# []

# %%
xaxis=(np.arange(header['NAXIS1'])-(header['CRPIX1']-1))*header['CDELT1']*60.0**2
yaxis=(np.arange(header['NAXIS2'])-(header['CRPIX2']-1))*header['CDELT2']*60.0**2
X, Y = np.meshgrid(xaxis, yaxis)

# %%
plt.figure()
plt.contourf(X,Y,AGNdata,500)
plt.show()

# %%
AGNsum = 0
for i in range(100):
    for j in range(100):
        AGNsum = AGNsum + AGNdata[i+300,j+300]
print AGNsum
# Out:
# 72754
