# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import math
import random

# %%
MAG_HD101274_B = 9.23
MAG_HD101274_V = 9.12
MAG_HD101274_G = 9.192
MAG_HD101274_J = float('nan')
MAG_HD101274_H = float('nan')
MAG_HD101274_K = float('nan')

MAG_HD101274_g = 9.1124
MAG_HD101274_r = 9.5110
MAG_HD101274_i = float('nan')
MAG_HD101274_z = 10.3072

MAG_TYCHO_2_7740_22_1_B = 12.58
MAG_TYCHO_2_7740_22_1_V = 12.12
MAG_TYCHO_2_7740_22_1_G = 11.78
MAG_TYCHO_2_7740_22_1_J = 10.919
MAG_TYCHO_2_7740_22_1_H = 10.726
MAG_TYCHO_2_7740_22_1_K = 10.611

MAG_TYCHO_2_7740_22_1_g = 13.1053 #11.7892
MAG_TYCHO_2_7740_22_1_r = 12.702 #11.6444
MAG_TYCHO_2_7740_22_1_i = 12.656
MAG_TYCHO_2_7740_22_1_z = float('nan') #11.5203

MAG_TYCHO_2_7740_529_1_B = 11.61
MAG_TYCHO_2_7740_529_1_V = 10.94
MAG_TYCHO_2_7740_529_1_G = 10.867
MAG_TYCHO_2_7740_529_1_J = 9.902
MAG_TYCHO_2_7740_529_1_H = 9.625
MAG_TYCHO_2_7740_529_1_K = 9.580

MAG_UCAC3_86_422902_g = 14.731
MAG_UCAC3_86_422902_r = 13.270
MAG_UCAC3_86_422902_i = 12.955
MAG_UCAC3_86_422902_z = 13.230

MAG_VEGA_B = 0.03
MAG_VEGA_V = 0.03
MAG_VEGA_G = 0.03
MAG_VEGA_J = -0.18
MAG_VEGA_H = -0.03
MAG_VEGA_K = 0.13

MAG_VEGA_g = -0.08
MAG_VEGA_r = 0.16
MAG_VEGA_i = 0.37
MAG_VEGA_z = 0.54

FLUX_LAMBDA_VEGA_B = 632*10**(-11) #erg/cm**2/s/A
FLUX_LAMBDA_VEGA_V = 363.1*10**(-11)
FLUX_LAMBDA_VEGA_G = float('nan')
FLUX_LAMBDA_VEGA_J = 31.47*10**(-11)
FLUX_LAMBDA_VEGA_H = 11.38*10**(-11)
FLUX_LAMBDA_VEGA_K = 3.961*10**(-11)

FLUX_LAMBDA_VEGA_g = 466.9*10**(-11) #erg/cm**2/s/A
FLUX_LAMBDA_VEGA_r = 278.0*10**(-11)
FLUX_LAMBDA_VEGA_i = 185.2*10**(-11)
FLUX_LAMBDA_VEGA_z = 131.5*10**(-11)


FLUX_V_VEGA_B = 4.063*10**(-20) #erg/cm**2/s/Hz
FLUX_V_VEGA_V = 3.636*10**(-20)
FLUX_V_VEGA_G = float('nan')
FLUX_V_VEGA_J = 1.589*10**(-20)
FLUX_V_VEGA_H = 1.021*10**(-20)
FLUX_V_VEGA_K = 0.64*10**(-20)

FLUX_V_VEGA_g = 3.631*10**(-20) #erg/cm**2/s/Hz
FLUX_V_VEGA_r = 3.631*10**(-20)
FLUX_V_VEGA_i = 3.631*10**(-20)
FLUX_V_VEGA_z = 3.631*10**(-20)

# %%
g_NGC3783 = np.loadtxt('NGC3783/NGC3783-g')
r_NGC3783 = np.loadtxt('NGC3783/NGC3783-r')
i_NGC3783 = np.loadtxt('NGC3783/NGC3783-i')
z_NGC3783 = np.loadtxt('NGC3783/NGC3783-z')
J_NGC3783 = np.loadtxt('NGC3783/J-NGC3783')
H_NGC3783 = np.loadtxt('NGC3783/H-NGC3783')
K_NGC3783 = np.loadtxt('NGC3783/K-NGC3783')

# %%
g_NGC7213 = np.loadtxt('NGC7213/NGC7213-g')
r_NGC7213 = np.loadtxt('NGC7213/NGC7213-r')
i_NGC7213 = np.loadtxt('NGC7213/NGC7213-i')
z_NGC7213 = np.loadtxt('NGC7213/NGC7213-z')
J_NGC7213 = np.loadtxt('NGC7213/J-NGC7213')
H_NGC7213 = np.loadtxt('NGC7213/H-NGC7213')
K_NGC7213 = np.loadtxt('NGC7213/K-NGC7213')

# %%
def flux_cal(A_mag,B_mag,B_flux):
    '''Flux of A found through magnitude and flux of B'''
    return B_flux*10**((B_mag-A_mag)/2.5)

# %%
g_NGC3783[:,2] *= flux_cal(MAG_TYCHO_2_7740_22_1_g,MAG_VEGA_g,FLUX_LAMBDA_VEGA_K)
r_NGC3783[:,2] *= flux_cal(MAG_TYCHO_2_7740_22_1_r,MAG_VEGA_r,FLUX_LAMBDA_VEGA_r)
i_NGC3783[:,2] *= flux_cal(MAG_TYCHO_2_7740_22_1_i,MAG_VEGA_i,FLUX_LAMBDA_VEGA_i)
z_NGC3783[:,2] *= flux_cal(MAG_TYCHO_2_7740_22_1_z,MAG_VEGA_z,FLUX_LAMBDA_VEGA_z)

# %%
g_NGC7213[:,1] *= flux_cal(MAG_UCAC3_86_422902_g,MAG_VEGA_g,FLUX_LAMBDA_VEGA_K)
r_NGC7213[:,1] *= flux_cal(MAG_UCAC3_86_422902_r,MAG_VEGA_r,FLUX_LAMBDA_VEGA_r)
i_NGC7213[:,1] *= flux_cal(MAG_UCAC3_86_422902_i,MAG_VEGA_i,FLUX_LAMBDA_VEGA_i)
z_NGC7213[:,1] *= flux_cal(MAG_UCAC3_86_422902_z,MAG_VEGA_z,FLUX_LAMBDA_VEGA_z)

# %%
#print g_NGC3783
comp_array_g = np.zeros((len(g_NGC3783[:,0]),3))
#comp_array_g[0,0] = g_NGC3783[0,0]
tjek = 0
acceptance = 0.01

for i in range(len(g_NGC3783)):
    if g_NGC3783[i,0] != comp_array_g[tjek,0]:
        comp_array_g[tjek,0] = g_NGC3783[i,0]
        com1 = []
        for j in range(len(g_NGC3783)):
            if comp_array_g[tjek,0] == g_NGC3783[j,0]:
                com1.append(g_NGC3783[j,2])
        comp_array_g[tjek,1] = np.mean(com1)
        comp_array_g[tjek,2] = np.std(com1)
        if comp_array_g[tjek,2]/float(comp_array_g[tjek,1]) > acceptance or float(comp_array_g[tjek,1]) < 0:
            comp_array_g[tjek,1] = float('nan')
            comp_array_g[tjek,2] = float('nan')
        tjek = tjek + 1

# %%
#print r_NGC3783
comp_array_r = np.zeros((len(r_NGC3783[:,0]),3))
#comp_array_r[0,0] = r_NGC3783[0,0]
tjek = 0
acceptance = 0.01

for i in range(len(r_NGC3783)):
    if r_NGC3783[i,0] != comp_array_r[tjek,0]:
        comp_array_r[tjek,0] = r_NGC3783[i,0]
        com1 = []
        for j in range(len(r_NGC3783)):
            if comp_array_r[tjek,0] == r_NGC3783[j,0]:
                com1.append(r_NGC3783[j,2])
        comp_array_r[tjek,1] = np.mean(com1)
        comp_array_r[tjek,2] = np.std(com1)
        if comp_array_r[tjek,2]/float(comp_array_r[tjek,1]) > acceptance or float(comp_array_r[tjek,1]) < 0:
            comp_array_r[tjek,1] = float('nan')
            comp_array_r[tjek,2] = float('nan')
        tjek = tjek + 1

# %%
#print i_NGC3783
comp_array_i = np.zeros((len(i_NGC3783[:,0]),3))
#comp_array_i[0,0] = i_NGC3783[0,0]
tjek = 0
acceptance = 0.01

for i in range(len(i_NGC3783)):
    if i_NGC3783[i,0] != comp_array_i[tjek,0]:
        comp_array_i[tjek,0] = i_NGC3783[i,0]
        com1 = []
        for j in range(len(i_NGC3783)):
            if comp_array_i[tjek,0] == i_NGC3783[j,0]:
                com1.append(i_NGC3783[j,2])
        comp_array_i[tjek,1] = np.mean(com1)
        comp_array_i[tjek,2] = np.std(com1)
        if comp_array_i[tjek,2]/float(comp_array_i[tjek,1]) > acceptance or float(comp_array_i[tjek,1]) < 0:
            comp_array_i[tjek,1] = float('nan')
            comp_array_i[tjek,2] = float('nan')
        tjek = tjek + 1

# %%
#print z_NGC3783
comp_array_z = np.zeros((len(z_NGC3783[:,0]),3))
#comp_array_z[0,0] = z_NGC3783[0,0]
tjek = 0
acceptance = 0.01

for i in range(len(z_NGC3783)):
    if z_NGC3783[i,0] != comp_array_z[tjek,0]:
        comp_array_z[tjek,0] = z_NGC3783[i,0]
        com1 = []
        for j in range(len(z_NGC3783)):
            if comp_array_z[tjek,0] == z_NGC3783[j,0]:
                com1.append(z_NGC3783[j,2])
        comp_array_z[tjek,1] = np.mean(com1)
        comp_array_z[tjek,2] = np.std(com1)
        if comp_array_z[tjek,2]/float(comp_array_z[tjek,1]) > acceptance or float(comp_array_z[tjek,1]) < 0:
            comp_array_z[tjek,1] = float('nan')
            comp_array_z[tjek,2] = float('nan')
        tjek = tjek + 1

# %%
#print g_NGC7213
comp_array_7213_g = np.zeros((len(g_NGC7213[:,0]),3))
#comp_array_7213_g[0,0] = g_NGC7213[0,0]
tjek = 0
acceptance = 0.01

for i in range(len(g_NGC7213)):
    if g_NGC7213[i,0] != comp_array_7213_g[tjek,0]:
        comp_array_7213_g[tjek,0] = g_NGC7213[i,0]
        com1 = []
        for j in range(len(g_NGC7213)):
            if comp_array_7213_g[tjek,0] == g_NGC7213[j,0]:
                com1.append(g_NGC7213[j,1])
        comp_array_7213_g[tjek,1] = np.mean(com1)
        comp_array_7213_g[tjek,2] = np.std(com1)
        if comp_array_7213_g[tjek,2]/float(comp_array_7213_g[tjek,1]) > acceptance or float(comp_array_7213_g[tjek,1]) < 0:
            comp_array_7213_g[tjek,1] = float('nan')
            comp_array_7213_g[tjek,2] = float('nan')
        tjek = tjek + 1

# %%
#print r_NGC7213
comp_array_7213_r = np.zeros((len(r_NGC7213[:,0]),3))
#comp_array_7213_r[0,0] = r_NGC7213[0,0]
tjek = 0
acceptance = 0.01

for i in range(len(r_NGC7213)):
    if r_NGC7213[i,0] != comp_array_7213_r[tjek,0]:
        comp_array_7213_r[tjek,0] = r_NGC7213[i,0]
        com1 = []
        for j in range(len(r_NGC7213)):
            if comp_array_7213_r[tjek,0] == r_NGC7213[j,0]:
                com1.append(r_NGC7213[j,1])
        comp_array_7213_r[tjek,1] = np.mean(com1)
        comp_array_7213_r[tjek,2] = np.std(com1)
        if comp_array_7213_r[tjek,2]/float(comp_array_7213_r[tjek,1]) > acceptance or float(comp_array_7213_r[tjek,1]) < 0:
            comp_array_7213_r[tjek,1] = float('nan')
            comp_array_7213_r[tjek,2] = float('nan')
        tjek = tjek + 1

# %%
#print i_NGC7213
comp_array_7213_i = np.zeros((len(i_NGC7213[:,0]),3))
#comp_array_7213_i[0,0] = i_NGC7213[0,0]
tjek = 0
acceptance = 0.01

for i in range(len(i_NGC7213)):
    if i_NGC7213[i,0] != comp_array_7213_i[tjek,0]:
        comp_array_7213_i[tjek,0] = i_NGC7213[i,0]
        com1 = []
        for j in range(len(i_NGC7213)):
            if comp_array_7213_i[tjek,0] == i_NGC7213[j,0]:
                com1.append(i_NGC7213[j,1])
        comp_array_7213_i[tjek,1] = np.mean(com1)
        comp_array_7213_i[tjek,2] = np.std(com1)
        if comp_array_7213_i[tjek,2]/float(comp_array_7213_i[tjek,1]) > acceptance or float(comp_array_7213_i[tjek,1]) < 0:
            comp_array_7213_i[tjek,1] = float('nan')
            comp_array_7213_i[tjek,2] = float('nan')
        tjek = tjek + 1

# %%
#print z_NGC7213
comp_array_7213_z = np.zeros((len(z_NGC7213[:,0]),3))
#comp_array_7213_z[0,0] = z_NGC7213[0,0]
tjek = 0
acceptance = 0.01

for i in range(len(z_NGC7213)):
    if z_NGC7213[i,0] != comp_array_7213_z[tjek,0]:
        comp_array_7213_z[tjek,0] = z_NGC7213[i,0]
        com1 = []
        for j in range(len(z_NGC7213)):
            if comp_array_7213_z[tjek,0] == z_NGC7213[j,0]:
                com1.append(z_NGC7213[j,1])
        comp_array_7213_z[tjek,1] = np.mean(com1)
        comp_array_7213_z[tjek,2] = np.std(com1)
        if comp_array_7213_z[tjek,2]/float(comp_array_7213_z[tjek,1]) > acceptance or float(comp_array_7213_z[tjek,1]) < 0:
            comp_array_7213_z[tjek,1] = float('nan')
            comp_array_7213_z[tjek,2] = float('nan')
        tjek = tjek + 1

# %%
plt.figure(figsize=(15,15))
plt.scatter(J_NGC3783[0,:],J_NGC3783[1,:],label='J band NGC3783')
plt.scatter(H_NGC3783[0,:],H_NGC3783[1,:],label='H band NGC3783')
plt.scatter(K_NGC3783[0,:],K_NGC3783[1,:],label='K band NGC3783')
plt.scatter(J_NGC7213[0,:],J_NGC7213[1,:],label='J band NGC7213')
plt.scatter(H_NGC7213[0,:],H_NGC7213[1,:],label='H band NGC7213')
plt.scatter(K_NGC7213[0,:],K_NGC7213[1,:],label='K band NGC7213')
plt.errorbar(comp_array_g[:,0],comp_array_g[:,1],yerr=comp_array_g[:,2],fmt='x',label='g band NGC3783')
plt.errorbar(comp_array_r[:,0],comp_array_r[:,1],yerr=comp_array_r[:,2],fmt='x',label='r band NGC3783')
plt.errorbar(comp_array_i[:,0],comp_array_i[:,1],yerr=comp_array_i[:,2],fmt='x',label='i band NGC3783')
plt.errorbar(comp_array_z[:,0],comp_array_z[:,1],yerr=comp_array_z[:,2],fmt='x',label='z band NGC3783')
plt.errorbar(comp_array_7213_g[:,0],comp_array_7213_g[:,1],yerr=comp_array_7213_g[:,2],fmt='x',label='g band NGC7213')
plt.errorbar(comp_array_7213_r[:,0],comp_array_7213_r[:,1],yerr=comp_array_7213_r[:,2],fmt='x',label='r band NGC7213')
plt.errorbar(comp_array_7213_i[:,0],comp_array_7213_i[:,1],yerr=comp_array_7213_i[:,2],fmt='x',label='i band NGC7213')
plt.errorbar(comp_array_7213_z[:,0],comp_array_7213_z[:,1],yerr=comp_array_7213_z[:,2],fmt='x',label='z band NGC7213')
plt.legend()
plt.yscale('log')
plt.ylim([1*10**(-18),9*10**(-12)])
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.scatter(J_NGC3783[0,:],J_NGC3783[1,:],label='J band NGC3783')
plt.scatter(H_NGC3783[0,:],H_NGC3783[1,:],label='H band NGC3783')
plt.scatter(K_NGC3783[0,:],K_NGC3783[1,:],label='K band NGC3783')
plt.errorbar(comp_array_g[:,0],comp_array_g[:,1],yerr=comp_array_g[:,2],fmt='x',label='g band NGC3783')
plt.errorbar(comp_array_r[:,0],comp_array_r[:,1],yerr=comp_array_r[:,2],fmt='x',label='r band NGC3783')
plt.errorbar(comp_array_i[:,0],comp_array_i[:,1],yerr=comp_array_i[:,2],fmt='x',label='i band NGC3783')
plt.errorbar(comp_array_z[:,0],comp_array_z[:,1],yerr=comp_array_z[:,2],fmt='x',label='z band NGC3783')
plt.legend()
plt.yscale('log')
plt.ylim([5*10**(-15),2*10**(-14)])
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.scatter(J_NGC7213[0,:],J_NGC7213[1,:],label='J band NGC7213')
plt.scatter(H_NGC7213[0,:],H_NGC7213[1,:],label='H band NGC7213')
plt.scatter(K_NGC7213[0,:],K_NGC7213[1,:],label='K band NGC7213')
plt.errorbar(comp_array_7213_g[:,0],comp_array_7213_g[:,1],yerr=comp_array_7213_g[:,2],fmt='x',label='g band NGC7213')
plt.errorbar(comp_array_7213_r[:,0],comp_array_7213_r[:,1],yerr=comp_array_7213_r[:,2],fmt='x',label='r band NGC7213')
plt.errorbar(comp_array_7213_i[:,0],comp_array_7213_i[:,1],yerr=comp_array_7213_i[:,2],fmt='x',label='i band NGC7213')
plt.errorbar(comp_array_7213_z[:,0],comp_array_7213_z[:,1],yerr=comp_array_7213_z[:,2],fmt='x',label='z band NGC7213')
plt.legend()
plt.yscale('log')
plt.ylim([7*10**(-15),9.9*10**(-14)])
plt.show()

# %%
plt.figure(figsize=(15,15))

plt.errorbar(comp_array_g[:,0],comp_array_g[:,1],yerr=comp_array_g[:,2],fmt='o',label='g band NGC3783')
plt.errorbar(comp_array_r[:,0],comp_array_r[:,1],yerr=comp_array_r[:,2],fmt='o',label='r band NGC3783')
plt.errorbar(comp_array_i[:,0],comp_array_i[:,1],yerr=comp_array_i[:,2],fmt='o',label='i band NGC3783')
plt.errorbar(comp_array_z[:,0],comp_array_z[:,1],yerr=comp_array_z[:,2],fmt='o',label='z band NGC3783')
plt.legend()
#plt.yscale('log')
plt.ylim([2*10**(-14),4.5*10**(-14)])
plt.show()

# %%
g_SNR_NGC3783 = np.loadtxt('NOVEMBER/NGC3783_SNR_g.txt')
r_SNR_NGC3783 = np.loadtxt('NOVEMBER/NGC3783_SNR_r.txt')
i_SNR_NGC3783 = np.loadtxt('NOVEMBER/NGC3783_SNR_i.txt')
z_SNR_NGC3783 = np.loadtxt('NOVEMBER/NGC3783_SNR_z.txt')
J_SNR_NGC3783 = np.loadtxt('NOVEMBER/NGC3783_SNR_J.txt')
H_SNR_NGC3783 = np.loadtxt('NOVEMBER/NGC3783_SNR_H.txt')
K_SNR_NGC3783 = np.loadtxt('NOVEMBER/NGC3783_SNR_K.txt')

# %%
plt.figure(figsize=(10,7))
plt.scatter(g_SNR_NGC3783[:,0],g_SNR_NGC3783[:,1],label='SNR')
plt.legend()
plt.title('g-SNR')
plt.show()

plt.figure(figsize=(10,7))
plt.scatter(g_SNR_NGC3783[:,0],g_SNR_NGC3783[:,2],label='Signal')
plt.scatter(g_SNR_NGC3783[:,0],g_SNR_NGC3783[:,3],label='Sky')
plt.scatter(g_SNR_NGC3783[:,0],g_SNR_NGC3783[:,4],label='RON')
plt.legend()
plt.title('g-SNR')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(r_SNR_NGC3783[:,0],r_SNR_NGC3783[:,1],label='SNR')
plt.legend()
plt.title('r-SNR')
plt.show()

plt.figure(figsize=(10,7))
plt.scatter(r_SNR_NGC3783[:,0],r_SNR_NGC3783[:,2],label='Signal')
plt.scatter(r_SNR_NGC3783[:,0],r_SNR_NGC3783[:,3],label='Sky')
plt.scatter(r_SNR_NGC3783[:,0],r_SNR_NGC3783[:,4],label='RON')
plt.legend()
plt.title('r-SNR')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(i_SNR_NGC3783[:,0],i_SNR_NGC3783[:,1],label='SNR')
plt.legend()
plt.title('i-SNR')
plt.show()

plt.figure(figsize=(10,7))
plt.scatter(i_SNR_NGC3783[:,0],i_SNR_NGC3783[:,2],label='Signal')
plt.scatter(i_SNR_NGC3783[:,0],i_SNR_NGC3783[:,3],label='Sky')
plt.scatter(i_SNR_NGC3783[:,0],i_SNR_NGC3783[:,4],label='RON')
plt.legend()
plt.title('i-SNR')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(z_SNR_NGC3783[:,0],z_SNR_NGC3783[:,1],label='SNR')
plt.legend()
plt.title('z-SNR')
plt.show()

plt.figure(figsize=(10,7))
plt.scatter(z_SNR_NGC3783[:,0],z_SNR_NGC3783[:,2],label='Signal')
plt.scatter(z_SNR_NGC3783[:,0],z_SNR_NGC3783[:,3],label='Sky')
plt.scatter(z_SNR_NGC3783[:,0],z_SNR_NGC3783[:,4],label='RON')
plt.legend()
plt.title('z-SNR')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(J_SNR_NGC3783[:,0],J_SNR_NGC3783[:,1],label='SNR')
plt.legend()
plt.title('J-SNR')
plt.show()

plt.figure(figsize=(10,7))
plt.scatter(J_SNR_NGC3783[:,0],J_SNR_NGC3783[:,2],label='Signal')
plt.scatter(J_SNR_NGC3783[:,0],J_SNR_NGC3783[:,3],label='Sky')
plt.scatter(J_SNR_NGC3783[:,0],J_SNR_NGC3783[:,4],label='RON')
plt.legend()
plt.title('J-SNR')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(H_SNR_NGC3783[:,0],H_SNR_NGC3783[:,1],label='SNR')
plt.legend()
plt.title('H-SNR')
plt.show()

plt.figure(figsize=(10,7))
plt.scatter(H_SNR_NGC3783[:,0],H_SNR_NGC3783[:,2],label='Signal')
plt.scatter(H_SNR_NGC3783[:,0],H_SNR_NGC3783[:,3],label='Sky')
plt.scatter(H_SNR_NGC3783[:,0],H_SNR_NGC3783[:,4],label='RON')
plt.legend()
plt.title('H-SNR')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(K_SNR_NGC3783[:,0],K_SNR_NGC3783[:,1],label='SNR')
plt.legend()
plt.title('K-SNR')
plt.show()

plt.figure(figsize=(10,7))
plt.scatter(K_SNR_NGC3783[:,0],K_SNR_NGC3783[:,2],label='Signal')
plt.scatter(K_SNR_NGC3783[:,0],K_SNR_NGC3783[:,3],label='Sky')
plt.scatter(K_SNR_NGC3783[:,0],K_SNR_NGC3783[:,4],label='RON')
plt.legend()
plt.title('K-SNR')
plt.show()
