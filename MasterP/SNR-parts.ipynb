# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
ESO323_K_SNR = np.loadtxt('NOVEMBER/ESO323_SNR_K.txt')
ESO323_H_SNR = np.loadtxt('NOVEMBER/ESO323_SNR_H.txt')
ESO323_J_SNR = np.loadtxt('NOVEMBER/ESO323_SNR_J.txt')

ESO323_K = np.loadtxt('NOVEMBER/NOV-ESO323-K')
ESO323_H = np.loadtxt('NOVEMBER/NOV-ESO323-H')
ESO323_J = np.loadtxt('NOVEMBER/NOV-ESO323-J')

#print ESO323_K_SNR[:,0]
#print ESO323_K

# %%
ESO323_g_SNR = np.loadtxt('NOVEMBER/ESO323_SNR_g.txt')
ESO323_r_SNR = np.loadtxt('NOVEMBER/ESO323_SNR_r.txt')
ESO323_i_SNR = np.loadtxt('NOVEMBER/ESO323_SNR_i.txt')
ESO323_z_SNR = np.loadtxt('NOVEMBER/ESO323_SNR_z.txt')

ESO323_g = np.loadtxt('NOVEMBER/NOV-ESO323-g')
ESO323_r = np.loadtxt('NOVEMBER/NOV-ESO323-r')
ESO323_i = np.loadtxt('NOVEMBER/NOV-ESO323-i')
ESO323_z = np.loadtxt('NOVEMBER/NOV-ESO323-z')

# %%
ESO323_err_K = np.array((ESO323_K_SNR[:,0],ESO323_K[:,1]/ESO323_K_SNR[:,1],\
                        ESO323_K[:,2]/ESO323_K_SNR[:,1],ESO323_K[:,3]/ESO323_K_SNR[:,1]))
ESO323_err_H = np.array((ESO323_H_SNR[:,0],ESO323_H[:,1]/ESO323_H_SNR[:,1],\
                        ESO323_H[:,2]/ESO323_H_SNR[:,1],ESO323_H[:,3]/ESO323_H_SNR[:,1]))
ESO323_err_J = np.array((ESO323_J_SNR[:,0],ESO323_J[:,1]/ESO323_J_SNR[:,1],\
                        ESO323_J[:,2]/ESO323_J_SNR[:,1],ESO323_J[:,3]/ESO323_J_SNR[:,1]))
ESO323_err_g = np.array((ESO323_g_SNR[:,0],ESO323_g[:,1]/ESO323_g_SNR[:,1],\
                        ESO323_g[:,2]/ESO323_g_SNR[:,1],ESO323_g[:,3]/ESO323_g_SNR[:,1]))
ESO323_err_r = np.array((ESO323_r_SNR[:,0],ESO323_r[:,1]/ESO323_r_SNR[:,1],\
                        ESO323_r[:,2]/ESO323_r_SNR[:,1],ESO323_r[:,3]/ESO323_r_SNR[:,1]))
ESO323_err_i = np.array((ESO323_i_SNR[:,0],ESO323_i[:,1]/ESO323_i_SNR[:,1],\
                        ESO323_i[:,2]/ESO323_i_SNR[:,1],ESO323_i[:,3]/ESO323_i_SNR[:,1]))
ESO323_err_z = np.array((ESO323_z_SNR[:,0],ESO323_z[:,1]/ESO323_z_SNR[:,1],\
                        ESO323_z[:,2]/ESO323_z_SNR[:,1],ESO323_z[:,3]/ESO323_z_SNR[:,1]))

# %%
F9_K_SNR = np.loadtxt('NOVEMBER/F9_SNR_K.txt')
F9_H_SNR = np.loadtxt('NOVEMBER/F9_SNR_H.txt')
F9_J_SNR = np.loadtxt('NOVEMBER/F9_SNR_J.txt')

F9_K = np.loadtxt('NOVEMBER/NOV-F9-K')
F9_H = np.loadtxt('NOVEMBER/NOV-F9-H')
F9_J = np.loadtxt('NOVEMBER/NOV-F9-J')

# %%
F9_g_SNR = np.loadtxt('NOVEMBER/F9_SNR_g.txt')
F9_r_SNR = np.loadtxt('NOVEMBER/F9_SNR_r.txt')
F9_i_SNR = np.loadtxt('NOVEMBER/F9_SNR_i.txt')
F9_z_SNR = np.loadtxt('NOVEMBER/F9_SNR_z.txt')

F9_g = np.loadtxt('NOVEMBER/NOV-F9-g')
F9_r = np.loadtxt('NOVEMBER/NOV-F9-r')
F9_i = np.loadtxt('NOVEMBER/NOV-F9-i')
F9_z = np.loadtxt('NOVEMBER/NOV-F9-z')

# %%
F9_err_K = np.array((F9_K_SNR[:,0],F9_K[:,1]/F9_K_SNR[:,1],\
                        F9_K[:,2]/F9_K_SNR[:,1],F9_K[:,3]/F9_K_SNR[:,1]))
F9_err_H = np.array((F9_H_SNR[:,0],F9_H[:,1]/F9_H_SNR[:,1],\
                        F9_H[:,2]/F9_H_SNR[:,1],F9_H[:,3]/F9_H_SNR[:,1]))
F9_err_J = np.array((F9_J_SNR[:,0],F9_J[:,1]/F9_J_SNR[:,1],\
                        F9_J[:,2]/F9_J_SNR[:,1],F9_J[:,3]/F9_J_SNR[:,1]))
F9_err_g = np.array((F9_g_SNR[:,0],F9_g[:,1]/F9_g_SNR[:,1],\
                        F9_g[:,2]/F9_g_SNR[:,1],F9_g[:,3]/F9_g_SNR[:,1]))
F9_err_r = np.array((F9_r_SNR[:,0],F9_r[:,1]/F9_r_SNR[:,1],\
                        F9_r[:,2]/F9_r_SNR[:,1],F9_r[:,3]/F9_r_SNR[:,1]))
F9_err_i = np.array((F9_i_SNR[:,0],F9_i[:,1]/F9_i_SNR[:,1],\
                        F9_i[:,2]/F9_i_SNR[:,1],F9_i[:,3]/F9_i_SNR[:,1]))
F9_err_z = np.array((F9_z_SNR[:,0],F9_z[:,1]/F9_z_SNR[:,1],\
                        F9_z[:,2]/F9_z_SNR[:,1],F9_z[:,3]/F9_z_SNR[:,1]))

# %%
H0557_K_SNR = np.loadtxt('NOVEMBER/H0557_SNR_K.txt')
H0557_H_SNR = np.loadtxt('NOVEMBER/H0557_SNR_H.txt')
H0557_J_SNR = np.loadtxt('NOVEMBER/H0557_SNR_J.txt')

H0557_K = np.loadtxt('NOVEMBER/NOV-H0557-K')
H0557_H = np.loadtxt('NOVEMBER/NOV-H0557-H')
H0557_J = np.loadtxt('NOVEMBER/NOV-H0557-J')

# %%
H0557_g_SNR = np.loadtxt('NOVEMBER/H0557_SNR_g.txt')
H0557_r_SNR = np.loadtxt('NOVEMBER/H0557_SNR_r.txt')
H0557_i_SNR = np.loadtxt('NOVEMBER/H0557_SNR_i.txt')
H0557_z_SNR = np.loadtxt('NOVEMBER/H0557_SNR_z.txt')

H0557_g = np.loadtxt('NOVEMBER/NOV-H0557-g')
H0557_r = np.loadtxt('NOVEMBER/NOV-H0557-r')
H0557_i = np.loadtxt('NOVEMBER/NOV-H0557-i')
H0557_z = np.loadtxt('NOVEMBER/NOV-H0557-z')

# %%
H0557_err_K = np.array((H0557_K_SNR[:,0],H0557_K[:,1]/H0557_K_SNR[:,1],\
                        H0557_K[:,2]/H0557_K_SNR[:,1],H0557_K[:,3]/H0557_K_SNR[:,1]))
H0557_err_H = np.array((H0557_H_SNR[:,0],H0557_H[:,1]/H0557_H_SNR[:,1],\
                        H0557_H[:,2]/H0557_H_SNR[:,1],H0557_H[:,3]/H0557_H_SNR[:,1]))
H0557_err_J = np.array((H0557_J_SNR[:,0],H0557_J[:,1]/H0557_J_SNR[:,1],\
                        H0557_J[:,2]/H0557_J_SNR[:,1],H0557_J[:,3]/H0557_J_SNR[:,1]))
H0557_err_g = np.array((H0557_g_SNR[:,0],H0557_g[:,1]/H0557_g_SNR[:,1],\
                        H0557_g[:,2]/H0557_g_SNR[:,1],H0557_g[:,3]/H0557_g_SNR[:,1]))
H0557_err_r = np.array((H0557_r_SNR[:,0],H0557_r[:,1]/H0557_r_SNR[:,1],\
                        H0557_r[:,2]/H0557_r_SNR[:,1],H0557_r[:,3]/H0557_r_SNR[:,1]))
H0557_err_i = np.array((H0557_i_SNR[:,0],H0557_i[:,1]/H0557_i_SNR[:,1],\
                        H0557_i[:,2]/H0557_i_SNR[:,1],H0557_i[:,3]/H0557_i_SNR[:,1]))
H0557_err_z = np.array((H0557_z_SNR[:,0],H0557_z[:,1]/H0557_z_SNR[:,1],\
                        H0557_z[:,2]/H0557_z_SNR[:,1],H0557_z[:,3]/H0557_z_SNR[:,1]))

# %%
F51_K_SNR = np.loadtxt('NOVEMBER/F51_SNR_K.txt')
F51_H_SNR = np.loadtxt('NOVEMBER/F51_SNR_H.txt')
F51_J_SNR = np.loadtxt('NOVEMBER/F51_SNR_J.txt')

F51_K = np.loadtxt('NOVEMBER/NOV-F51-K')
F51_H = np.loadtxt('NOVEMBER/NOV-F51-H')
F51_J = np.loadtxt('NOVEMBER/NOV-F51-J')

# %%
F51_g_SNR = np.loadtxt('NOVEMBER/F51_SNR_g.txt')
F51_r_SNR = np.loadtxt('NOVEMBER/F51_SNR_r.txt')
F51_i_SNR = np.loadtxt('NOVEMBER/F51_SNR_i.txt')
F51_z_SNR = np.loadtxt('NOVEMBER/F51_SNR_z.txt')

F51_g = np.loadtxt('NOVEMBER/NOV-F51-g')
F51_r = np.loadtxt('NOVEMBER/NOV-F51-r')
F51_i = np.loadtxt('NOVEMBER/NOV-F51-i')
F51_z = np.loadtxt('NOVEMBER/NOV-F51-z')

# %%
F51_err_K = np.array((F51_K_SNR[:,0],F51_K[:,1]/F51_K_SNR[:,1],\
                        F51_K[:,2]/F51_K_SNR[:,1],F51_K[:,3]/F51_K_SNR[:,1]))
F51_err_H = np.array((F51_H_SNR[:,0],F51_H[:,1]/F51_H_SNR[:,1],\
                        F51_H[:,2]/F51_H_SNR[:,1],F51_H[:,3]/F51_H_SNR[:,1]))
F51_err_J = np.array((F51_J_SNR[:,0],F51_J[:,1]/F51_J_SNR[:,1],\
                        F51_J[:,2]/F51_J_SNR[:,1],F51_J[:,3]/F51_J_SNR[:,1]))
F51_err_g = np.array((F51_g_SNR[:,0],F51_g[:,1]/F51_g_SNR[:,1],\
                        F51_g[:,2]/F51_g_SNR[:,1],F51_g[:,3]/F51_g_SNR[:,1]))
F51_err_r = np.array((F51_r_SNR[:,0],F51_r[:,1]/F51_r_SNR[:,1],\
                        F51_r[:,2]/F51_r_SNR[:,1],F51_r[:,3]/F51_r_SNR[:,1]))
F51_err_i = np.array((F51_i_SNR[:,0],F51_i[:,1]/F51_i_SNR[:,1],\
                        F51_i[:,2]/F51_i_SNR[:,1],F51_i[:,3]/F51_i_SNR[:,1]))
F51_err_z = np.array((F51_z_SNR[:,0],F51_z[:,1]/F51_z_SNR[:,1],\
                        F51_z[:,2]/F51_z_SNR[:,1],F51_z[:,3]/F51_z_SNR[:,1]))

# %%
MARK509_K_SNR = np.loadtxt('NOVEMBER/MARK509_SNR_K.txt')
MARK509_H_SNR = np.loadtxt('NOVEMBER/MARK509_SNR_H.txt')
MARK509_J_SNR = np.loadtxt('NOVEMBER/MARK509_SNR_J.txt')

MARK509_K = np.loadtxt('NOVEMBER/NOV-MARK509-K')
MARK509_H = np.loadtxt('NOVEMBER/NOV-MARK509-H')
MARK509_J = np.loadtxt('NOVEMBER/NOV-MARK509-J')

# %%
MARK509_g_SNR = np.loadtxt('NOVEMBER/MARK509_SNR_g.txt')
MARK509_r_SNR = np.loadtxt('NOVEMBER/MARK509_SNR_r.txt')
MARK509_i_SNR = np.loadtxt('NOVEMBER/MARK509_SNR_i.txt')
MARK509_z_SNR = np.loadtxt('NOVEMBER/MARK509_SNR_z.txt')

MARK509_g = np.loadtxt('NOVEMBER/NOV-MARK509-g')
MARK509_r = np.loadtxt('NOVEMBER/NOV-MARK509-r')
MARK509_i = np.loadtxt('NOVEMBER/NOV-MARK509-i')
MARK509_z = np.loadtxt('NOVEMBER/NOV-MARK509-z')

# %%
MARK509_err_K = np.array((MARK509_K_SNR[:,0],MARK509_K[:,1]/MARK509_K_SNR[:,1],\
                        MARK509_K[:,2]/MARK509_K_SNR[:,1],MARK509_K[:,3]/MARK509_K_SNR[:,1]))
MARK509_err_H = np.array((MARK509_H_SNR[:,0],MARK509_H[:,1]/MARK509_H_SNR[:,1],\
                        MARK509_H[:,2]/MARK509_H_SNR[:,1],MARK509_H[:,3]/MARK509_H_SNR[:,1]))
MARK509_err_J = np.array((MARK509_J_SNR[:,0],MARK509_J[:,1]/MARK509_J_SNR[:,1],\
                        MARK509_J[:,2]/MARK509_J_SNR[:,1],MARK509_J[:,3]/MARK509_J_SNR[:,1]))
MARK509_err_g = np.array((MARK509_g_SNR[:,0],MARK509_g[:,1]/MARK509_g_SNR[:,1],\
                        MARK509_g[:,2]/MARK509_g_SNR[:,1],MARK509_g[:,3]/MARK509_g_SNR[:,1]))
MARK509_err_r = np.array((MARK509_r_SNR[:,0],MARK509_r[:,1]/MARK509_r_SNR[:,1],\
                        MARK509_r[:,2]/MARK509_r_SNR[:,1],MARK509_r[:,3]/MARK509_r_SNR[:,1]))
MARK509_err_i = np.array((MARK509_i_SNR[:,0],MARK509_i[:,1]/MARK509_i_SNR[:,1],\
                        MARK509_i[:,2]/MARK509_i_SNR[:,1],MARK509_i[:,3]/MARK509_i_SNR[:,1]))
MARK509_err_z = np.array((MARK509_z_SNR[:,0],MARK509_z[:,1]/MARK509_z_SNR[:,1],\
                        MARK509_z[:,2]/MARK509_z_SNR[:,1],MARK509_z[:,3]/MARK509_z_SNR[:,1]))

# %%
NGC3783_K_SNR = np.loadtxt('NOVEMBER/NGC3783_SNR_K.txt')
NGC3783_H_SNR = np.loadtxt('NOVEMBER/NGC3783_SNR_H.txt')
NGC3783_J_SNR = np.loadtxt('NOVEMBER/NGC3783_SNR_J.txt')

NGC3783_K = np.loadtxt('NOVEMBER/NOV-NGC3783-K')
NGC3783_H = np.loadtxt('NOVEMBER/NOV-NGC3783-H')
NGC3783_J = np.loadtxt('NOVEMBER/NOV-NGC3783-J')

# %%
NGC3783_g_SNR = np.loadtxt('NOVEMBER/NGC3783_SNR_g.txt')
NGC3783_r_SNR = np.loadtxt('NOVEMBER/NGC3783_SNR_r.txt')
NGC3783_i_SNR = np.loadtxt('NOVEMBER/NGC3783_SNR_i.txt')
NGC3783_z_SNR = np.loadtxt('NOVEMBER/NGC3783_SNR_z.txt')

NGC3783_g = np.loadtxt('NOVEMBER/NOV-NGC3783-g')
NGC3783_r = np.loadtxt('NOVEMBER/NOV-NGC3783-r')
NGC3783_i = np.loadtxt('NOVEMBER/NOV-NGC3783-i')
NGC3783_z = np.loadtxt('NOVEMBER/NOV-NGC3783-z')

# %%
NGC3783_err_K = np.array((NGC3783_K_SNR[:,0],NGC3783_K[:,1]/NGC3783_K_SNR[:,1],\
                        NGC3783_K[:,2]/NGC3783_K_SNR[:,1],NGC3783_K[:,3]/NGC3783_K_SNR[:,1]))
NGC3783_err_H = np.array((NGC3783_H_SNR[:,0],NGC3783_H[:,1]/NGC3783_H_SNR[:,1],\
                        NGC3783_H[:,2]/NGC3783_H_SNR[:,1],NGC3783_H[:,3]/NGC3783_H_SNR[:,1]))
NGC3783_err_J = np.array((NGC3783_J_SNR[:,0],NGC3783_J[:,1]/NGC3783_J_SNR[:,1],\
                        NGC3783_J[:,2]/NGC3783_J_SNR[:,1],NGC3783_J[:,3]/NGC3783_J_SNR[:,1]))
NGC3783_err_g = np.array((NGC3783_g_SNR[:,0],NGC3783_g[:,1]/NGC3783_g_SNR[:,1],\
                        NGC3783_g[:,2]/NGC3783_g_SNR[:,1],NGC3783_g[:,3]/NGC3783_g_SNR[:,1]))
NGC3783_err_r = np.array((NGC3783_r_SNR[:,0],NGC3783_r[:,1]/NGC3783_r_SNR[:,1],\
                        NGC3783_r[:,2]/NGC3783_r_SNR[:,1],NGC3783_r[:,3]/NGC3783_r_SNR[:,1]))
NGC3783_err_i = np.array((NGC3783_i_SNR[:,0],NGC3783_i[:,1]/NGC3783_i_SNR[:,1],\
                        NGC3783_i[:,2]/NGC3783_i_SNR[:,1],NGC3783_i[:,3]/NGC3783_i_SNR[:,1]))
NGC3783_err_z = np.array((NGC3783_z_SNR[:,0],NGC3783_z[:,1]/NGC3783_z_SNR[:,1],\
                        NGC3783_z[:,2]/NGC3783_z_SNR[:,1],NGC3783_z[:,3]/NGC3783_z_SNR[:,1]))

# %%
NGC7213_K_SNR = np.loadtxt('NOVEMBER/NGC7213_SNR_K.txt')
NGC7213_H_SNR = np.loadtxt('NOVEMBER/NGC7213_SNR_H.txt')
NGC7213_J_SNR = np.loadtxt('NOVEMBER/NGC7213_SNR_J.txt')

NGC7213_K = np.loadtxt('NOVEMBER/NOV-NGC7213-K')
NGC7213_H = np.loadtxt('NOVEMBER/NOV-NGC7213-H')
NGC7213_J = np.loadtxt('NOVEMBER/NOV-NGC7213-J')

# %%
NGC7213_g_SNR = np.loadtxt('NOVEMBER/NGC7213_SNR_g.txt')
NGC7213_r_SNR = np.loadtxt('NOVEMBER/NGC7213_SNR_r.txt')
NGC7213_i_SNR = np.loadtxt('NOVEMBER/NGC7213_SNR_i.txt')
NGC7213_z_SNR = np.loadtxt('NOVEMBER/NGC7213_SNR_z.txt')

NGC7213_g = np.loadtxt('NOVEMBER/NOV-NGC7213-g')
NGC7213_r = np.loadtxt('NOVEMBER/NOV-NGC7213-r')
NGC7213_i = np.loadtxt('NOVEMBER/NOV-NGC7213-i')
NGC7213_z = np.loadtxt('NOVEMBER/NOV-NGC7213-z')

# %%
NGC7213_err_K = np.array((NGC7213_K_SNR[:,0],NGC7213_K[:,1]/NGC7213_K_SNR[:,1],\
                        NGC7213_K[:,2]/NGC7213_K_SNR[:,1],NGC7213_K[:,3]/NGC7213_K_SNR[:,1]))
NGC7213_err_H = np.array((NGC7213_H_SNR[:,0],NGC7213_H[:,1]/NGC7213_H_SNR[:,1],\
                        NGC7213_H[:,2]/NGC7213_H_SNR[:,1],NGC7213_H[:,3]/NGC7213_H_SNR[:,1]))
NGC7213_err_J = np.array((NGC7213_J_SNR[:,0],NGC7213_J[:,1]/NGC7213_J_SNR[:,1],\
                        NGC7213_J[:,2]/NGC7213_J_SNR[:,1],NGC7213_J[:,3]/NGC7213_J_SNR[:,1]))
NGC7213_err_g = np.array((NGC7213_g_SNR[:,0],NGC7213_g[:,1]/NGC7213_g_SNR[:,1],\
                        NGC7213_g[:,2]/NGC7213_g_SNR[:,1],NGC7213_g[:,3]/NGC7213_g_SNR[:,1]))
NGC7213_err_r = np.array((NGC7213_r_SNR[:,0],NGC7213_r[:,1]/NGC7213_r_SNR[:,1],\
                        NGC7213_r[:,2]/NGC7213_r_SNR[:,1],NGC7213_r[:,3]/NGC7213_r_SNR[:,1]))
NGC7213_err_i = np.array((NGC7213_i_SNR[:,0],NGC7213_i[:,1]/NGC7213_i_SNR[:,1],\
                        NGC7213_i[:,2]/NGC7213_i_SNR[:,1],NGC7213_i[:,3]/NGC7213_i_SNR[:,1]))
NGC7213_err_z = np.array((NGC7213_z_SNR[:,0],NGC7213_z[:,1]/NGC7213_z_SNR[:,1],\
                        NGC7213_z[:,2]/NGC7213_z_SNR[:,1],NGC7213_z[:,3]/NGC7213_z_SNR[:,1]))

# %%
NGC6673_K_SNR = np.loadtxt('NOVEMBER/NGC6673_SNR_K.txt')
NGC6673_H_SNR = np.loadtxt('NOVEMBER/NGC6673_SNR_H.txt')
NGC6673_J_SNR = np.loadtxt('NOVEMBER/NGC6673_SNR_J.txt')

NGC6673_K = np.loadtxt('NOVEMBER/NOV-NGC6673-K')
NGC6673_H = np.loadtxt('NOVEMBER/NOV-NGC6673-H')
NGC6673_J = np.loadtxt('NOVEMBER/NOV-NGC6673-J')

# %%
H0557_2_g_SNR = np.loadtxt('NOVEMBER/H0557_2_SNR_g.txt')
H0557_2_r_SNR = np.loadtxt('NOVEMBER/H0557_2_SNR_r.txt')
H0557_2_i_SNR = np.loadtxt('NOVEMBER/H0557_2_SNR_i.txt')
H0557_2_z_SNR = np.loadtxt('NOVEMBER/H0557_2_SNR_z.txt')

H0557_2_g = np.loadtxt('NOVEMBER/NOV-H0557_2-g')
H0557_2_r = np.loadtxt('NOVEMBER/NOV-H0557_2-r')
H0557_2_i = np.loadtxt('NOVEMBER/NOV-H0557_2-i')
H0557_2_z = np.loadtxt('NOVEMBER/NOV-H0557_2-z')

# %%
NGC6673_err_K = np.array((NGC6673_K_SNR[:,0],NGC6673_K[:,1]/NGC6673_K_SNR[:,1],\
                        NGC6673_K[:,2]/NGC6673_K_SNR[:,1],NGC6673_K[:,3]/NGC6673_K_SNR[:,1]))
NGC6673_err_H = np.array((NGC6673_H_SNR[:,0],NGC6673_H[:,1]/NGC6673_H_SNR[:,1],\
                        NGC6673_H[:,2]/NGC6673_H_SNR[:,1],NGC6673_H[:,3]/NGC6673_H_SNR[:,1]))
NGC6673_err_J = np.array((NGC6673_J_SNR[:,0],NGC6673_J[:,1]/NGC6673_J_SNR[:,1],\
                        NGC6673_J[:,2]/NGC6673_J_SNR[:,1],NGC6673_J[:,3]/NGC6673_J_SNR[:,1]))

# %%
H0557_2_err_g = np.array((H0557_2_g_SNR[:,0],H0557_2_g[:,1]/H0557_2_g_SNR[:,1],\
                        H0557_2_g[:,2]/H0557_2_g_SNR[:,1],H0557_2_g[:,3]/H0557_2_g_SNR[:,1]))
H0557_2_err_r = np.array((H0557_2_r_SNR[:,0],H0557_2_r[:,1]/H0557_2_r_SNR[:,1],\
                        H0557_2_r[:,2]/H0557_2_r_SNR[:,1],H0557_2_r[:,3]/H0557_2_r_SNR[:,1]))
H0557_2_err_i = np.array((H0557_2_i_SNR[:,0],H0557_2_i[:,1]/H0557_2_i_SNR[:,1],\
                        H0557_2_i[:,2]/H0557_2_i_SNR[:,1],H0557_2_i[:,3]/H0557_2_i_SNR[:,1]))
H0557_2_err_z = np.array((H0557_2_z_SNR[:,0],H0557_2_z[:,1]/H0557_2_z_SNR[:,1],\
                        H0557_2_z[:,2]/H0557_2_z_SNR[:,1],H0557_2_z[:,3]/H0557_2_z_SNR[:,1]))

# %%
AKN120_K_SNR = np.loadtxt('NOVEMBER/AKN120_SNR_K.txt')
AKN120_H_SNR = np.loadtxt('NOVEMBER/AKN120_SNR_H.txt')
AKN120_J_SNR = np.loadtxt('NOVEMBER/AKN120_SNR_J.txt')

AKN120_K = np.loadtxt('NOVEMBER/NOV-AKN120-K')
AKN120_H = np.loadtxt('NOVEMBER/NOV-AKN120-H')
AKN120_J = np.loadtxt('NOVEMBER/NOV-AKN120-J')

# %%
AKN120_g_SNR = np.loadtxt('NOVEMBER/AKN120_SNR_g.txt')
AKN120_r_SNR = np.loadtxt('NOVEMBER/AKN120_SNR_r.txt')
AKN120_i_SNR = np.loadtxt('NOVEMBER/AKN120_SNR_i.txt')
AKN120_z_SNR = np.loadtxt('NOVEMBER/AKN120_SNR_z.txt')

AKN120_g = np.loadtxt('NOVEMBER/NOV-AKN120-g')
AKN120_r = np.loadtxt('NOVEMBER/NOV-AKN120-r')
AKN120_i = np.loadtxt('NOVEMBER/NOV-AKN120-i')
AKN120_z = np.loadtxt('NOVEMBER/NOV-AKN120-z')

# %%
AKN120_err_K = np.array((AKN120_K_SNR[:,0],AKN120_K[:,1]/AKN120_K_SNR[:,1],\
                        AKN120_K[:,2]/AKN120_K_SNR[:,1],AKN120_K[:,3]/AKN120_K_SNR[:,1]))
AKN120_err_H = np.array((AKN120_H_SNR[:,0],AKN120_H[:,1]/AKN120_H_SNR[:,1],\
                        AKN120_H[:,2]/AKN120_H_SNR[:,1],AKN120_H[:,3]/AKN120_H_SNR[:,1]))
AKN120_err_J = np.array((AKN120_J_SNR[:,0],AKN120_J[:,1]/AKN120_J_SNR[:,1],\
                        AKN120_J[:,2]/AKN120_J_SNR[:,1],AKN120_J[:,3]/AKN120_J_SNR[:,1]))
AKN120_err_g = np.array((AKN120_g_SNR[:,0],AKN120_g[:,1]/AKN120_g_SNR[:,1],\
                        AKN120_g[:,2]/AKN120_g_SNR[:,1],AKN120_g[:,3]/AKN120_g_SNR[:,1]))
AKN120_err_r = np.array((AKN120_r_SNR[:,0],AKN120_r[:,1]/AKN120_r_SNR[:,1],\
                        AKN120_r[:,2]/AKN120_r_SNR[:,1],AKN120_r[:,3]/AKN120_r_SNR[:,1]))
AKN120_err_i = np.array((AKN120_i_SNR[:,0],AKN120_i[:,1]/AKN120_i_SNR[:,1],\
                        AKN120_i[:,2]/AKN120_i_SNR[:,1],AKN120_i[:,3]/AKN120_i_SNR[:,1]))
AKN120_err_z = np.array((AKN120_z_SNR[:,0],AKN120_z[:,1]/AKN120_z_SNR[:,1],\
                        AKN120_z[:,2]/AKN120_z_SNR[:,1],AKN120_z[:,3]/AKN120_z_SNR[:,1]))

# %%
plt.figure(figsize=(15,10))
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,1],yerr=NGC7213_err_K[1,:],color='b',fmt='x',label='NGC7213 K STA1')
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,2],yerr=NGC7213_err_K[2,:],color='b',fmt='o',label='NGC7213 K STA2')
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,3],yerr=NGC7213_err_K[3,:],color='b',fmt='*',label='NGC7213 K STA3')

plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,1],yerr=NGC7213_err_H[1,:],color='r',fmt='x',label='NGC7213 H STA1')
plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,2],yerr=NGC7213_err_H[1,:],color='r',fmt='o',label='NGC7213 H STA2')
plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,3],yerr=NGC7213_err_H[1,:],color='r',fmt='*',label='NGC7213 H STA3')

plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,1],yerr=NGC7213_err_J[1,:],color='g',fmt='x',label='NGC7213 J STA1')
plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,2],yerr=NGC7213_err_J[1,:],color='g',fmt='o',label='NGC7213 J STA2')
plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,3],yerr=NGC7213_err_J[1,:],color='g',fmt='*',label='NGC7213 J STA3')

plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,1],yerr=NGC7213_err_g[1,:],color='purple',fmt='x',label='NGC7213 g STA1')
plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,2],yerr=NGC7213_err_g[1,:],color='purple',fmt='o',label='NGC7213 g STA2')
plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,3],yerr=NGC7213_err_g[1,:],color='purple',fmt='*',label='NGC7213 g STA3')

plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,1],yerr=NGC7213_err_r[1,:],color='black',fmt='x',label='NGC7213 r STA1')
plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,2],yerr=NGC7213_err_r[1,:],color='black',fmt='o',label='NGC7213 r STA2')
plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,3],yerr=NGC7213_err_r[1,:],color='black',fmt='*',label='NGC7213 r STA3')

plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,1],yerr=NGC7213_err_i[1,:],color='yellow',fmt='x',label='NGC7213 i STA1')
plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,2],yerr=NGC7213_err_i[1,:],color='yellow',fmt='o',label='NGC7213 i STA2')
plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,3],yerr=NGC7213_err_i[1,:],color='yellow',fmt='*',label='NGC7213 i STA3')

plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,1],yerr=NGC7213_err_z[1,:],color='orange',fmt='x',label='NGC7213 z STA1')
plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,2],yerr=NGC7213_err_z[1,:],color='orange',fmt='o',label='NGC7213 z STA2')
plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,3],yerr=NGC7213_err_z[1,:],color='orange',fmt='*',label='NGC7213 z STA3')

plt.title('NGC7213 FLux')
plt.legend()
plt.ylim([4*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

# %%
print ESO323_err_K[1,:]
print ESO323_K[:,1]
# Out:
# [  1.12252024e-17   1.07499456e-17   1.34668994e-17   1.37674875e-17
#    1.36449622e-17   1.17918219e-17              nan   1.20590904e-17
#    1.01151774e-17   9.87569452e-18              nan   8.86870809e-18
#    9.34857145e-18   9.82544971e-18   8.85096653e-18   8.24339404e-18
#    8.74786166e-18   7.88525261e-18   9.39115013e-18   9.51020369e-18
#    8.77636373e-18   1.24931349e-17   1.15841052e-17   1.80991010e-17
#    1.18027308e-17   1.48052339e-17]
# [  1.00456185e-14   9.87474213e-15   9.85225878e-15   9.66271044e-15
#    9.66634929e-15   9.55275819e-15              nan   9.57863873e-15
#    9.56108823e-15   8.92600939e-15   8.65186245e-15   8.94115925e-15
#    8.70893095e-15   8.81268815e-15   8.48793663e-15   8.62467877e-15
#    8.81974063e-15   8.54166698e-15   8.61457158e-15   8.60342184e-15
#    8.56361952e-15   8.57491812e-15   8.34349929e-15   1.25850864e-14
#    8.34948024e-15   8.47897988e-15]

# %%
plt.figure(figsize=(15,10))
plt.errorbar(ESO323_K[:,0],ESO323_K[:,1],yerr=ESO323_err_K[1,:],color='b',fmt='x',label='ESO323 K STA1')
plt.errorbar(ESO323_K[:,0],ESO323_K[:,2],yerr=ESO323_err_K[2,:],color='b',fmt='o',label='ESO323 K STA2')
plt.errorbar(ESO323_K[:,0],ESO323_K[:,3],yerr=ESO323_err_K[3,:],color='b',fmt='*',label='ESO323 K STA3')

plt.errorbar(ESO323_H[:,0],ESO323_H[:,1],yerr=ESO323_err_H[1,:],color='r',fmt='x',label='ESO323 H STA1')
plt.errorbar(ESO323_H[:,0],ESO323_H[:,2],yerr=ESO323_err_H[1,:],color='r',fmt='o',label='ESO323 H STA2')
plt.errorbar(ESO323_H[:,0],ESO323_H[:,3],yerr=ESO323_err_H[1,:],color='r',fmt='*',label='ESO323 H STA3')

plt.errorbar(ESO323_J[:,0],ESO323_J[:,1],yerr=ESO323_err_J[1,:],color='g',fmt='x',label='ESO323 J STA1')
plt.errorbar(ESO323_J[:,0],ESO323_J[:,2],yerr=ESO323_err_J[1,:],color='g',fmt='o',label='ESO323 J STA2')
plt.errorbar(ESO323_J[:,0],ESO323_J[:,3],yerr=ESO323_err_J[1,:],color='g',fmt='*',label='ESO323 J STA3')

plt.errorbar(ESO323_g[:,0],ESO323_g[:,1],yerr=ESO323_err_g[1,:],color='purple',fmt='x',label='ESO323 g STA1')
plt.errorbar(ESO323_g[:,0],ESO323_g[:,2],yerr=ESO323_err_g[1,:],color='purple',fmt='o',label='ESO323 g STA2')
plt.errorbar(ESO323_g[:,0],ESO323_g[:,3],yerr=ESO323_err_g[1,:],color='purple',fmt='*',label='ESO323 g STA3')

plt.errorbar(ESO323_r[:,0],ESO323_r[:,1],yerr=ESO323_err_r[1,:],color='black',fmt='x',label='ESO323 r STA1')
plt.errorbar(ESO323_r[:,0],ESO323_r[:,2],yerr=ESO323_err_r[1,:],color='black',fmt='o',label='ESO323 r STA2')
plt.errorbar(ESO323_r[:,0],ESO323_r[:,3],yerr=ESO323_err_r[1,:],color='black',fmt='*',label='ESO323 r STA3')

plt.errorbar(ESO323_i[:,0],ESO323_i[:,1],yerr=ESO323_err_i[1,:],color='yellow',fmt='x',label='ESO323 i STA1')
plt.errorbar(ESO323_i[:,0],ESO323_i[:,2],yerr=ESO323_err_i[1,:],color='yellow',fmt='o',label='ESO323 i STA2')
plt.errorbar(ESO323_i[:,0],ESO323_i[:,3],yerr=ESO323_err_i[1,:],color='yellow',fmt='*',label='ESO323 i STA3')

plt.errorbar(ESO323_z[:,0],ESO323_z[:,1],yerr=ESO323_err_z[1,:],color='orange',fmt='x',label='ESO323 z STA1')
plt.errorbar(ESO323_z[:,0],ESO323_z[:,2],yerr=ESO323_err_z[1,:],color='orange',fmt='o',label='ESO323 z STA2')
plt.errorbar(ESO323_z[:,0],ESO323_z[:,3],yerr=ESO323_err_z[1,:],color='orange',fmt='*',label='ESO323 z STA3')

plt.title('ESO323 FLux')
plt.legend()
plt.ylim([4*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(F9_K[:,0],F9_K[:,1],yerr=F9_err_K[1,:],color='b',fmt='x',label='F9 K STA1')
plt.errorbar(F9_K[:,0],F9_K[:,2],yerr=F9_err_K[2,:],color='b',fmt='o',label='F9 K STA2')
plt.errorbar(F9_K[:,0],F9_K[:,3],yerr=F9_err_K[3,:],color='b',fmt='*',label='F9 K STA3')

plt.errorbar(F9_H[:,0],F9_H[:,1],yerr=F9_err_H[1,:],color='r',fmt='x',label='F9 H STA1')
plt.errorbar(F9_H[:,0],F9_H[:,2],yerr=F9_err_H[1,:],color='r',fmt='o',label='F9 H STA2')
plt.errorbar(F9_H[:,0],F9_H[:,3],yerr=F9_err_H[1,:],color='r',fmt='*',label='F9 H STA3')

plt.errorbar(F9_J[:,0],F9_J[:,1],yerr=F9_err_J[1,:],color='g',fmt='x',label='F9 J STA1')
plt.errorbar(F9_J[:,0],F9_J[:,2],yerr=F9_err_J[1,:],color='g',fmt='o',label='F9 J STA2')
plt.errorbar(F9_J[:,0],F9_J[:,3],yerr=F9_err_J[1,:],color='g',fmt='*',label='F9 J STA3')

plt.errorbar(F9_g[:,0],F9_g[:,1],yerr=F9_err_g[1,:],color='purple',fmt='x',label='F9 g STA1')
plt.errorbar(F9_g[:,0],F9_g[:,2],yerr=F9_err_g[1,:],color='purple',fmt='o',label='F9 g STA2')
plt.errorbar(F9_g[:,0],F9_g[:,3],yerr=F9_err_g[1,:],color='purple',fmt='*',label='F9 g STA3')

plt.errorbar(F9_r[:,0],F9_r[:,1],yerr=F9_err_r[1,:],color='black',fmt='x',label='F9 r STA1')
plt.errorbar(F9_r[:,0],F9_r[:,2],yerr=F9_err_r[1,:],color='black',fmt='o',label='F9 r STA2')
plt.errorbar(F9_r[:,0],F9_r[:,3],yerr=F9_err_r[1,:],color='black',fmt='*',label='F9 r STA3')

plt.errorbar(F9_i[:,0],F9_i[:,1],yerr=F9_err_i[1,:],color='yellow',fmt='x',label='F9 i STA1')
plt.errorbar(F9_i[:,0],F9_i[:,2],yerr=F9_err_i[1,:],color='yellow',fmt='o',label='F9 i STA2')
plt.errorbar(F9_i[:,0],F9_i[:,3],yerr=F9_err_i[1,:],color='yellow',fmt='*',label='F9 i STA3')

plt.errorbar(F9_z[:,0],F9_z[:,1],yerr=F9_err_z[1,:],color='orange',fmt='x',label='F9 z STA1')
plt.errorbar(F9_z[:,0],F9_z[:,2],yerr=F9_err_z[1,:],color='orange',fmt='o',label='F9 z STA2')
plt.errorbar(F9_z[:,0],F9_z[:,3],yerr=F9_err_z[1,:],color='orange',fmt='*',label='F9 z STA3')

plt.title('F9 FLux')
#plt.legend()
plt.ylim([1*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(F51_K[:,0],F51_K[:,1],yerr=F51_err_K[1,:],color='b',fmt='x',label='F51 K STA1')
plt.errorbar(F51_K[:,0],F51_K[:,2],yerr=F51_err_K[2,:],color='b',fmt='o',label='F51 K STA2')
plt.errorbar(F51_K[:,0],F51_K[:,3],yerr=F51_err_K[3,:],color='b',fmt='*',label='F51 K STA3')

plt.errorbar(F51_H[:,0],F51_H[:,1],yerr=F51_err_H[1,:],color='r',fmt='x',label='F51 H STA1')
plt.errorbar(F51_H[:,0],F51_H[:,2],yerr=F51_err_H[1,:],color='r',fmt='o',label='F51 H STA2')
plt.errorbar(F51_H[:,0],F51_H[:,3],yerr=F51_err_H[1,:],color='r',fmt='*',label='F51 H STA3')

plt.errorbar(F51_J[:,0],F51_J[:,1],yerr=F51_err_J[1,:],color='g',fmt='x',label='F51 J STA1')
plt.errorbar(F51_J[:,0],F51_J[:,2],yerr=F51_err_J[1,:],color='g',fmt='o',label='F51 J STA2')
plt.errorbar(F51_J[:,0],F51_J[:,3],yerr=F51_err_J[1,:],color='g',fmt='*',label='F51 J STA3')

plt.errorbar(F51_g[:,0],F51_g[:,1],yerr=F51_err_g[1,:],color='purple',fmt='x',label='F51 g STA1')
plt.errorbar(F51_g[:,0],F51_g[:,2],yerr=F51_err_g[1,:],color='purple',fmt='o',label='F51 g STA2')
plt.errorbar(F51_g[:,0],F51_g[:,3],yerr=F51_err_g[1,:],color='purple',fmt='*',label='F51 g STA3')

plt.errorbar(F51_r[:,0],F51_r[:,1],yerr=F51_err_r[1,:],color='black',fmt='x',label='F51 r STA1')
plt.errorbar(F51_r[:,0],F51_r[:,2],yerr=F51_err_r[1,:],color='black',fmt='o',label='F51 r STA2')
plt.errorbar(F51_r[:,0],F51_r[:,3],yerr=F51_err_r[1,:],color='black',fmt='*',label='F51 r STA3')

plt.errorbar(F51_i[:,0],F51_i[:,1],yerr=F51_err_i[1,:],color='yellow',fmt='x',label='F51 i STA1')
plt.errorbar(F51_i[:,0],F51_i[:,2],yerr=F51_err_i[1,:],color='yellow',fmt='o',label='F51 i STA2')
plt.errorbar(F51_i[:,0],F51_i[:,3],yerr=F51_err_i[1,:],color='yellow',fmt='*',label='F51 i STA3')

plt.errorbar(F51_z[:,0],F51_z[:,1],yerr=F51_err_z[1,:],color='orange',fmt='x',label='F51 z STA1')
plt.errorbar(F51_z[:,0],F51_z[:,2],yerr=F51_err_z[1,:],color='orange',fmt='o',label='F51 z STA2')
plt.errorbar(F51_z[:,0],F51_z[:,3],yerr=F51_err_z[1,:],color='orange',fmt='*',label='F51 z STA3')

plt.title('F51 FLux')
#plt.legend()
plt.ylim([2*10**(-15),1.1*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(AKN120_K[:,0],AKN120_K[:,1],yerr=AKN120_err_K[1,:],color='b',fmt='x',label='AKN120 K STA1')
plt.errorbar(AKN120_K[:,0],AKN120_K[:,2],yerr=AKN120_err_K[2,:],color='b',fmt='o',label='AKN120 K STA2')
plt.errorbar(AKN120_K[:,0],AKN120_K[:,3],yerr=AKN120_err_K[3,:],color='b',fmt='*',label='AKN120 K STA3')

plt.errorbar(AKN120_H[:,0],AKN120_H[:,1],yerr=AKN120_err_H[1,:],color='r',fmt='x',label='AKN120 H STA1')
plt.errorbar(AKN120_H[:,0],AKN120_H[:,2],yerr=AKN120_err_H[1,:],color='r',fmt='o',label='AKN120 H STA2')
plt.errorbar(AKN120_H[:,0],AKN120_H[:,3],yerr=AKN120_err_H[1,:],color='r',fmt='*',label='AKN120 H STA3')

plt.errorbar(AKN120_J[:,0],AKN120_J[:,1],yerr=AKN120_err_J[1,:],color='g',fmt='x',label='AKN120 J STA1')
plt.errorbar(AKN120_J[:,0],AKN120_J[:,2],yerr=AKN120_err_J[1,:],color='g',fmt='o',label='AKN120 J STA2')
plt.errorbar(AKN120_J[:,0],AKN120_J[:,3],yerr=AKN120_err_J[1,:],color='g',fmt='*',label='AKN120 J STA3')

plt.errorbar(AKN120_g[:,0],AKN120_g[:,1],yerr=AKN120_err_g[1,:],color='purple',fmt='x',label='AKN120 g STA1')
plt.errorbar(AKN120_g[:,0],AKN120_g[:,2],yerr=AKN120_err_g[1,:],color='purple',fmt='o',label='AKN120 g STA2')
plt.errorbar(AKN120_g[:,0],AKN120_g[:,3],yerr=AKN120_err_g[1,:],color='purple',fmt='*',label='AKN120 g STA3')

plt.errorbar(AKN120_r[:,0],AKN120_r[:,1],yerr=AKN120_err_r[1,:],color='black',fmt='x',label='AKN120 r STA1')
plt.errorbar(AKN120_r[:,0],AKN120_r[:,2],yerr=AKN120_err_r[1,:],color='black',fmt='o',label='AKN120 r STA2')
plt.errorbar(AKN120_r[:,0],AKN120_r[:,3],yerr=AKN120_err_r[1,:],color='black',fmt='*',label='AKN120 r STA3')

plt.errorbar(AKN120_i[:,0],AKN120_i[:,1],yerr=AKN120_err_i[1,:],color='yellow',fmt='x',label='AKN120 i STA1')
plt.errorbar(AKN120_i[:,0],AKN120_i[:,2],yerr=AKN120_err_i[1,:],color='yellow',fmt='o',label='AKN120 i STA2')
plt.errorbar(AKN120_i[:,0],AKN120_i[:,3],yerr=AKN120_err_i[1,:],color='yellow',fmt='*',label='AKN120 i STA3')

plt.errorbar(AKN120_z[:,0],AKN120_z[:,1],yerr=AKN120_err_z[1,:],color='orange',fmt='x',label='AKN120 z STA1')
plt.errorbar(AKN120_z[:,0],AKN120_z[:,2],yerr=AKN120_err_z[1,:],color='orange',fmt='o',label='AKN120 z STA2')
plt.errorbar(AKN120_z[:,0],AKN120_z[:,3],yerr=AKN120_err_z[1,:],color='orange',fmt='*',label='AKN120 z STA3')

plt.title('AKN120 FLux')
#plt.legend()
plt.ylim([2*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(NGC3783_K[:,0],NGC3783_K[:,1],yerr=NGC3783_err_K[1,:],color='b',fmt='x',label='NGC3783 K STA1')
plt.errorbar(NGC3783_K[:,0],NGC3783_K[:,2],yerr=NGC3783_err_K[2,:],color='b',fmt='o',label='NGC3783 K STA2')
plt.errorbar(NGC3783_K[:,0],NGC3783_K[:,3],yerr=NGC3783_err_K[3,:],color='b',fmt='*',label='NGC3783 K STA3')

plt.errorbar(NGC3783_H[:,0],NGC3783_H[:,1],yerr=NGC3783_err_H[1,:],color='r',fmt='x',label='NGC3783 H STA1')
plt.errorbar(NGC3783_H[:,0],NGC3783_H[:,2],yerr=NGC3783_err_H[1,:],color='r',fmt='o',label='NGC3783 H STA2')
plt.errorbar(NGC3783_H[:,0],NGC3783_H[:,3],yerr=NGC3783_err_H[1,:],color='r',fmt='*',label='NGC3783 H STA3')

plt.errorbar(NGC3783_J[:,0],NGC3783_J[:,1],yerr=NGC3783_err_J[1,:],color='g',fmt='x',label='NGC3783 J STA1')
plt.errorbar(NGC3783_J[:,0],NGC3783_J[:,2],yerr=NGC3783_err_J[1,:],color='g',fmt='o',label='NGC3783 J STA2')
plt.errorbar(NGC3783_J[:,0],NGC3783_J[:,3],yerr=NGC3783_err_J[1,:],color='g',fmt='*',label='NGC3783 J STA3')

plt.errorbar(NGC3783_g[:,0],NGC3783_g[:,1],yerr=NGC3783_err_g[1,:],color='purple',fmt='x',label='NGC3783 g STA1')
plt.errorbar(NGC3783_g[:,0],NGC3783_g[:,2],yerr=NGC3783_err_g[1,:],color='purple',fmt='o',label='NGC3783 g STA2')
plt.errorbar(NGC3783_g[:,0],NGC3783_g[:,3],yerr=NGC3783_err_g[1,:],color='purple',fmt='*',label='NGC3783 g STA3')

plt.errorbar(NGC3783_r[:,0],NGC3783_r[:,1],yerr=NGC3783_err_r[1,:],color='black',fmt='x',label='NGC3783 r STA1')
plt.errorbar(NGC3783_r[:,0],NGC3783_r[:,2],yerr=NGC3783_err_r[1,:],color='black',fmt='o',label='NGC3783 r STA2')
plt.errorbar(NGC3783_r[:,0],NGC3783_r[:,3],yerr=NGC3783_err_r[1,:],color='black',fmt='*',label='NGC3783 r STA3')

plt.errorbar(NGC3783_i[:,0],NGC3783_i[:,1],yerr=NGC3783_err_i[1,:],color='yellow',fmt='x',label='NGC3783 i STA1')
plt.errorbar(NGC3783_i[:,0],NGC3783_i[:,2],yerr=NGC3783_err_i[1,:],color='yellow',fmt='o',label='NGC3783 i STA2')
plt.errorbar(NGC3783_i[:,0],NGC3783_i[:,3],yerr=NGC3783_err_i[1,:],color='yellow',fmt='*',label='NGC3783 i STA3')

plt.errorbar(NGC3783_z[:,0],NGC3783_z[:,1],yerr=NGC3783_err_z[1,:],color='orange',fmt='x',label='NGC3783 z STA1')
plt.errorbar(NGC3783_z[:,0],NGC3783_z[:,2],yerr=NGC3783_err_z[1,:],color='orange',fmt='o',label='NGC3783 z STA2')
plt.errorbar(NGC3783_z[:,0],NGC3783_z[:,3],yerr=NGC3783_err_z[1,:],color='orange',fmt='*',label='NGC3783 z STA3')

plt.title('NGC3783 FLux')
#plt.legend()
plt.ylim([5*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(MARK509_K[:,0],MARK509_K[:,1],yerr=MARK509_err_K[1,:],color='b',fmt='x',label='MARK509 K STA1')
plt.errorbar(MARK509_K[:,0],MARK509_K[:,2],yerr=MARK509_err_K[2,:],color='b',fmt='o',label='MARK509 K STA2')
plt.errorbar(MARK509_K[:,0],MARK509_K[:,3],yerr=MARK509_err_K[3,:],color='b',fmt='*',label='MARK509 K STA3')

plt.errorbar(MARK509_H[:,0],MARK509_H[:,1],yerr=MARK509_err_H[1,:],color='r',fmt='x',label='MARK509 H STA1')
plt.errorbar(MARK509_H[:,0],MARK509_H[:,2],yerr=MARK509_err_H[1,:],color='r',fmt='o',label='MARK509 H STA2')
plt.errorbar(MARK509_H[:,0],MARK509_H[:,3],yerr=MARK509_err_H[1,:],color='r',fmt='*',label='MARK509 H STA3')

plt.errorbar(MARK509_J[:,0],MARK509_J[:,1],yerr=MARK509_err_J[1,:],color='g',fmt='x',label='MARK509 J STA1')
plt.errorbar(MARK509_J[:,0],MARK509_J[:,2],yerr=MARK509_err_J[1,:],color='g',fmt='o',label='MARK509 J STA2')
plt.errorbar(MARK509_J[:,0],MARK509_J[:,3],yerr=MARK509_err_J[1,:],color='g',fmt='*',label='MARK509 J STA3')

plt.errorbar(MARK509_g[:,0],MARK509_g[:,1],yerr=MARK509_err_g[1,:],color='purple',fmt='x',label='MARK509 g STA1')
plt.errorbar(MARK509_g[:,0],MARK509_g[:,2],yerr=MARK509_err_g[1,:],color='purple',fmt='o',label='MARK509 g STA2')
plt.errorbar(MARK509_g[:,0],MARK509_g[:,3],yerr=MARK509_err_g[1,:],color='purple',fmt='*',label='MARK509 g STA3')

plt.errorbar(MARK509_r[:,0],MARK509_r[:,1],yerr=MARK509_err_r[1,:],color='black',fmt='x',label='MARK509 r STA1')
plt.errorbar(MARK509_r[:,0],MARK509_r[:,2],yerr=MARK509_err_r[1,:],color='black',fmt='o',label='MARK509 r STA2')
plt.errorbar(MARK509_r[:,0],MARK509_r[:,3],yerr=MARK509_err_r[1,:],color='black',fmt='*',label='MARK509 r STA3')

plt.errorbar(MARK509_i[:,0],MARK509_i[:,1],yerr=MARK509_err_i[1,:],color='yellow',fmt='x',label='MARK509 i STA1')
plt.errorbar(MARK509_i[:,0],MARK509_i[:,2],yerr=MARK509_err_i[1,:],color='yellow',fmt='o',label='MARK509 i STA2')
plt.errorbar(MARK509_i[:,0],MARK509_i[:,3],yerr=MARK509_err_i[1,:],color='yellow',fmt='*',label='MARK509 i STA3')

plt.errorbar(MARK509_z[:,0],MARK509_z[:,1],yerr=MARK509_err_z[1,:],color='orange',fmt='x',label='MARK509 z STA1')
plt.errorbar(MARK509_z[:,0],MARK509_z[:,2],yerr=MARK509_err_z[1,:],color='orange',fmt='o',label='MARK509 z STA2')
plt.errorbar(MARK509_z[:,0],MARK509_z[:,3],yerr=MARK509_err_z[1,:],color='orange',fmt='*',label='MARK509 z STA3')

plt.title('MARK509 FLux')
#plt.legend()
plt.ylim([2*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(H0557_K[:,0],H0557_K[:,1],color='b',fmt='x',label='H0557 K STA1')
plt.errorbar(H0557_K[:,0],H0557_K[:,2],color='b',fmt='o',label='H0557 K STA2')
plt.errorbar(H0557_K[:,0],H0557_K[:,3],color='b',fmt='*',label='H0557 K STA3')

plt.errorbar(H0557_H[:,0],H0557_H[:,1],color='r',fmt='x',label='H0557 H STA1')
plt.errorbar(H0557_H[:,0],H0557_H[:,2],color='r',fmt='o',label='H0557 H STA2')
plt.errorbar(H0557_H[:,0],H0557_H[:,3],color='r',fmt='*',label='H0557 H STA3')

plt.errorbar(H0557_J[:,0],H0557_J[:,1],color='g',fmt='x',label='H0557 J STA1')
plt.errorbar(H0557_J[:,0],H0557_J[:,2],color='g',fmt='o',label='H0557 J STA2')
plt.errorbar(H0557_J[:,0],H0557_J[:,3],color='g',fmt='*',label='H0557 J STA3')

plt.errorbar(H0557_g[:,0],H0557_g[:,1],color='purple',fmt='x',label='H0557 g STA1')
plt.errorbar(H0557_g[:,0],H0557_g[:,2],color='purple',fmt='o',label='H0557 g STA2')
plt.errorbar(H0557_g[:,0],H0557_g[:,3],color='purple',fmt='*',label='H0557 g STA3')

plt.errorbar(H0557_r[:,0],H0557_r[:,1],color='black',fmt='x',label='H0557 r STA1')
plt.errorbar(H0557_r[:,0],H0557_r[:,2],color='black',fmt='o',label='H0557 r STA2')
plt.errorbar(H0557_r[:,0],H0557_r[:,3],color='black',fmt='*',label='H0557 r STA3')

plt.errorbar(H0557_i[:,0],H0557_i[:,1],color='yellow',fmt='x',label='H0557 i STA1')
plt.errorbar(H0557_i[:,0],H0557_i[:,2],color='yellow',fmt='o',label='H0557 i STA2')
plt.errorbar(H0557_i[:,0],H0557_i[:,3],color='yellow',fmt='*',label='H0557 i STA3')

plt.errorbar(H0557_z[:,0],H0557_z[:,1],color='orange',fmt='x',label='H0557 z STA1')
plt.errorbar(H0557_z[:,0],H0557_z[:,2],color='orange',fmt='o',label='H0557 z STA2')
plt.errorbar(H0557_z[:,0],H0557_z[:,3],color='orange',fmt='*',label='H0557 z STA3')

plt.title('H0557 FLux')
#plt.legend()
plt.ylim([2*10**(-15),1.6*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,1],yerr=NGC7213_err_K[1,:],color='b',fmt='x',label='NGC7213 K STA1')
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,2],yerr=NGC7213_err_K[2,:],color='b',fmt='o',label='NGC7213 K STA2')
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,3],yerr=NGC7213_err_K[3,:],color='b',fmt='*',label='NGC7213 K STA3')

plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,1],yerr=NGC7213_err_H[1,:],color='r',fmt='x',label='NGC7213 H STA1')
plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,2],yerr=NGC7213_err_H[1,:],color='r',fmt='o',label='NGC7213 H STA2')
plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,3],yerr=NGC7213_err_H[1,:],color='r',fmt='*',label='NGC7213 H STA3')

plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,1],yerr=NGC7213_err_J[1,:],color='g',fmt='x',label='NGC7213 J STA1')
plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,2],yerr=NGC7213_err_J[1,:],color='g',fmt='o',label='NGC7213 J STA2')
plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,3],yerr=NGC7213_err_J[1,:],color='g',fmt='*',label='NGC7213 J STA3')

plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,1],yerr=NGC7213_err_g[1,:],color='purple',fmt='x',label='NGC7213 g STA1')
plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,2],yerr=NGC7213_err_g[1,:],color='purple',fmt='o',label='NGC7213 g STA2')
plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,3],yerr=NGC7213_err_g[1,:],color='purple',fmt='*',label='NGC7213 g STA3')

plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,1],yerr=NGC7213_err_r[1,:],color='black',fmt='x',label='NGC7213 r STA1')
plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,2],yerr=NGC7213_err_r[1,:],color='black',fmt='o',label='NGC7213 r STA2')
plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,3],yerr=NGC7213_err_r[1,:],color='black',fmt='*',label='NGC7213 r STA3')

plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,1],yerr=NGC7213_err_i[1,:],color='yellow',fmt='x',label='NGC7213 i STA1')
plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,2],yerr=NGC7213_err_i[1,:],color='yellow',fmt='o',label='NGC7213 i STA2')
plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,3],yerr=NGC7213_err_i[1,:],color='yellow',fmt='*',label='NGC7213 i STA3')

plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,1],yerr=NGC7213_err_z[1,:],color='orange',fmt='x',label='NGC7213 z STA1')
plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,2],yerr=NGC7213_err_z[1,:],color='orange',fmt='o',label='NGC7213 z STA2')
plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,3],yerr=NGC7213_err_z[1,:],color='orange',fmt='*',label='NGC7213 z STA3')

plt.title('NGC7213 FLux')
plt.legend()
plt.ylim([10*10**(-15),4.5*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(ESO323_K_SNR[:,0],ESO323_K_SNR[:,2],label='ESO323 K SIGNAL')
plt.scatter(ESO323_K_SNR[:,0],ESO323_K_SNR[:,3],label='ESO323 K SKY')
plt.scatter(ESO323_K_SNR[:,0],ESO323_K_SNR[:,4],label='ESO323 K RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(ESO323_H_SNR[:,0],ESO323_H_SNR[:,2],label='ESO323 H SIGNAL')
plt.scatter(ESO323_H_SNR[:,0],ESO323_H_SNR[:,3],label='ESO323 H SKY')
plt.scatter(ESO323_H_SNR[:,0],ESO323_H_SNR[:,4],label='ESO323 H RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(ESO323_J_SNR[:,0],ESO323_J_SNR[:,2],label='ESO323 J SIGNAL')
plt.scatter(ESO323_J_SNR[:,0],ESO323_J_SNR[:,3],label='ESO323 J SKY')
plt.scatter(ESO323_J_SNR[:,0],ESO323_J_SNR[:,4],label='ESO323 J RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(ESO323_g_SNR[:,0],ESO323_g_SNR[:,2],label='ESO323 g SIGNAL')
plt.scatter(ESO323_g_SNR[:,0],ESO323_g_SNR[:,3],label='ESO323 g SKY')
plt.scatter(ESO323_g_SNR[:,0],ESO323_g_SNR[:,4],label='ESO323 g RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(ESO323_r_SNR[:,0],ESO323_r_SNR[:,2],label='ESO323 r SIGNAL')
plt.scatter(ESO323_r_SNR[:,0],ESO323_r_SNR[:,3],label='ESO323 r SKY')
plt.scatter(ESO323_r_SNR[:,0],ESO323_r_SNR[:,4],label='ESO323 r RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(ESO323_i_SNR[:,0],ESO323_i_SNR[:,2],label='ESO323 i SIGNAL')
plt.scatter(ESO323_i_SNR[:,0],ESO323_i_SNR[:,3],label='ESO323 i SKY')
plt.scatter(ESO323_i_SNR[:,0],ESO323_i_SNR[:,4],label='ESO323 i RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(ESO323_z_SNR[:,0],ESO323_z_SNR[:,2],label='ESO323 z SIGNAL')
plt.scatter(ESO323_z_SNR[:,0],ESO323_z_SNR[:,3],label='ESO323 z SKY')
plt.scatter(ESO323_z_SNR[:,0],ESO323_z_SNR[:,4],label='ESO323 z RON')

plt.legend()

plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(AKN120_K_SNR[:,0],AKN120_K_SNR[:,2],label='AKN120 K SIGNAL')
plt.scatter(AKN120_K_SNR[:,0],AKN120_K_SNR[:,3],label='AKN120 K SKY')
plt.scatter(AKN120_K_SNR[:,0],AKN120_K_SNR[:,4],label='AKN120 K RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(AKN120_H_SNR[:,0],AKN120_H_SNR[:,2],label='AKN120 H SIGNAL')
plt.scatter(AKN120_H_SNR[:,0],AKN120_H_SNR[:,3],label='AKN120 H SKY')
plt.scatter(AKN120_H_SNR[:,0],AKN120_H_SNR[:,4],label='AKN120 H RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(AKN120_J_SNR[:,0],AKN120_J_SNR[:,2],label='AKN120 J SIGNAL')
plt.scatter(AKN120_J_SNR[:,0],AKN120_J_SNR[:,3],label='AKN120 J SKY')
plt.scatter(AKN120_J_SNR[:,0],AKN120_J_SNR[:,4],label='AKN120 J RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(AKN120_g_SNR[:,0],AKN120_g_SNR[:,2],label='AKN120 g SIGNAL')
plt.scatter(AKN120_g_SNR[:,0],AKN120_g_SNR[:,3],label='AKN120 g SKY')
plt.scatter(AKN120_g_SNR[:,0],AKN120_g_SNR[:,4],label='AKN120 g RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(AKN120_r_SNR[:,0],AKN120_r_SNR[:,2],label='AKN120 r SIGNAL')
plt.scatter(AKN120_r_SNR[:,0],AKN120_r_SNR[:,3],label='AKN120 r SKY')
plt.scatter(AKN120_r_SNR[:,0],AKN120_r_SNR[:,4],label='AKN120 r RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(AKN120_i_SNR[:,0],AKN120_i_SNR[:,2],label='AKN120 i SIGNAL')
plt.scatter(AKN120_i_SNR[:,0],AKN120_i_SNR[:,3],label='AKN120 i SKY')
plt.scatter(AKN120_i_SNR[:,0],AKN120_i_SNR[:,4],label='AKN120 i RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(AKN120_z_SNR[:,0],AKN120_z_SNR[:,2],label='AKN120 z SIGNAL')
plt.scatter(AKN120_z_SNR[:,0],AKN120_z_SNR[:,3],label='AKN120 z SKY')
plt.scatter(AKN120_z_SNR[:,0],AKN120_z_SNR[:,4],label='AKN120 z RON')

plt.legend()

plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(NGC3783_K_SNR[:,0],NGC3783_K_SNR[:,2],label='NGC3783 K SIGNAL')
plt.scatter(NGC3783_K_SNR[:,0],NGC3783_K_SNR[:,3],label='NGC3783 K SKY')
plt.scatter(NGC3783_K_SNR[:,0],NGC3783_K_SNR[:,4],label='NGC3783 K RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC3783_H_SNR[:,0],NGC3783_H_SNR[:,2],label='NGC3783 H SIGNAL')
plt.scatter(NGC3783_H_SNR[:,0],NGC3783_H_SNR[:,3],label='NGC3783 H SKY')
plt.scatter(NGC3783_H_SNR[:,0],NGC3783_H_SNR[:,4],label='NGC3783 H RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC3783_J_SNR[:,0],NGC3783_J_SNR[:,2],label='NGC3783 J SIGNAL')
plt.scatter(NGC3783_J_SNR[:,0],NGC3783_J_SNR[:,3],label='NGC3783 J SKY')
plt.scatter(NGC3783_J_SNR[:,0],NGC3783_J_SNR[:,4],label='NGC3783 J RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC3783_g_SNR[:,0],NGC3783_g_SNR[:,2],label='NGC3783 g SIGNAL')
plt.scatter(NGC3783_g_SNR[:,0],NGC3783_g_SNR[:,3],label='NGC3783 g SKY')
plt.scatter(NGC3783_g_SNR[:,0],NGC3783_g_SNR[:,4],label='NGC3783 g RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC3783_r_SNR[:,0],NGC3783_r_SNR[:,2],label='NGC3783 r SIGNAL')
plt.scatter(NGC3783_r_SNR[:,0],NGC3783_r_SNR[:,3],label='NGC3783 r SKY')
plt.scatter(NGC3783_r_SNR[:,0],NGC3783_r_SNR[:,4],label='NGC3783 r RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC3783_i_SNR[:,0],NGC3783_i_SNR[:,2],label='NGC3783 i SIGNAL')
plt.scatter(NGC3783_i_SNR[:,0],NGC3783_i_SNR[:,3],label='NGC3783 i SKY')
plt.scatter(NGC3783_i_SNR[:,0],NGC3783_i_SNR[:,4],label='NGC3783 i RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC3783_z_SNR[:,0],NGC3783_z_SNR[:,2],label='NGC3783 z SIGNAL')
plt.scatter(NGC3783_z_SNR[:,0],NGC3783_z_SNR[:,3],label='NGC3783 z SKY')
plt.scatter(NGC3783_z_SNR[:,0],NGC3783_z_SNR[:,4],label='NGC3783 z RON')

plt.legend()

plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(NGC7213_K_SNR[:,0],NGC7213_K_SNR[:,2],label='NGC7213 K SIGNAL')
plt.scatter(NGC7213_K_SNR[:,0],NGC7213_K_SNR[:,3],label='NGC7213 K SKY')
plt.scatter(NGC7213_K_SNR[:,0],NGC7213_K_SNR[:,4],label='NGC7213 K RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC7213_H_SNR[:,0],NGC7213_H_SNR[:,2],label='NGC7213 H SIGNAL')
plt.scatter(NGC7213_H_SNR[:,0],NGC7213_H_SNR[:,3],label='NGC7213 H SKY')
plt.scatter(NGC7213_H_SNR[:,0],NGC7213_H_SNR[:,4],label='NGC7213 H RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC7213_J_SNR[:,0],NGC7213_J_SNR[:,2],label='NGC7213 J SIGNAL')
plt.scatter(NGC7213_J_SNR[:,0],NGC7213_J_SNR[:,3],label='NGC7213 J SKY')
plt.scatter(NGC7213_J_SNR[:,0],NGC7213_J_SNR[:,4],label='NGC7213 J RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC7213_g_SNR[:,0],NGC7213_g_SNR[:,2],label='NGC7213 g SIGNAL')
plt.scatter(NGC7213_g_SNR[:,0],NGC7213_g_SNR[:,3],label='NGC7213 g SKY')
plt.scatter(NGC7213_g_SNR[:,0],NGC7213_g_SNR[:,4],label='NGC7213 g RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC7213_r_SNR[:,0],NGC7213_r_SNR[:,2],label='NGC7213 r SIGNAL')
plt.scatter(NGC7213_r_SNR[:,0],NGC7213_r_SNR[:,3],label='NGC7213 r SKY')
plt.scatter(NGC7213_r_SNR[:,0],NGC7213_r_SNR[:,4],label='NGC7213 r RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC7213_i_SNR[:,0],NGC7213_i_SNR[:,2],label='NGC7213 i SIGNAL')
plt.scatter(NGC7213_i_SNR[:,0],NGC7213_i_SNR[:,3],label='NGC7213 i SKY')
plt.scatter(NGC7213_i_SNR[:,0],NGC7213_i_SNR[:,4],label='NGC7213 i RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(NGC7213_z_SNR[:,0],NGC7213_z_SNR[:,2],label='NGC7213 z SIGNAL')
plt.scatter(NGC7213_z_SNR[:,0],NGC7213_z_SNR[:,3],label='NGC7213 z SKY')
plt.scatter(NGC7213_z_SNR[:,0],NGC7213_z_SNR[:,4],label='NGC7213 z RON')

plt.legend()

plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(F9_g_SNR[:,0],F9_g_SNR[:,1],label='F9 g SNR')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F9_K_SNR[:,0],F9_K_SNR[:,2],label='F9 K SIGNAL')
plt.scatter(F9_K_SNR[:,0],F9_K_SNR[:,3],label='F9 K SKY')
plt.scatter(F9_K_SNR[:,0],F9_K_SNR[:,4],label='F9 K RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F9_H_SNR[:,0],F9_H_SNR[:,2],label='F9 H SIGNAL')
plt.scatter(F9_H_SNR[:,0],F9_H_SNR[:,3],label='F9 H SKY')
plt.scatter(F9_H_SNR[:,0],F9_H_SNR[:,4],label='F9 H RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F9_J_SNR[:,0],F9_J_SNR[:,2],label='F9 J SIGNAL')
plt.scatter(F9_J_SNR[:,0],F9_J_SNR[:,3],label='F9 J SKY')
plt.scatter(F9_J_SNR[:,0],F9_J_SNR[:,4],label='F9 J RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F9_g_SNR[:,0],F9_g_SNR[:,2],label='F9 g SIGNAL')
plt.scatter(F9_g_SNR[:,0],F9_g_SNR[:,3],label='F9 g SKY')
plt.scatter(F9_g_SNR[:,0],F9_g_SNR[:,4],label='F9 g RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F9_r_SNR[:,0],F9_r_SNR[:,2],label='F9 r SIGNAL')
plt.scatter(F9_r_SNR[:,0],F9_r_SNR[:,3],label='F9 r SKY')
plt.scatter(F9_r_SNR[:,0],F9_r_SNR[:,4],label='F9 r RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F9_i_SNR[:,0],F9_i_SNR[:,2],label='F9 i SIGNAL')
plt.scatter(F9_i_SNR[:,0],F9_i_SNR[:,3],label='F9 i SKY')
plt.scatter(F9_i_SNR[:,0],F9_i_SNR[:,4],label='F9 i RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F9_z_SNR[:,0],F9_z_SNR[:,2],label='F9 z SIGNAL')
plt.scatter(F9_z_SNR[:,0],F9_z_SNR[:,3],label='F9 z SKY')
plt.scatter(F9_z_SNR[:,0],F9_z_SNR[:,4],label='F9 z RON')

plt.legend()

plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(F51_K_SNR[:,0],F51_K_SNR[:,2],label='F51 K SIGNAL')
plt.scatter(F51_K_SNR[:,0],F51_K_SNR[:,3],label='F51 K SKY')
plt.scatter(F51_K_SNR[:,0],F51_K_SNR[:,4],label='F51 K RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F51_H_SNR[:,0],F51_H_SNR[:,2],label='F51 H SIGNAL')
plt.scatter(F51_H_SNR[:,0],F51_H_SNR[:,3],label='F51 H SKY')
plt.scatter(F51_H_SNR[:,0],F51_H_SNR[:,4],label='F51 H RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F51_J_SNR[:,0],F51_J_SNR[:,2],label='F51 J SIGNAL')
plt.scatter(F51_J_SNR[:,0],F51_J_SNR[:,3],label='F51 J SKY')
plt.scatter(F51_J_SNR[:,0],F51_J_SNR[:,4],label='F51 J RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F51_g_SNR[:,0],F51_g_SNR[:,2],label='F51 g SIGNAL')
plt.scatter(F51_g_SNR[:,0],F51_g_SNR[:,3],label='F51 g SKY')
plt.scatter(F51_g_SNR[:,0],F51_g_SNR[:,4],label='F51 g RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F51_r_SNR[:,0],F51_r_SNR[:,2],label='F51 r SIGNAL')
plt.scatter(F51_r_SNR[:,0],F51_r_SNR[:,3],label='F51 r SKY')
plt.scatter(F51_r_SNR[:,0],F51_r_SNR[:,4],label='F51 r RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F51_i_SNR[:,0],F51_i_SNR[:,2],label='F51 i SIGNAL')
plt.scatter(F51_i_SNR[:,0],F51_i_SNR[:,3],label='F51 i SKY')
plt.scatter(F51_i_SNR[:,0],F51_i_SNR[:,4],label='F51 i RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(F51_z_SNR[:,0],F51_z_SNR[:,2],label='F51 z SIGNAL')
plt.scatter(F51_z_SNR[:,0],F51_z_SNR[:,3],label='F51 z SKY')
plt.scatter(F51_z_SNR[:,0],F51_z_SNR[:,4],label='F51 z RON')

plt.legend()

plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(H0557_K_SNR[:,0],H0557_K_SNR[:,2],label='H0557 K SIGNAL')
plt.scatter(H0557_K_SNR[:,0],H0557_K_SNR[:,3],label='H0557 K SKY')
plt.scatter(H0557_K_SNR[:,0],H0557_K_SNR[:,4],label='H0557 K RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(H0557_H_SNR[:,0],H0557_H_SNR[:,2],label='H0557 H SIGNAL')
plt.scatter(H0557_H_SNR[:,0],H0557_H_SNR[:,3],label='H0557 H SKY')
plt.scatter(H0557_H_SNR[:,0],H0557_H_SNR[:,4],label='H0557 H RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(H0557_J_SNR[:,0],H0557_J_SNR[:,2],label='H0557 J SIGNAL')
plt.scatter(H0557_J_SNR[:,0],H0557_J_SNR[:,3],label='H0557 J SKY')
plt.scatter(H0557_J_SNR[:,0],H0557_J_SNR[:,4],label='H0557 J RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(H0557_g_SNR[:,0],H0557_g_SNR[:,2],label='H0557 g SIGNAL')
plt.scatter(H0557_g_SNR[:,0],H0557_g_SNR[:,3],label='H0557 g SKY')
plt.scatter(H0557_g_SNR[:,0],H0557_g_SNR[:,4],label='H0557 g RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(H0557_r_SNR[:,0],H0557_r_SNR[:,2],label='H0557 r SIGNAL')
plt.scatter(H0557_r_SNR[:,0],H0557_r_SNR[:,3],label='H0557 r SKY')
plt.scatter(H0557_r_SNR[:,0],H0557_r_SNR[:,4],label='H0557 r RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(H0557_i_SNR[:,0],H0557_i_SNR[:,2],label='H0557 i SIGNAL')
plt.scatter(H0557_i_SNR[:,0],H0557_i_SNR[:,3],label='H0557 i SKY')
plt.scatter(H0557_i_SNR[:,0],H0557_i_SNR[:,4],label='H0557 i RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(H0557_z_SNR[:,0],H0557_z_SNR[:,2],label='H0557 z SIGNAL')
plt.scatter(H0557_z_SNR[:,0],H0557_z_SNR[:,3],label='H0557 z SKY')
plt.scatter(H0557_z_SNR[:,0],H0557_z_SNR[:,4],label='H0557 z RON')

plt.legend()

plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.scatter(MARK509_K_SNR[:,0],MARK509_K_SNR[:,2],label='MARK509 K SIGNAL')
plt.scatter(MARK509_K_SNR[:,0],MARK509_K_SNR[:,3],label='MARK509 K SKY')
plt.scatter(MARK509_K_SNR[:,0],MARK509_K_SNR[:,4],label='MARK509 K RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(MARK509_H_SNR[:,0],MARK509_H_SNR[:,2],label='MARK509 H SIGNAL')
plt.scatter(MARK509_H_SNR[:,0],MARK509_H_SNR[:,3],label='MARK509 H SKY')
plt.scatter(MARK509_H_SNR[:,0],MARK509_H_SNR[:,4],label='MARK509 H RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(MARK509_J_SNR[:,0],MARK509_J_SNR[:,2],label='MARK509 J SIGNAL')
plt.scatter(MARK509_J_SNR[:,0],MARK509_J_SNR[:,3],label='MARK509 J SKY')
plt.scatter(MARK509_J_SNR[:,0],MARK509_J_SNR[:,4],label='MARK509 J RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(MARK509_g_SNR[:,0],MARK509_g_SNR[:,2],label='MARK509 g SIGNAL')
plt.scatter(MARK509_g_SNR[:,0],MARK509_g_SNR[:,3],label='MARK509 g SKY')
plt.scatter(MARK509_g_SNR[:,0],MARK509_g_SNR[:,4],label='MARK509 g RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(MARK509_r_SNR[:,0],MARK509_r_SNR[:,2],label='MARK509 r SIGNAL')
plt.scatter(MARK509_r_SNR[:,0],MARK509_r_SNR[:,3],label='MARK509 r SKY')
plt.scatter(MARK509_r_SNR[:,0],MARK509_r_SNR[:,4],label='MARK509 r RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(MARK509_i_SNR[:,0],MARK509_i_SNR[:,2],label='MARK509 i SIGNAL')
plt.scatter(MARK509_i_SNR[:,0],MARK509_i_SNR[:,3],label='MARK509 i SKY')
plt.scatter(MARK509_i_SNR[:,0],MARK509_i_SNR[:,4],label='MARK509 i RON')

plt.legend()

plt.xlabel('Days')
plt.show()

plt.figure(figsize=(10,7))

plt.scatter(MARK509_z_SNR[:,0],MARK509_z_SNR[:,2],label='MARK509 z SIGNAL')
plt.scatter(MARK509_z_SNR[:,0],MARK509_z_SNR[:,3],label='MARK509 z SKY')
plt.scatter(MARK509_z_SNR[:,0],MARK509_z_SNR[:,4],label='MARK509 z RON')

plt.legend()

plt.xlabel('Days')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.errorbar(ESO323_K[:,0],ESO323_K[:,1],yerr=10*ESO323_err_K[1,:],color='b',fmt='x',label='ESO323 K STA1')
plt.errorbar(ESO323_K[:,0],ESO323_K[:,2],yerr=10*ESO323_err_K[2,:],color='b',fmt='o',label='ESO323 K STA2')
plt.errorbar(ESO323_K[:,0],ESO323_K[:,3],yerr=10*ESO323_err_K[3,:],color='b',fmt='*',label='ESO323 K STA3')

plt.errorbar(ESO323_H[:,0],ESO323_H[:,1],yerr=10*ESO323_err_H[1,:],color='r',fmt='x',label='ESO323 H STA1')
plt.errorbar(ESO323_H[:,0],ESO323_H[:,2],yerr=10*ESO323_err_H[1,:],color='r',fmt='o',label='ESO323 H STA2')
plt.errorbar(ESO323_H[:,0],ESO323_H[:,3],yerr=10*ESO323_err_H[1,:],color='r',fmt='*',label='ESO323 H STA3')

plt.errorbar(ESO323_J[:,0],ESO323_J[:,1],yerr=10*ESO323_err_J[1,:],color='g',fmt='x',label='ESO323 J STA1')
plt.errorbar(ESO323_J[:,0],ESO323_J[:,2],yerr=10*ESO323_err_J[1,:],color='g',fmt='o',label='ESO323 J STA2')
plt.errorbar(ESO323_J[:,0],ESO323_J[:,3],yerr=10*ESO323_err_J[1,:],color='g',fmt='*',label='ESO323 J STA3')

plt.errorbar(ESO323_g[:,0],ESO323_g[:,1],yerr=10*ESO323_err_g[1,:],color='purple',fmt='x',label='ESO323 g STA1')
plt.errorbar(ESO323_g[:,0],ESO323_g[:,2],yerr=10*ESO323_err_g[1,:],color='purple',fmt='o',label='ESO323 g STA2')
plt.errorbar(ESO323_g[:,0],ESO323_g[:,3],yerr=10*ESO323_err_g[1,:],color='purple',fmt='*',label='ESO323 g STA3')

plt.errorbar(ESO323_r[:,0],ESO323_r[:,1],yerr=10*ESO323_err_r[1,:],color='black',fmt='x',label='ESO323 r STA1')
plt.errorbar(ESO323_r[:,0],ESO323_r[:,2],yerr=10*ESO323_err_r[1,:],color='black',fmt='o',label='ESO323 r STA2')
plt.errorbar(ESO323_r[:,0],ESO323_r[:,3],yerr=10*ESO323_err_r[1,:],color='black',fmt='*',label='ESO323 r STA3')

plt.errorbar(ESO323_i[:,0],ESO323_i[:,1],yerr=10*ESO323_err_i[1,:],color='yellow',fmt='x',label='ESO323 i STA1')
plt.errorbar(ESO323_i[:,0],ESO323_i[:,2],yerr=10*ESO323_err_i[1,:],color='yellow',fmt='o',label='ESO323 i STA2')
plt.errorbar(ESO323_i[:,0],ESO323_i[:,3],yerr=10*ESO323_err_i[1,:],color='yellow',fmt='*',label='ESO323 i STA3')

plt.errorbar(ESO323_z[:,0],ESO323_z[:,1],yerr=10*ESO323_err_z[1,:],color='orange',fmt='x',label='ESO323 z STA1')
plt.errorbar(ESO323_z[:,0],ESO323_z[:,2],yerr=10*ESO323_err_z[1,:],color='orange',fmt='o',label='ESO323 z STA2')
plt.errorbar(ESO323_z[:,0],ESO323_z[:,3],yerr=10*ESO323_err_z[1,:],color='orange',fmt='*',label='ESO323 z STA3')

plt.title('ESO323 FLux')
plt.legend()
plt.ylim([4*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(F9_K[:,0],F9_K[:,1],yerr=10*F9_err_K[1,:],color='b',fmt='x',label='F9 K STA1')
plt.errorbar(F9_K[:,0],F9_K[:,2],yerr=10*F9_err_K[2,:],color='b',fmt='o',label='F9 K STA2')
plt.errorbar(F9_K[:,0],F9_K[:,3],yerr=10*F9_err_K[3,:],color='b',fmt='*',label='F9 K STA3')

plt.errorbar(F9_H[:,0],F9_H[:,1],yerr=10*F9_err_H[1,:],color='r',fmt='x',label='F9 H STA1')
plt.errorbar(F9_H[:,0],F9_H[:,2],yerr=10*F9_err_H[1,:],color='r',fmt='o',label='F9 H STA2')
plt.errorbar(F9_H[:,0],F9_H[:,3],yerr=10*F9_err_H[1,:],color='r',fmt='*',label='F9 H STA3')

plt.errorbar(F9_J[:,0],F9_J[:,1],yerr=10*F9_err_J[1,:],color='g',fmt='x',label='F9 J STA1')
plt.errorbar(F9_J[:,0],F9_J[:,2],yerr=10*F9_err_J[1,:],color='g',fmt='o',label='F9 J STA2')
plt.errorbar(F9_J[:,0],F9_J[:,3],yerr=10*F9_err_J[1,:],color='g',fmt='*',label='F9 J STA3')

plt.errorbar(F9_g[:,0],F9_g[:,1],yerr=10*F9_err_g[1,:],color='purple',fmt='x',label='F9 g STA1')
plt.errorbar(F9_g[:,0],F9_g[:,2],yerr=10*F9_err_g[1,:],color='purple',fmt='o',label='F9 g STA2')
plt.errorbar(F9_g[:,0],F9_g[:,3],yerr=10*F9_err_g[1,:],color='purple',fmt='*',label='F9 g STA3')

plt.errorbar(F9_r[:,0],F9_r[:,1],yerr=10*F9_err_r[1,:],color='black',fmt='x',label='F9 r STA1')
plt.errorbar(F9_r[:,0],F9_r[:,2],yerr=10*F9_err_r[1,:],color='black',fmt='o',label='F9 r STA2')
plt.errorbar(F9_r[:,0],F9_r[:,3],yerr=10*F9_err_r[1,:],color='black',fmt='*',label='F9 r STA3')

plt.errorbar(F9_i[:,0],F9_i[:,1],yerr=10*F9_err_i[1,:],color='yellow',fmt='x',label='F9 i STA1')
plt.errorbar(F9_i[:,0],F9_i[:,2],yerr=10*F9_err_i[1,:],color='yellow',fmt='o',label='F9 i STA2')
plt.errorbar(F9_i[:,0],F9_i[:,3],yerr=10*F9_err_i[1,:],color='yellow',fmt='*',label='F9 i STA3')

plt.errorbar(F9_z[:,0],F9_z[:,1],yerr=10*F9_err_z[1,:],color='orange',fmt='x',label='F9 z STA1')
plt.errorbar(F9_z[:,0],F9_z[:,2],yerr=10*F9_err_z[1,:],color='orange',fmt='o',label='F9 z STA2')
plt.errorbar(F9_z[:,0],F9_z[:,3],yerr=10*F9_err_z[1,:],color='orange',fmt='*',label='F9 z STA3')

plt.title('F9 FLux')
#plt.legend()
plt.ylim([1*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(F51_K[:,0],F51_K[:,1],yerr=10*F51_err_K[1,:],color='b',fmt='x',label='F51 K STA1')
plt.errorbar(F51_K[:,0],F51_K[:,2],yerr=10*F51_err_K[2,:],color='b',fmt='o',label='F51 K STA2')
plt.errorbar(F51_K[:,0],F51_K[:,3],yerr=10*F51_err_K[3,:],color='b',fmt='*',label='F51 K STA3')

plt.errorbar(F51_H[:,0],F51_H[:,1],yerr=10*F51_err_H[1,:],color='r',fmt='x',label='F51 H STA1')
plt.errorbar(F51_H[:,0],F51_H[:,2],yerr=10*F51_err_H[1,:],color='r',fmt='o',label='F51 H STA2')
plt.errorbar(F51_H[:,0],F51_H[:,3],yerr=10*F51_err_H[1,:],color='r',fmt='*',label='F51 H STA3')

plt.errorbar(F51_J[:,0],F51_J[:,1],yerr=10*F51_err_J[1,:],color='g',fmt='x',label='F51 J STA1')
plt.errorbar(F51_J[:,0],F51_J[:,2],yerr=10*F51_err_J[1,:],color='g',fmt='o',label='F51 J STA2')
plt.errorbar(F51_J[:,0],F51_J[:,3],yerr=10*F51_err_J[1,:],color='g',fmt='*',label='F51 J STA3')

plt.errorbar(F51_g[:,0],F51_g[:,1],yerr=10*F51_err_g[1,:],color='purple',fmt='x',label='F51 g STA1')
plt.errorbar(F51_g[:,0],F51_g[:,2],yerr=10*F51_err_g[1,:],color='purple',fmt='o',label='F51 g STA2')
plt.errorbar(F51_g[:,0],F51_g[:,3],yerr=10*F51_err_g[1,:],color='purple',fmt='*',label='F51 g STA3')

plt.errorbar(F51_r[:,0],F51_r[:,1],yerr=10*F51_err_r[1,:],color='black',fmt='x',label='F51 r STA1')
plt.errorbar(F51_r[:,0],F51_r[:,2],yerr=10*F51_err_r[1,:],color='black',fmt='o',label='F51 r STA2')
plt.errorbar(F51_r[:,0],F51_r[:,3],yerr=10*F51_err_r[1,:],color='black',fmt='*',label='F51 r STA3')

plt.errorbar(F51_i[:,0],F51_i[:,1],yerr=10*F51_err_i[1,:],color='yellow',fmt='x',label='F51 i STA1')
plt.errorbar(F51_i[:,0],F51_i[:,2],yerr=10*F51_err_i[1,:],color='yellow',fmt='o',label='F51 i STA2')
plt.errorbar(F51_i[:,0],F51_i[:,3],yerr=10*F51_err_i[1,:],color='yellow',fmt='*',label='F51 i STA3')

plt.errorbar(F51_z[:,0],F51_z[:,1],yerr=10*F51_err_z[1,:],color='orange',fmt='x',label='F51 z STA1')
plt.errorbar(F51_z[:,0],F51_z[:,2],yerr=10*F51_err_z[1,:],color='orange',fmt='o',label='F51 z STA2')
plt.errorbar(F51_z[:,0],F51_z[:,3],yerr=10*F51_err_z[1,:],color='orange',fmt='*',label='F51 z STA3')

plt.title('F51 FLux')
#plt.legend()
plt.ylim([2*10**(-15),1.1*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(AKN120_K[:,0],AKN120_K[:,1],yerr=10*AKN120_err_K[1,:],color='b',fmt='x',label='AKN120 K STA1')
plt.errorbar(AKN120_K[:,0],AKN120_K[:,2],yerr=10*AKN120_err_K[2,:],color='b',fmt='o',label='AKN120 K STA2')
plt.errorbar(AKN120_K[:,0],AKN120_K[:,3],yerr=10*AKN120_err_K[3,:],color='b',fmt='*',label='AKN120 K STA3')

plt.errorbar(AKN120_H[:,0],AKN120_H[:,1],yerr=10*AKN120_err_H[1,:],color='r',fmt='x',label='AKN120 H STA1')
plt.errorbar(AKN120_H[:,0],AKN120_H[:,2],yerr=10*AKN120_err_H[1,:],color='r',fmt='o',label='AKN120 H STA2')
plt.errorbar(AKN120_H[:,0],AKN120_H[:,3],yerr=10*AKN120_err_H[1,:],color='r',fmt='*',label='AKN120 H STA3')

plt.errorbar(AKN120_J[:,0],AKN120_J[:,1],yerr=10*AKN120_err_J[1,:],color='g',fmt='x',label='AKN120 J STA1')
plt.errorbar(AKN120_J[:,0],AKN120_J[:,2],yerr=10*AKN120_err_J[1,:],color='g',fmt='o',label='AKN120 J STA2')
plt.errorbar(AKN120_J[:,0],AKN120_J[:,3],yerr=10*AKN120_err_J[1,:],color='g',fmt='*',label='AKN120 J STA3')

plt.errorbar(AKN120_g[:,0],AKN120_g[:,1],yerr=10*AKN120_err_g[1,:],color='purple',fmt='x',label='AKN120 g STA1')
plt.errorbar(AKN120_g[:,0],AKN120_g[:,2],yerr=10*AKN120_err_g[1,:],color='purple',fmt='o',label='AKN120 g STA2')
plt.errorbar(AKN120_g[:,0],AKN120_g[:,3],yerr=10*AKN120_err_g[1,:],color='purple',fmt='*',label='AKN120 g STA3')

plt.errorbar(AKN120_r[:,0],AKN120_r[:,1],yerr=10*AKN120_err_r[1,:],color='black',fmt='x',label='AKN120 r STA1')
plt.errorbar(AKN120_r[:,0],AKN120_r[:,2],yerr=10*AKN120_err_r[1,:],color='black',fmt='o',label='AKN120 r STA2')
plt.errorbar(AKN120_r[:,0],AKN120_r[:,3],yerr=10*AKN120_err_r[1,:],color='black',fmt='*',label='AKN120 r STA3')

plt.errorbar(AKN120_i[:,0],AKN120_i[:,1],yerr=10*AKN120_err_i[1,:],color='yellow',fmt='x',label='AKN120 i STA1')
plt.errorbar(AKN120_i[:,0],AKN120_i[:,2],yerr=10*AKN120_err_i[1,:],color='yellow',fmt='o',label='AKN120 i STA2')
plt.errorbar(AKN120_i[:,0],AKN120_i[:,3],yerr=10*AKN120_err_i[1,:],color='yellow',fmt='*',label='AKN120 i STA3')

plt.errorbar(AKN120_z[:,0],AKN120_z[:,1],yerr=10*AKN120_err_z[1,:],color='orange',fmt='x',label='AKN120 z STA1')
plt.errorbar(AKN120_z[:,0],AKN120_z[:,2],yerr=10*AKN120_err_z[1,:],color='orange',fmt='o',label='AKN120 z STA2')
plt.errorbar(AKN120_z[:,0],AKN120_z[:,3],yerr=10*AKN120_err_z[1,:],color='orange',fmt='*',label='AKN120 z STA3')

plt.title('AKN120 FLux')
#plt.legend()
plt.ylim([2*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(NGC3783_K[:,0],NGC3783_K[:,1],yerr=10*NGC3783_err_K[1,:],color='b',fmt='x',label='NGC3783 K STA1')
plt.errorbar(NGC3783_K[:,0],NGC3783_K[:,2],yerr=10*NGC3783_err_K[2,:],color='b',fmt='o',label='NGC3783 K STA2')
plt.errorbar(NGC3783_K[:,0],NGC3783_K[:,3],yerr=10*NGC3783_err_K[3,:],color='b',fmt='*',label='NGC3783 K STA3')

plt.errorbar(NGC3783_H[:,0],NGC3783_H[:,1],yerr=10*NGC3783_err_H[1,:],color='r',fmt='x',label='NGC3783 H STA1')
plt.errorbar(NGC3783_H[:,0],NGC3783_H[:,2],yerr=10*NGC3783_err_H[1,:],color='r',fmt='o',label='NGC3783 H STA2')
plt.errorbar(NGC3783_H[:,0],NGC3783_H[:,3],yerr=10*NGC3783_err_H[1,:],color='r',fmt='*',label='NGC3783 H STA3')

plt.errorbar(NGC3783_J[:,0],NGC3783_J[:,1],yerr=10*NGC3783_err_J[1,:],color='g',fmt='x',label='NGC3783 J STA1')
plt.errorbar(NGC3783_J[:,0],NGC3783_J[:,2],yerr=10*NGC3783_err_J[1,:],color='g',fmt='o',label='NGC3783 J STA2')
plt.errorbar(NGC3783_J[:,0],NGC3783_J[:,3],yerr=10*NGC3783_err_J[1,:],color='g',fmt='*',label='NGC3783 J STA3')

plt.errorbar(NGC3783_g[:,0],NGC3783_g[:,1],yerr=10*NGC3783_err_g[1,:],color='purple',fmt='x',label='NGC3783 g STA1')
plt.errorbar(NGC3783_g[:,0],NGC3783_g[:,2],yerr=10*NGC3783_err_g[1,:],color='purple',fmt='o',label='NGC3783 g STA2')
plt.errorbar(NGC3783_g[:,0],NGC3783_g[:,3],yerr=10*NGC3783_err_g[1,:],color='purple',fmt='*',label='NGC3783 g STA3')

plt.errorbar(NGC3783_r[:,0],NGC3783_r[:,1],yerr=10*NGC3783_err_r[1,:],color='black',fmt='x',label='NGC3783 r STA1')
plt.errorbar(NGC3783_r[:,0],NGC3783_r[:,2],yerr=10*NGC3783_err_r[1,:],color='black',fmt='o',label='NGC3783 r STA2')
plt.errorbar(NGC3783_r[:,0],NGC3783_r[:,3],yerr=10*NGC3783_err_r[1,:],color='black',fmt='*',label='NGC3783 r STA3')

plt.errorbar(NGC3783_i[:,0],NGC3783_i[:,1],yerr=10*NGC3783_err_i[1,:],color='yellow',fmt='x',label='NGC3783 i STA1')
plt.errorbar(NGC3783_i[:,0],NGC3783_i[:,2],yerr=10*NGC3783_err_i[1,:],color='yellow',fmt='o',label='NGC3783 i STA2')
plt.errorbar(NGC3783_i[:,0],NGC3783_i[:,3],yerr=10*NGC3783_err_i[1,:],color='yellow',fmt='*',label='NGC3783 i STA3')

plt.errorbar(NGC3783_z[:,0],NGC3783_z[:,1],yerr=10*NGC3783_err_z[1,:],color='orange',fmt='x',label='NGC3783 z STA1')
plt.errorbar(NGC3783_z[:,0],NGC3783_z[:,2],yerr=10*NGC3783_err_z[1,:],color='orange',fmt='o',label='NGC3783 z STA2')
plt.errorbar(NGC3783_z[:,0],NGC3783_z[:,3],yerr=10*NGC3783_err_z[1,:],color='orange',fmt='*',label='NGC3783 z STA3')

plt.title('NGC3783 FLux')
#plt.legend()
plt.ylim([5*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(MARK509_K[:,0],MARK509_K[:,1],yerr=10*MARK509_err_K[1,:],color='b',fmt='x',label='MARK509 K STA1')
plt.errorbar(MARK509_K[:,0],MARK509_K[:,2],yerr=10*MARK509_err_K[2,:],color='b',fmt='o',label='MARK509 K STA2')
plt.errorbar(MARK509_K[:,0],MARK509_K[:,3],yerr=10*MARK509_err_K[3,:],color='b',fmt='*',label='MARK509 K STA3')

plt.errorbar(MARK509_H[:,0],MARK509_H[:,1],yerr=10*MARK509_err_H[1,:],color='r',fmt='x',label='MARK509 H STA1')
plt.errorbar(MARK509_H[:,0],MARK509_H[:,2],yerr=10*MARK509_err_H[1,:],color='r',fmt='o',label='MARK509 H STA2')
plt.errorbar(MARK509_H[:,0],MARK509_H[:,3],yerr=10*MARK509_err_H[1,:],color='r',fmt='*',label='MARK509 H STA3')

plt.errorbar(MARK509_J[:,0],MARK509_J[:,1],yerr=10*MARK509_err_J[1,:],color='g',fmt='x',label='MARK509 J STA1')
plt.errorbar(MARK509_J[:,0],MARK509_J[:,2],yerr=10*MARK509_err_J[1,:],color='g',fmt='o',label='MARK509 J STA2')
plt.errorbar(MARK509_J[:,0],MARK509_J[:,3],yerr=10*MARK509_err_J[1,:],color='g',fmt='*',label='MARK509 J STA3')

plt.errorbar(MARK509_g[:,0],MARK509_g[:,1],yerr=10*MARK509_err_g[1,:],color='purple',fmt='x',label='MARK509 g STA1')
plt.errorbar(MARK509_g[:,0],MARK509_g[:,2],yerr=10*MARK509_err_g[1,:],color='purple',fmt='o',label='MARK509 g STA2')
plt.errorbar(MARK509_g[:,0],MARK509_g[:,3],yerr=10*MARK509_err_g[1,:],color='purple',fmt='*',label='MARK509 g STA3')

plt.errorbar(MARK509_r[:,0],MARK509_r[:,1],yerr=10*MARK509_err_r[1,:],color='black',fmt='x',label='MARK509 r STA1')
plt.errorbar(MARK509_r[:,0],MARK509_r[:,2],yerr=10*MARK509_err_r[1,:],color='black',fmt='o',label='MARK509 r STA2')
plt.errorbar(MARK509_r[:,0],MARK509_r[:,3],yerr=10*MARK509_err_r[1,:],color='black',fmt='*',label='MARK509 r STA3')

plt.errorbar(MARK509_i[:,0],MARK509_i[:,1],yerr=10*MARK509_err_i[1,:],color='yellow',fmt='x',label='MARK509 i STA1')
plt.errorbar(MARK509_i[:,0],MARK509_i[:,2],yerr=10*MARK509_err_i[1,:],color='yellow',fmt='o',label='MARK509 i STA2')
plt.errorbar(MARK509_i[:,0],MARK509_i[:,3],yerr=10*MARK509_err_i[1,:],color='yellow',fmt='*',label='MARK509 i STA3')

plt.errorbar(MARK509_z[:,0],MARK509_z[:,1],yerr=10*MARK509_err_z[1,:],color='orange',fmt='x',label='MARK509 z STA1')
plt.errorbar(MARK509_z[:,0],MARK509_z[:,2],yerr=10*MARK509_err_z[1,:],color='orange',fmt='o',label='MARK509 z STA2')
plt.errorbar(MARK509_z[:,0],MARK509_z[:,3],yerr=10*MARK509_err_z[1,:],color='orange',fmt='*',label='MARK509 z STA3')

plt.title('MARK509 FLux')
#plt.legend()
plt.ylim([2*10**(-15),2*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(H0557_K[:,0],H0557_K[:,1],color='b',fmt='x',label='H0557 K STA1')
plt.errorbar(H0557_K[:,0],H0557_K[:,2],color='b',fmt='o',label='H0557 K STA2')
plt.errorbar(H0557_K[:,0],H0557_K[:,3],color='b',fmt='*',label='H0557 K STA3')

plt.errorbar(H0557_H[:,0],H0557_H[:,1],color='r',fmt='x',label='H0557 H STA1')
plt.errorbar(H0557_H[:,0],H0557_H[:,2],color='r',fmt='o',label='H0557 H STA2')
plt.errorbar(H0557_H[:,0],H0557_H[:,3],color='r',fmt='*',label='H0557 H STA3')

plt.errorbar(H0557_J[:,0],H0557_J[:,1],color='g',fmt='x',label='H0557 J STA1')
plt.errorbar(H0557_J[:,0],H0557_J[:,2],color='g',fmt='o',label='H0557 J STA2')
plt.errorbar(H0557_J[:,0],H0557_J[:,3],color='g',fmt='*',label='H0557 J STA3')

plt.errorbar(H0557_g[:,0],H0557_g[:,1],color='purple',fmt='x',label='H0557 g STA1')
plt.errorbar(H0557_g[:,0],H0557_g[:,2],color='purple',fmt='o',label='H0557 g STA2')
plt.errorbar(H0557_g[:,0],H0557_g[:,3],color='purple',fmt='*',label='H0557 g STA3')

plt.errorbar(H0557_r[:,0],H0557_r[:,1],color='black',fmt='x',label='H0557 r STA1')
plt.errorbar(H0557_r[:,0],H0557_r[:,2],color='black',fmt='o',label='H0557 r STA2')
plt.errorbar(H0557_r[:,0],H0557_r[:,3],color='black',fmt='*',label='H0557 r STA3')

plt.errorbar(H0557_i[:,0],H0557_i[:,1],color='yellow',fmt='x',label='H0557 i STA1')
plt.errorbar(H0557_i[:,0],H0557_i[:,2],color='yellow',fmt='o',label='H0557 i STA2')
plt.errorbar(H0557_i[:,0],H0557_i[:,3],color='yellow',fmt='*',label='H0557 i STA3')

plt.errorbar(H0557_z[:,0],H0557_z[:,1],color='orange',fmt='x',label='H0557 z STA1')
plt.errorbar(H0557_z[:,0],H0557_z[:,2],color='orange',fmt='o',label='H0557 z STA2')
plt.errorbar(H0557_z[:,0],H0557_z[:,3],color='orange',fmt='*',label='H0557 z STA3')

plt.title('H0557 FLux')
#plt.legend()
plt.ylim([2*10**(-15),1.6*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()

plt.figure(figsize=(15,10))
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,1],yerr=10*NGC7213_err_K[1,:],color='b',fmt='x',label='NGC7213 K STA1')
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,2],yerr=10*NGC7213_err_K[2,:],color='b',fmt='o',label='NGC7213 K STA2')
plt.errorbar(NGC7213_K[:,0],NGC7213_K[:,3],yerr=10*NGC7213_err_K[3,:],color='b',fmt='*',label='NGC7213 K STA3')

plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,1],yerr=10*NGC7213_err_H[1,:],color='r',fmt='x',label='NGC7213 H STA1')
plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,2],yerr=10*NGC7213_err_H[1,:],color='r',fmt='o',label='NGC7213 H STA2')
plt.errorbar(NGC7213_H[:,0],NGC7213_H[:,3],yerr=10*NGC7213_err_H[1,:],color='r',fmt='*',label='NGC7213 H STA3')

plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,1],yerr=10*NGC7213_err_J[1,:],color='g',fmt='x',label='NGC7213 J STA1')
plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,2],yerr=10*NGC7213_err_J[1,:],color='g',fmt='o',label='NGC7213 J STA2')
plt.errorbar(NGC7213_J[:,0],NGC7213_J[:,3],yerr=10*NGC7213_err_J[1,:],color='g',fmt='*',label='NGC7213 J STA3')

plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,1],yerr=10*NGC7213_err_g[1,:],color='purple',fmt='x',label='NGC7213 g STA1')
plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,2],yerr=10*NGC7213_err_g[1,:],color='purple',fmt='o',label='NGC7213 g STA2')
plt.errorbar(NGC7213_g[:,0],NGC7213_g[:,3],yerr=10*NGC7213_err_g[1,:],color='purple',fmt='*',label='NGC7213 g STA3')

plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,1],yerr=10*NGC7213_err_r[1,:],color='black',fmt='x',label='NGC7213 r STA1')
plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,2],yerr=10*NGC7213_err_r[1,:],color='black',fmt='o',label='NGC7213 r STA2')
plt.errorbar(NGC7213_r[:,0],NGC7213_r[:,3],yerr=10*NGC7213_err_r[1,:],color='black',fmt='*',label='NGC7213 r STA3')

plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,1],yerr=10*NGC7213_err_i[1,:],color='yellow',fmt='x',label='NGC7213 i STA1')
plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,2],yerr=10*NGC7213_err_i[1,:],color='yellow',fmt='o',label='NGC7213 i STA2')
plt.errorbar(NGC7213_i[:,0],NGC7213_i[:,3],yerr=10*NGC7213_err_i[1,:],color='yellow',fmt='*',label='NGC7213 i STA3')

plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,1],yerr=10*NGC7213_err_z[1,:],color='orange',fmt='x',label='NGC7213 z STA1')
plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,2],yerr=10*NGC7213_err_z[1,:],color='orange',fmt='o',label='NGC7213 z STA2')
plt.errorbar(NGC7213_z[:,0],NGC7213_z[:,3],yerr=10*NGC7213_err_z[1,:],color='orange',fmt='*',label='NGC7213 z STA3')

plt.title('NGC7213 FLux')
plt.legend()
plt.ylim([10*10**(-15),4.5*10**(-14)])
plt.ylabel('Flux')
plt.xlabel('Days')
plt.show()
